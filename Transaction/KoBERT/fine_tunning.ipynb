# %% [markdown]
# <a href="https://colab.research.google.com/github/Johyeyoung/capstone-2021-35/blob/master/Transaction/KoBERT/fine_tunning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 라이브러리 설치

# %%
# 이는 구글 코랩으로 돌린 버전입니다. 그리고 기본 코드는 SKT Brain의 KoBERT를 그대로 가져왔고, 학습 및 테스트 데이터셋만 따로 준비한 것입니다.
# SKT Brain github 주소는 다음과 같습니다. https://github.com/SKTBrain/KoBERT

# !pip install mxnet
# !pip install gluonnlp pandas tqdm
# !pip install sentencepiece
# !pip install transformers==3 # 최신 버전으로 설치하면 "Input: must be Tensor, not str" 라는 에러 발생
# !pip install torch

# !pip install git+https://git@github.com/SKTBrain/KoBERT.git@master
# Out:
# Collecting mxnet
#   Downloading https://files.pythonhosted.org/packages/30/07/66174e78c12a3048db9039aaa09553e35035ef3a008ba3e0ed8d2aa3c47b/mxnet-1.8.0.post0-py2.py3-none-manylinux2014_x86_64.whl (46.9MB)
#      |████████████████████████████████| 46.9MB 64kB/s
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading https://files.pythonhosted.org/packages/53/39/4ab213673844e0c004bed8a0781a0721a3f6bb23eb8854ee75c236428892/graphviz-0.8.4-py2.py3-none-any.whl
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from mxnet) (2.23.0)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.7/dist-packages (from mxnet) (1.19.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (3.0.4)
# Installing collected packages: graphviz, mxnet
#   Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# Successfully installed graphviz-0.8.4 mxnet-1.8.0.post0
# Collecting gluonnlp
#   Downloading https://files.pythonhosted.org/packages/9c/81/a238e47ccba0d7a61dcef4e0b4a7fd4473cb86bed3d84dd4fe28d45a0905/gluonnlp-0.10.0.tar.gz (344kB)
#      |████████████████████████████████| 348kB 29.9MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.41.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from gluonnlp) (1.19.5)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from gluonnlp) (0.29.23)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from gluonnlp) (20.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->gluonnlp) (2.4.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Building wheels for collected packages: gluonnlp
#   Building wheel for gluonnlp (setup.py) ... done
#   Created wheel for gluonnlp: filename=gluonnlp-0.10.0-cp37-cp37m-linux_x86_64.whl size=595697 sha256=664978ebbe6f0c19e9433b5cc2b6046bdbf400ccea56b23e663e7fd660dc0ad6
#   Stored in directory: /root/.cache/pip/wheels/37/65/52/63032864a0f31a08b9a88569f803b5bafac8abd207fd7f7534
# Successfully built gluonnlp
# Installing collected packages: gluonnlp
# Successfully installed gluonnlp-0.10.0
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/ac/aa/1437691b0c7c83086ebb79ce2da16e00bef024f24fec2a5161c35476f499/sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 26.1MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.96
# Collecting transformers==3
#   Downloading https://files.pythonhosted.org/packages/9c/35/1c3f6e62d81f5f0daff1384e6d5e6c5758682a8357ebc765ece2b9def62b/transformers-3.0.0-py3-none-any.whl (754kB)
#      |████████████████████████████████| 757kB 24.6MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3) (4.41.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3) (3.0.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3) (2019.12.20)
# Collecting tokenizers==0.8.0-rc4
#   Downloading https://files.pythonhosted.org/packages/f7/82/0e82a95bd9db2b32569500cc1bb47aa7c4e0f57aa5e35cceba414096917b/tokenizers-0.8.0rc4-cp37-cp37m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 30.0MB/s
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from transformers==3) (0.1.96)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3) (1.19.5)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 43.0MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3) (20.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3) (1.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3) (2.4.7)
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.45 tokenizers-0.8.0rc4 transformers-3.0.0
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.7.4.3)
# Collecting git+https://****@github.com/SKTBrain/KoBERT.git@master
#   Cloning https://****@github.com/SKTBrain/KoBERT.git (to revision master) to /tmp/pip-req-build-ijrx9wfk
#   Running command git clone -q 'https://****@github.com/SKTBrain/KoBERT.git' /tmp/pip-req-build-ijrx9wfk
# Building wheels for collected packages: kobert
#   Building wheel for kobert (setup.py) ... done
#   Created wheel for kobert: filename=kobert-0.1.2-cp37-none-any.whl size=12718 sha256=85e5da7c9b09ae027786b5b16cd339c399d03ff5725474b37a113c0aa5391b87
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zxqnkcsv/wheels/a2/b0/41/435ee4e918f91918be41529283c5ff86cd010f02e7525aecf3
# Successfully built kobert
# Installing collected packages: kobert
# Successfully installed kobert-0.1.2

# %% [markdown]
# ## KoBERT 불러오기

# %%
import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import gluonnlp as nlp
import numpy as np
from tqdm import tqdm, tqdm_notebook

from kobert.utils import get_tokenizer
from kobert.pytorch_kobert import get_pytorch_kobert_model

from transformers import AdamW
from transformers.optimization import get_cosine_schedule_with_warmup

##GPU 사용 시
device = torch.device("cuda:0")
bertmodel, vocab = get_pytorch_kobert_model()

# 기본 Bert tokenizer 사용
tokenizer = get_tokenizer()
tok = nlp.data.BERTSPTokenizer(tokenizer, vocab, lower=False)


class BERTDataset(Dataset):
    def __init__(self, dataset, sent_idx, label_idx, bert_tokenizer, max_len,
                 pad, pair):
        transform = nlp.data.BERTSentenceTransform(
            bert_tokenizer, max_seq_length=max_len, pad=pad, pair=pair) 

        self.sentences = [transform([i[sent_idx]]) for i in dataset]
        self.labels = [np.int32(i[label_idx]) for i in dataset]

    def __getitem__(self, i):
        return (self.sentences[i] + (self.labels[i], ))

    def __len__(self):
        return (len(self.labels))
# Out:
# [██████████████████████████████████████████████████]
# [██████████████████████████████████████████████████]
# using cached model

# %% [markdown]
# ## 데이터 로드

# %%
# 학습용 데이터셋 불러오기
import pandas as pd
file_path = '/content/drive/MyDrive/Trigger_list_final.csv'
new_data = pd.read_csv(file_path, names=['type_num', 'content', 'type'])

# 데이터 전처리
new_data = new_data.dropna(axis=0) # 결측값 제거
new_data.drop(['type_num'], axis=1, inplace=True)
new_data.head()
# Out:
#                                   content     type
# 1                               ADAS 꺼달라함  ADAS_고장
# 2             ADAS 시스템 점검경고등 및 시스템점검 문구 뜸  ADAS_고장
# 3                     ADAS 장애 운행에는 지장이 없음  ADAS_고장
# 4                ADAS 프로그램 점검 안내 점등되었다고인입  ADAS_고장
# 5  ADSD경고등으로 주행에는 문제 없으나 이용에 불편하실지 질의 괜찮음  ADAS_고장

# %%
# 같은 내용의 카테고리 합치기
new_data["type"] = new_data["type"].str.replace(pat=r'하이패스_카드분실', repl=r'하이패스_분실', regex=True)
new_data["type"] = new_data["type"].str.replace(pat=r'트렁크_파손', repl=r'트렁크_고장', regex=True)
new_data["type"] = new_data["type"].str.replace(pat=r'거치대_(분실|파손)', repl=r'내비게이션_파손', regex=True)
new_data["type"] = new_data["type"].str.replace(pat=r'타이어_파스/펑크\(후우\)', repl=r'타이어_파스/펑크', regex=True)
new_data["type"] = new_data["type"].str.replace(pat=r'타이어_파스/펑크\(후좌\)', repl=r'타이어_파스/펑크', regex=True)
new_data["type"] = new_data["type"].str.replace(pat=r'타이어_파스/펑크\(전우\)', repl=r'타이어_파스/펑크', regex=True)
new_data["type"] = new_data["type"].str.replace(pat=r'타이어_파스/펑크\(전좌\)', repl=r'타이어_파스/펑크', regex=True)
new_data["type"] = new_data["type"].str.replace(pat=r'블랙박스_탈거', repl=r'블랙박스_고장', regex=True)


# 장애요인 라벨링
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(new_data['type'])
new_data['type'] = encoder.transform(new_data['type'])
new_data.head()


# 라벨링된 type 매핑 ex) {0: '타이어_파스/펑크', 1: '내비게이션_고장', 2: '블랙박스고장', 3: '하이패스 분실', 4: '주행_차량떨림'}
mapping = dict(zip(range(len(encoder.classes_)), encoder.classes_))
print(mapping)

# Train / Test set 분리
from sklearn.model_selection import train_test_split
train, test = train_test_split(new_data, test_size=0.2, random_state=42)
print("train shape is:", len(train))
print("test shape is:", len(test))
# Out:
# {0: 'ADAS_고장', 1: 'ADAS_파손', 2: 'USB포트_고장', 3: '경고등_ABS', 4: '경고등_DPF(배출가스)', 5: '경고등_ESC(차세제어)', 6: '경고등_배터리', 7: '경고등_브레이크', 8: '경고등_스패너(서비스알림)', 9: '경고등_에어백', 10: '경고등_엔진오일', 11: '경고등_엔진체크', 12: '경고등_연료부족', 13: '경고등_온도게이지', 14: '경고등_요소수부족', 15: '경고등_전/후측방 충돌 경고', 16: '경고등_통합경고등(느낌표)', 17: '글로브박스_파손', 18: '내비게이션_고장', 19: '내비게이션_분실', 20: '내비게이션_업데이트', 21: '내비게이션_인터넷연결불가', 22: '내비게이션_파손', 23: '내장제_파손', 24: '단말기_배선', 25: '단말기_신호불량', 26: '단말기_탈거', 27: '단말기_파손', 28: '도어_고장', 29: '도어_소음', 30: '도어_파손', 31: '라이트/전구_경고등(고장)', 32: '라이트/전구_파손', 33: '룸미러_파손', 34: '목받침대_고장/분실', 35: '문제어불가_옥스트라', 36: '문제어불가_카드태깅', 37: '발판매트_분실', 38: '번호판_분실', 39: '번호판_파손', 40: '본넷_고장', 41: '본넷_파손', 42: '브레이크_고장', 43: '브레이크_밀림', 44: '브레이크_소음', 45: '블랙박스_고장', 46: '블랙박스_분실', 47: '블랙박스_파손', 48: '사고조사_요청', 49: '사이드미러_고장', 50: '사이드미러_파손', 51: '사이드브레이크_해제불가', 52: '선바이저_파손', 53: '시거잭_고장', 54: '시동_고장', 55: '시동_꺼짐', 56: '시동_배터리방전', 57: '시동_키인식불가(키아웃)', 58: '시트_시트조절_고장', 59: '시트_열선시트_고장', 60: '시트_파손', 61: '실내등_고장', 62: '안심번호_분실', 63: '안심번호_연동오류', 64: '안전벨트_고장', 65: '에어컨_고장', 66: '에어컨_소음', 67: '에어컨_악취', 68: '오디오_AUX', 69: '오디오_고장', 70: '오디오_버튼파손/분실', 71: '오디오_블루투스', 72: '오디오_소음', 73: '와이퍼_고장', 74: '와이퍼_교체필요', 75: '와이퍼_파손', 76: '외관_누유', 77: '외관_파손(상부)', 78: '외관_파손(하부)', 79: '외부스티커_훼손', 80: '워셔액_(통)파손', 81: '워셔액_고장', 82: '위생_구토', 83: '위생_내부위생불량(모래, 흙, 먼지 등)', 84: '위생_담배(담배냄새, 담뱃재 등)', 85: '위생_동물털', 86: '위생_쓰레기', 87: '위생_악취', 88: '위생_외부위생불량 (유리, 경고장 등)', 89: '위생_워셔액', 90: '전기차_충전구 고장/파손', 91: '전기차_충전불가(태깅불가)', 92: '전기차_충전커넥터_고장', 93: '주유구_(캡)분실', 94: '주유구_고장/파손', 95: '주유카드_결제오류', 96: '주유카드_분실', 97: '주유카드_비치함 파손/탈거', 98: '주유카드_파손', 99: '주차장_입차불가(만차)', 100: '주차장_차량위치확인불가', 101: '주차장_출차불가(비용발생)', 102: '주차장_환경이슈', 103: '주행_RPM이상', 104: '주행_변속기이상', 105: '주행_변속레버파손', 106: '주행_소음', 107: '주행_차량떨림', 108: '주행_차량쏠림(얼라이먼트)', 109: '주행_타는냄새', 110: '주행_핸들떨림', 111: '차량상태확인', 112: '창문_썬팅', 113: '창문_작동불가', 114: '창문_파손', 115: '충전카드_결제오류', 116: '충전카드_보관함 파손/탈거', 117: '충전카드_분실', 118: '타이어_공기압경고등', 119: '타이어_마모', 120: '타이어_코드절상', 121: '타이어_파스/펑크', 122: '트렁크_고장', 123: '하이패스_고장', 124: '하이패스_분실', 125: '하이패스_카드오류', 126: '하이패스_파손(탈거, 파손)', 127: '핸들_경적_고장', 128: '핸들_기능조작', 129: '핸들_소음', 130: '핸들_열선_고장', 131: '핸들_위치조절_고장', 132: '핸들_파손', 133: '후방센서_고장', 134: '후방카메라_고장', 135: '후방카메라_파손(탈거, 각도이상)', 136: '휠_손상', 137: '히터_고장', 138: '히터_소음', 139: '히터_악취'}
# train shape is: 8772
# test shape is: 2193

# %%
type_num = train['type'].values.tolist()
content = train['content'].values.tolist()
train_list = [[str(content[i]), type_num[i]] for i in range(len(type_num))]
# Train 리스트 비율 확인
print('Train ratio :', [type_num.count(i) for i in range(len(mapping))])

type_num = test['type'].values.tolist()
content = test['content'].values.tolist()
test_list = [[str(content[i]), type_num[i]] for i in range(len(type_num))]
# Test 리스트 비율 확인
print('Test ratio: ', [type_num.count(i) for i in range(len(mapping))])
# Out:
# Train ratio : [22, 1, 24, 7, 6, 8, 14, 62, 28, 14, 30, 331, 18, 12, 18, 84, 191, 5, 806, 6, 73, 536, 130, 55, 17, 133, 10, 1, 74, 14, 16, 843, 48, 5, 2, 100, 16, 7, 14, 7, 16, 4, 41, 66, 138, 125, 5, 4, 13, 38, 15, 27, 9, 25, 63, 31, 412, 147, 112, 30, 9, 24, 4, 5, 63, 2, 3, 13, 2, 40, 82, 135, 9, 29, 27, 21, 13, 27, 33, 3, 10, 355, 2, 18, 9, 6, 6, 4, 11, 14, 13, 8, 13, 15, 33, 42, 91, 7, 7, 8, 37, 4, 0, 80, 43, 2, 281, 106, 102, 25, 23, 31, 46, 58, 11, 69, 6, 57, 510, 34, 9, 285, 32, 104, 26, 31, 15, 29, 22, 27, 2, 12, 3, 17, 205, 42, 7, 25, 18, 11]
# Test ratio:  [8, 0, 9, 3, 1, 0, 3, 10, 3, 6, 10, 103, 7, 2, 6, 11, 39, 0, 202, 2, 20, 111, 46, 22, 6, 23, 6, 0, 19, 5, 2, 235, 10, 1, 2, 31, 3, 2, 2, 1, 1, 0, 6, 19, 32, 24, 1, 0, 1, 13, 3, 9, 3, 8, 18, 10, 88, 31, 29, 9, 3, 8, 0, 1, 12, 0, 2, 3, 0, 8, 22, 44, 4, 7, 9, 5, 2, 8, 9, 1, 0, 73, 2, 1, 1, 1, 0, 1, 2, 5, 3, 5, 3, 4, 9, 9, 19, 0, 2, 1, 10, 0, 1, 19, 11, 0, 60, 22, 30, 3, 11, 9, 17, 13, 1, 16, 2, 18, 136, 14, 2, 62, 7, 23, 5, 10, 0, 9, 10, 9, 0, 3, 0, 9, 54, 12, 0, 8, 6, 5]

# %%
for i in range(len(test_list)):
  print(train_list[i])
# Out:
# ['지난 이용간 후방카메라 없었음 다른 차량에서는 작동되는지 문의', 134]
# ['헤드라이트 기스 예약취소요청', 32]
# ['브레이크 밟을때마다 조수석 앞바퀴에서 쇠긁히는 소음 발생', 44]
# ['히터가 안나와서 너무 추워 대차 요청', 137]
# ['차량 조수석 문계패 불가', 28]
# ['배터리 수치', 56]
# ['내비게이션 인터넷 및 와이파이 연결불가항의', 21]
# ['주행 중 워셔액 안나옴', 81]
# ['현장조치 이후 기사님이 보조석 앞타이어 휠 쪽 확인 요청하였다고함', 136]
# ['타이어공기압 경고등 ', 118]
# ['내비게이션 SD카드 오류나서 인입', 21]
# ['악취난다며인입', 87]
# ['시동 거니 경고등이 많이 떠있다함', 15]
# ['운행 중 차량떨림이 심함', 107]
# ['엔진 소음이 심하고 악셀레이터를 밟을 때 차가 튕기고 불안정함', 106]
# ['안나오는 라이트 사진촬영후 인입', 31]
# ['안전벨트가 제대로 안된다고하심', 64]
# ['차량 경고등 문의', 31]
# ['차량 바리게이트가 쳐져있어 지상층으로 입차 불가', 99]
# ['제동등 경고등', 31]
# ['워셔액 얼어있음', 81]
# ['키아웃으로 긴급출동 점검 받으셧으나 조치 불가로 확인되어 차량 잔여시간 환불요청', 57]
# ['기타', 7]
# ['타이어공기압경고등점등 및 제동등 점검 문구로 인입', 118]
# ['카드가 빠져있다는 알람 지속 출력 카드 재삽입 시에도 동일했다고 함 ', 123]
# ['내비게이션 음성 안내 나오지 않음', 18]
# ['스마트키를 인식할수 없다고 시동안걸려서 인입', 57]
# ['액셀 밞으면 소리난다고함', 106]
# ['고객 시동걸었으나 지속 소음발생인입', 111]
# ['어제 이용한 코나 차량 후방카메라 고장', 135]
# ['차량 사이드 미러 각도 조작이 안되서 문의', 49]
# ['내비 탈거되있다고 인입', 22]
# ['인터넷 연결 불가 상태', 18]
# ['경고등이 점등되었다고 함', 32]
# ['눈때문에 출차 불가 문의', 101]
# ['내비게이션 고정이 안되고 자꾸 앞으로 쏠림', 22]
# ['볼륨버튼 파손으로 인입', 70]
# ['주유구 버튼 없는 차량이며 주유구 눌렀으나 안 열림', 94]
# ['사진첨부 탑승시 부터 경고등 점등 라이트 켜면 한쪽만 나오는듯 차량 확인해야할듯', 31]
# ['핸들쏠임으로 공업사입고해야한다고하심', 110]
# ['스마트 키 인식이 되지 않는다고 인입', 57]
# ['내비게이션이 되지 않음', 18]
# ['트렁크 안열림', 122]
# ['운전석 등받이', 58]
# ['조수석 뒷바퀴에 못이 박혀있어서 떼우긴 했는데', 121]
# ['차량 주행중 경고등 점등되어 문의', 31]
# ['엑셀레이터 밟으면 진동 및 밀림현상 느껴진다고 하여 대차 처리 진행 별도 경고등 없음 ', 107]
# ['공지', 112]
# ['운행전 엔진체크 경고등 인입', 11]
# ['내비게이션 SD카드 버튼 없음', 22]
# ['문열고 차량탑승후 스마트키 인식안됨 메세지', 54]
# ['대차차량 엔진체크경고등점등', 11]
# ['운행중 타이어가 펑크나서 연락드림', 121]
# ['라이트 통화중꺼짐', 31]
# ['오디오 버튼 안눌림', 70]
# ['해당부분 이후 조치하겠음 안내', 89]
# ['키아웃 지속 상담하고있으나 말이 안통하는것같다며 항의', 57]
# ['이용전 배터리 방전으로 유입', 56]
# ['내비게이션 이용불가 기기가 작동하지 않음', 21]
# ['터널지나던중 라이트를 켰는데 갑자기 경고등이 발생하여 인입', 31]
# ['브레이크밟을때 소음 브레이크밀림 죽을뻔했다고하심', 44]
# ['보충은 해놓은 상태라고 함', 81]
# ['차량 문제어 불가로인하여 장애블락 생성', 35]
# ['핸들 조작할 때 소음 발생 조치 가능하여 인입', 129]
# ['눈으로 인해 시야 확보 불가 예약 취소 요청', 77]
# ['운행시 전조등 점검 확인과 경고등 점등되어 인입', 31]
# ['카니발 실내등이 들어오지 않는다고 함', 61]
# ['문제차량은정위치주차', 11]
# ['쏘카존 만차라고함', 108]
# ['네비가안켜짐', 18]
# ['고객 내비에서 지메일 연결하라는 문구 뜬다고 하심', 21]
# ['내비게이션 작동 안된다함 인터넷이나 GPS연결이 안되는것같음', 21]
# ['떨림현상이 있음', 103]
# ['운행하려는데 배터리가 방전되어인입', 56]
# ['차량이용중 전조등이 점등안된다며인입', 31]
# ['라이트 현장조치 불가하다고 하여 차량 변경 요청', 31]
# ['네비게이션 인터넷 연결불가로 인입', 21]
# ['내비 버튼 중 하나가 빠져 문의', 22]
# ['엔진 소리 이상', 77]
# ['전좌 바람빠짐', 121]
# ['조수석 글러브 박스에 충전 카드 넣어달라고 안내', 116]
# ['왼쪽 하향등 점검표시가 뜹니다 내려서 확인은 안했지만 불이들어오지 않는것 같음', 31]
# ['차량이 없음 경적 울려도 그렇고 안들림', 18]
# ['제동등 점검 안내 뜸', 31]
# ['내비지속 꺼짐', 18]
# ['보복운전 당해 블랙박스 영상 파일 요청', 45]
# ['내비게이션 기능만 작동 불가', 18]
# ['차량에서 초마다 삑 삑 소리가 규칙적으로 계속 남', 106]
# ['차량 탑승전 타이어 바람이 빠져있어 인입', 118]
# ['내비게이션 사용자 인증정보를 인증할 수 없다고 나오신다고 함', 18]
# ['T맵 실행 준비중으로 나오고 안된다고 하심', 15]
# ['차량 내비게이션 소리가 안남 주차비 환불 서비스에 대해 문의', 18]
# ['기아오토큐 방문해서 수리 받고 영수증 첨부하겠다고 함', 31]
# ['전조등 장애 제보', 31]
# ['화면은이상없이 잘나오신다고하여 종료 ', 135]
# ['현위치 반납 알엠SV협의', 107]
# ['네비게이션 정상작동하나 시간연장버튼이 눌리지않음', 18]
# ['차량 주행등 경고등 점등됐다함', 31]
# ['시동 안걸려서 문의', 56]
# ['쏘카존에 처음 이용하러 온건데 시동이 안 걸리는 것인지 문의', 56]
# ['전조등등 점등', 31]
# ['들어보니 소음이 심하긴 함', 29]
# ['주유카드 거래정지카드라 나오신다며 문의', 95]
# ['아직 주간이라 주행등 문제가 되진 않을거다', 31]
# ['시동을 꺼도 네비게이션 화면이 꺼지지 않는다고 하심', 18]
# ['대차존 반납요청', 134]
# ['히터 소음', 138]
# ['차량 변경 요청', 118]
# ['다시가기엔멀다고함', 96]
# ['TCS인터넷 연결불가', 21]
# ['배터리 방전으로 문제어 불가 인입', 56]
# ['보조석 에어백에서 달달거리는 소리 난다고 주장', 106]
# ['이용 중인 차량 워셔액 나오지 않음', 81]
# ['차량에서 폰 버튼이 눌려지지 않음', 71]
# ['T맵실행중으로안나온다고함', 21]
# ['오전에 대여했었던 차량 내부 위생상태 관련하여 쿠폰 안내받았으나 발급 안되어 있으며 이후 이용했던 차량 라이트가 안 들어왔었다며 제보 문의', 31]
# ['제동등 제보로 사진확인 시 통합경고등 점등됨 확인', 16]
# ['고객 차량 빌리고 운행을 안했으나 라이트 껴져있어서 반납이 안된다고 인입', 121]
# ['차량 이용하는데 통합경고등 발생했다며 인입', 31]
# ['운행중에 경고등이 떴다가 사라졌다 하는데 지금은 또 안나온다고 하심', 64]
# ['내비게이션이 주행하다가 갑자기 꺼졌음', 18]
# ['엔진 경고등 나왔다며 인입', 11]
# ['후진하다가 꺼진 뒤로 엔진 체크 경고등이 계속 들어오는데 주행해도 되냐고 함', 11]
# ['경고등 점등되어 인입', 8]
# ['운전하기에 시트가 뒤로 너무 누워있어 불편하다고 함', 58]
# ['주유카드 언제 없어졌는지 확인요청', 96]
# ['내비게이션 연결안됨', 21]
# ['이미 고속도로 위에서 대전쪽으로 이동중', 11]
# ['고객 사진거부', 21]
# ['경고등점등 문의', 118]
# ['내비게이션 사진 첨부 업데이트만하고 작동이 안됨', 20]
# ['동계형 워셔액으로 넣어놔야지 이렇게 얼어서 어떻게 사용하냐고 항의불만', 81]
# ['트렁크 버튼파손', 122]
# ['주유카드 인식불가로 고객 자비결제', 95]
# ['이용전 배터리 방전 시동불가', 56]
# ['차량에서 석유냄새가 많이난다며인입', 109]
# ['긴급출동기사가 브레이크패드문제로 공업사에서 조치받아야한다고함', 44]
# ['경고등점등으로인입', 11]
# ['안산시 단원구 고잔동 월드코어 층', 57]
# ['어차피 잠깐 탈거라 운행지장 없으면 그냥타려고하는데', 11]
# ['고객님 배터리방전으로인한 시동불가인입', 56]
# ['고객 시동걸리지 않아 안입', 56]
# ['운행전에 이미 시동이 켜져있었고 경고등점등됐다고하심', 8]
# ['주행중 덜덜덜 거리는 소음', 106]
# ['차량 변경 시 대여요금 보험요금 주행요금은 동일하게 적용 혹은 이전 차량과 비교하여 더 저렴한 금액으로 조정해 드리며 하이패스 요금과 연장요금 및 사고 발생 시 사고비용 휴차료의 경우 변경된 차량 기준으로 부과', 31]
# ['현재차량 운행해서 이동하기로함', 31]
# ['확인 후 조치하겠다 안내', 96]
# ['차량사진 추가 등록요청', 70]
# ['정해 해진 반납위치가 아님 으로인한 반납불가인입', 25]
# ['운행전 경고등이 점등되어 인입', 16]
# ['차량 시트 높낮이 조절 불가', 58]
# ['메뚜기 우는소리같은 소음이 시동키면 바로발생', 106]
# ['노래를 재생해도 소리가 안들린다고함', 18]
# ['네비게이션 인터넷 연결불가', 21]
# ['타이어 공기압으로 현장조치는 했으나 타이어 펑크및 파스같다고하셨다고함현재 날씨 폭설로인해 확인불가하여 아침까지 공기압 점등이 되어있으면 공업사 가보라고 긴출기사님께 안내 받으셨다고함', 118]
# ['시동켜자마자 공기압경고등 확인', 118]
# ['통합경고등 점등되었다함', 16]
# ['카드가이상이있는건아닌지말씀 사진첨부', 115]
# ['타이어 주져 앉아서 문의', 118]
# ['바퀴쪽에서 긁히는소리 발생', 106]
# ['보조제동등점검 문구 발생 통합경고등', 31]
# ['제동등점등으로 대차요청', 31]
# ['차량 운행중인데 후우 타이어에 펑크나서 문의', 121]
# ['차량이용할려고했는데 보니까 타이어가 터져있음', 121]
# ['직접 본인이 결제하면서 통과 했다고 함', 124]
# ['반납존 돌아가는길로 반납후 점검 요청', 106]
# ['운행전 타이어공기압경고등 확인 외관상 문제 없음', 118]
# ['파일수', 112]
# ['대차 차량에도 타이어 공기압 경고등이 점등됐다고 하심', 118]
# ['차량 바닥 모래 타기 싫다며 코나올뉴 K 로 대차요구', 121]
# ['입', 16]
# ['후방카메라가 되지않아인입', 134]
# ['조수석 방향 제동등 이상', 31]
# ['워셔액 안나와서 문의', 89]
# ['타이어공기압경고등이 발생되었음 주행하는데는 문제가없는데 반납 후 점검요청', 118]
# ['TCS 재시작 상담사 시행', 16]
# ['타이어공기압 경고등 점등으로 인해 인입', 118]
# ['허 블락조정요청', 83]
# ['분실물 문제어 완료', 103]
# ['배터리방전 문의', 56]
# ['핸들열선', 130]
# ['타이어 조치 후 문의', 106]
# ['TCS오작동 티맵 실행준비중', 21]
# ['경고등 점등 사진전송 후 인입', 31]
# ['차량 비상등 방향지시등이 낟오지 않는다고하심', 31]
# ['후방카메라 사진찍어준다며 링크전송요청', 135]
# ['워셔액이 분출이 안됨', 81]
# ['제동등 점검필요 엑셀을 밟을 시 RPM이 심하게 올라감', 31]
# ['내비게이션 인터넷 연결실패 T맵실해중만 뜬다고함', 21]
# ['경고등 점등된 부분도 없다하심', 81]
# ['쏘카존 출차하려는데 후진시에 떨림이 너무 심하다고하심', 107]
# ['해당 차량 사이드 브레이크 조작시 뻑뻑해서 점검필요하다고 함', 51]
# ['고객 워셔액이 분사되지 않는다고 함', 81]
# ['타이어에서바림이 빠지는거같다며인입', 121]
# ['차량 트렁크 안에 뭔가 작고 찐득한게 뭍어있음', 112]
# ['여러번의 재부팅 시도에도 불구하고 티맵준비중이라는 문구만 나오며 실행되지 않음', 18]
# ['와이퍼 작동O 워셔액 분출불가', 81]
# ['와이파이 문제이며 문제어시에도 열리지않아 상담사가 열어줬다며 블루투스문제도 있는것 같다고 함', 25]
# ['내비게이션이 지속 꺼졌다 켜졌다 함', 18]
# ['브레이크 경고등점등으로 대차요청', 42]
# ['경고등점등 사진첨부', 11]
# ['고객님 네비게이션 소리안나오신다하심', 18]
# ['브레이크 풀었는데 브레이크등 점등이라고함', 11]
# ['주행중 소음으로 인해 인입 차량 정비 안하냐고 하심', 106]
# ['차량 방전된거 같다 문의', 56]
# ['내비게이션 SD 카드 오류', 21]
# ['전조등 경고등 앞 라이트 고장 문의', 31]
# ['주유캡이 없다고 유잆', 93]
# ['타이어 공기압 경고등 못박힘 확인', 118]
# ['이후 점검하겠다고 안내', 16]
# ['내비없다며인입', 22]
# ['정차중에도 RPM 오르락내리락함', 103]
# ['원존으로 반납 안내', 56]
# ['왼쪽 하향 전조등 점검 경고등 점등 및 왼쪽 라이트 점등 불가', 31]
# ['악취 문의', 22]
# ['주유후 게이지 반영이 안됨 인입', 12]
# ['주유하려고 하니깐 주유카드가 없다며 인입', 96]
# ['현장 조치 불가로 인입', 55]
# ['후방카메라나오지않는다고인입', 134]
# ['거치대 없어서 불편하다고 하심', 18]
# ['전조등 경고등 점등됨라이트 안나온다고함', 31]
# ['화면이 계속 꺼진다고 하심', 18]
# ['전조등 하향등 점검하라고 뜸 우측 하향등 안나옴', 31]
# ['주유카드 분실', 96]
# ['워셔액 안나온다고 함', 81]
# ['타이어 공기압경고등', 118]
# ['내비는 옵션 사항으로 보조 시스템임', 18]
# ['엔진경고등이 들어왔다고함', 11]
# ['퇴근길 막히는 도로에서 브레이크 뗐다 밟았다 할때마다 놀이기구 탄것만큼 덜덜 거려서 몸이 흔들릴 정도입니다 정비를 한번 해보셔야 할 것 같아요', 107]
# ['주유카드는 뽑았는데 부숴져있다고 주장 그래서 테이프로 임시로 하고 주유를 시도 해보았으나 안된다고함', 98]
# ['TCS재실행 상담사', 21]
# ['조수석쪽 사이드미러쪽에서 소리난다고함', 50]
# ['현장조치가 불가하여 연락을드렸음안내', 31]
# ['스티어링휠의 볼륨 조절 스위치가 고장', 132]
# ['내부사진못찍음 AUX선 이상하게되어있음 블루투스 버튼 빠져있음', 18]
# ['시트조절장치 파손', 58]
# ['차량 밧데리 방전으로 문의', 56]
# ['내비게이션 안됨 인터넷 확인할 수 없다함', 21]
# ['처음 이용떄부터 내부에 기름냄새가 났다고함', 11]
# ['주유카드없음과 카드기기 탈거 이전고객 미주유와 내부 쓰레기 방치로 항의', 96]
# ['고장견인으로 접수됨', 121]
# ['부재중 문자받고 인입', 83]
# ['오디오 소리 나오지 않음', 69]
# ['방전인거 같다고함', 56]
# ['내비게이션 TMAP 지연중', 18]
# ['처음 인입은 타이어공기압경고등', 11]
# ['차량 키아웃 으로 시동이 걸리지 않아', 57]
# ['차량 후진이 안된다며 인입 차량은 일단 롯데월드 지하주차장 층 A번 기둥에 주차했다고 함', 25]
# ['제동등 점등', 31]
# ['라이트 장애로 긴출접수요청', 31]
# ['주행중 핸들돌리면 소리랑 걸리는 느낌난다고 브레이크 밞을떄도 소리가난다고함', 106]
# ['내비게이션 전원이 켜졌다가 꺼졌다가 한다고 함', 18]
# ['운행 중 차량떨림 발생', 42]
# ['현재 차량 위치 서울 금천구 독산동 주공단지아파트 독산주공아파트 동 지상 주차장 확인', 25]
# ['운행전 원존에서 문열기 불가', 25]
# ['레벨업 쿠폰 사용하려는데 적용이 안됨', 18]
# ['시동이 걸리지 않아 인입', 56]
# ['반납차량 엔진오일 경고등 점등되어 인입', 18]
# ['워셔액통', 80]
# ['운전석 시트 레버 파손 문의', 58]
# ['스마트키를 인식할 수 없다며 시동이 안 걸린다고 하심', 57]
# ['조치 불가', 121]
# ['네비게이션이되지않음으로인입', 18]
# ['네비게이션 서비스 지연으로 인입', 18]
# ['차량 보조제동등 점등으로 인입', 7]
# ['하향등 점검 문구보고 인입', 31]
# ['고객 차량 운행 페달 부분에 플라스틱 커버가 없다고 문의', 23]
# ['경고등 사진 보내고 인입', 11]
# ['하이패스 결제가 안된다 하심', 124]
# ['통합경고등 전방추돌경고등', 16]
# ['타이어공기압경고등 떠서 인입', 118]
# ['내비가 지우는 중이라고 뜨면서 안된다고 함', 18]
# ['경고등 점등문의', 11]
# ['주간주행등점검경고등', 31]
# ['네비 소리 안나서 문의', 18]
# ['이전 문제어 이력확인 및 GPS신호는 정상확인되나 문제어 불가하여 장애블락 생성', 35]
# ['요소수 문의', 14]
# ['스패너 경고등 점등', 8]
# ['가온오토 업무 대행', 38]
# ['차량이 후진시에 떨림이 있고 타는 냄새가 남', 109]
# ['눈쌓이고 얼어 와이퍼 미작동', 73]
# ['에어컨에서 악취가 나온다고함', 67]
# ['타이어 이격 있다며 반납 후 정비 요청', 106]
# ['주행중 떨림', 107]
# ['카드가 거꾸로 되어 있다고 했다고 함', 125]
# ['문제어 가능하며 계기판 전원은 들어오나 시동불가', 54]
# ['전기차 반납하려 충전 연결 연결되지않아 반납도 안됨 기차시간떄문에 연결하고왔음 반납처리 안됨', 92]
# ['라이닝이 닳은것 같다며 차량 변경요청', 113]
# ['내비게이션 네트워크 미연결', 21]
# ['사이드브레이크 해제 했다고함', 106]
# ['전조등 경고등 들어왔다 문의', 31]
# ['타이어 경고등 점등되어 인입', 118]
# ['차량운행하려는데 경고등이 점등되어인입', 15]
# ['워셔액 미작동건 항의 인입', 81]
# ['내비 T맵 실행중 으로만 나오고 작동 안됌 문의', 18]
# ['네비 안되서 문의', 18]
# ['워셔액이 안나옴 경고등 없음', 81]
# ['이용전 배터리 방전', 56]
# ['운행하려고 하는데 시동 안걸려 인입', 56]
# ['비와서 와이퍼켰는데 떨어짐', 75]
# ['배터리방전 시동불가 인입', 56]
# ['주간주행등 점검등이 점등되어 인입', 31]
# ['강성거부 자동차 극장가서 오디오 틀어놓고 해야한느데 아예 안된다 항의', 18]
# ['내비게이션 화면 전환안됨', 21]
# ['담배냄새가많이나고 내비게이션 떨어져있어서 말씀해주신다함', 18]
# ['사과진행', 21]
# ['주행할 때 소음이 발생함 엔진 소음은 아닌데 어디서 계속 소음 발생함', 106]
# ['물리버튼 누르지 도 않았는데 오작동 한다고함', 70]
# ['정상운행 및 안전운행 안내수긍', 81]
# ['내비게이션 화면이 먹통임', 18]
# ['조수석 문제어 계패불가', 28]
# ['전조등안들어온다고함', 31]
# ['타이어 찢어짐', 121]
# ['파손 거치 빠짐', 22]
# ['타이어 육안으로 확인시 펑크로 확인됨', 121]
# ['차량 히터만 틀면 소음이 들림', 138]
# ['차량 단말기 탈선으로 인입', 24]
# ['단선되어 재연락드림', 22]
# ['점검 진행하겠다 안내 ', 118]
# ['한번더 재시작 해드림', 18]
# ['내비 오작동되어 인입', 21]
# ['차량에 문제있다고 지속 피드백했는데 왜조치안하고 본인에게 배정하냐 항의', 106]
# ['통화중 분실물 확인 습득 X', 22]
# ['주유카드 개', 96]
# ['이미 반납 함', 44]
# ['오디오 듣는 기능이 제대로 작동안함', 71]
# ['타이어 공기압 경고등 워셔액 안나옴', 118]
# ['사진 첨부 계기판', 118]
# ['내비게이션이 많이 덜렁 거리고 핸들이 빡빡하여 인입', 22]
# ['원존임', 11]
# ['블랙박스 좌측 루프쪽 외관손상으로 인한 블랙박스 탈거', 45]
# ['운행 전 차량 타이터 펑크 라고 함', 121]
# ['전조등 경고등 점등 문의', 31]
# ['주행하려고 하는데 브레이크 패달 떼면 쿵 소리 발생하여 문의', 44]
# ['담배냄새도 난다고 함', 108]
# ['가시동으로 조회되는데 시동 켜도 동일한지', 113]
# ['고객 운행중 차량 주유량 부족으로 운행 어렵다고 하심', 12]
# ['방향지시등경고등점등', 31]
# ['고객님 하이패스 이용문의', 30]
# ['내비게이션 오작동 시트 조절 손잡이 파손', 58]
# ['라이트경고등 점등으로 인입', 31]
# ['본인 카드로 결제를 했다고 함', 96]
# ['통화끊겨 오비', 118]
# ['내비가 네트워크 연결이 되어있지 않다고 뜬다 함', 18]
# ['어제 이용한 차량 내부 확인에 대해 물어볼게있음', 60]
# ['착불택배요청', 111]
# ['후방카메라가 안된다', 134]
# ['볼일 보고 다시 시동걸었을때 엔진 RPM이 혼자 올랐다가 내렸다가 반복해서 이상하다고 생각했는데 운행한지 분도 안되어서 길가에 멈춰섰음', 56]
# ['사진 요청 드림 고객님 사진 보내 드림', 31]
# ['타이어 공기압 경고등 점등되었다고 하심', 31]
# ['원존으로 차량 운행전이며 배터리 방전으로 긴출접수 되었으나 고객 취소요청', 56]
# ['방향지시등 장애', 31]
# ['내비 전원 불가 문의', 18]
# ['대차차량도 내부위생불량으로인입', 118]
# ['이전에 상담받았는데 본네트가 주행중 열림으로 확인되어 사진찍고 전화주셨다고함', 134]
# ['하이패스 구간 지나갈때 하이패스 단말기에서 카드가 없다고 나온다고하심', 124]
# ['긴출기사님께서도 소음이 많이발생한다고 올려주시겠다고 했다하심', 106]
# ['열 안전벨트 꼽는 부분 없음', 64]
# ['환경부 충전관련 센터에 연락해보았으나 충전기 문제아님 답변받았다하심', 90]
# ['시간 이상 주행했는데도 안녹고 문제있는 차량임', 81]
# ['하이패스인식되지않았다며문의', 123]
# ['워셔액이 안나와서 인입', 81]
# ['주행중 엑셀 밟아도 힘이 전달 되지 않아 갓길로 이동후 본네트에서 연기 발생', 11]
# ['운행에는 불편이 없으나 올리고 내리는 것 보조석 창문이 원래부터 망가져 있었 다고 하시며 확인 원하심', 113]
# ['TCS 재시작 조치 받은 후 정상작동 되는줄 알았으나 서비스가 지연되고 있어 잠시후 다시시도해주세요 팝업문구 나오며 오류발생', 21]
# ['에어컨 악취 문의', 67]
# ['문', 28]
# ['변경받은 차량 시동걸었는데 소음이 너무 심함', 106]
# ['워셔액 안나옴 담배냄새 트렁크 내 쓰레기', 81]
# ['통화중 TCS 재시작 다시 시도', 21]
# ['운전석 시트 조절 레버 파손', 58]
# ['블루투스 사용불가', 71]
# ['운행중 엔진체크경고등점등', 11]
# ['네비게이션 티맵실행중입니다 확인 후 안나옴', 21]
# ['해당건으로 대차불가한 것 안내', 18]
# ['소음도 심하다고 하심', 106]
# ['브레이크 밟을때 소음이 정말 너무크다고 항의', 44]
# ['공기압은 조치완료하였으나 후좌타이어 공기압 주입구 고장으로 점검필요하다고하심', 121]
# ['엔진경고등점등문의', 11]
# ['사이드미러 조작버튼', 49]
# ['차량 열쇠 제작', 111]
# ['워셔액 이용불가', 81]
# ['재시작 해드릴려고 했으나 어제도 번이나 했었다고 항의 불만', 21]
# ['소음이 너무 심하고 기름냄새가 심함', 106]
# ['시동안걸리며 배터리방전의심', 57]
# ['주유카드없다고함', 96]
# ['타이어 공기압 경고등 들어와있고 점검도 안하고 가지고 오냐고 항의 불만', 118]
# ['운행 중 전조등 작동시 계기판에 전조등 점검하라는 문구표출됨', 31]
# ['시동켜면 계기판전조등비상등 지동 깜빡임 배터리 수치 불안정', 56]
# ['운행 시작시점 차량내 블랙박스 화면에 메모리 카드를 확인해주세요 알림 뜸', 45]
# ['타이어공기압경고등 안없어짐', 118]
# ['에이필러 탈거 문의', 23]
# ['대기호 명 대표번호', 112]
# ['트렁크 경고등점등으로 인입', 122]
# ['후방카메라 고정불량', 135]
# ['전우 앞 타이어 물받이', 78]
# ['뒷 와이퍼 파손', 75]
# ['통합경고등말고 다른건 점등안된다하심', 16]
# ['와이퍼 고무탈거', 74]
# ['주행시 달그락 거리는 소리가 난다함', 106]
# ['전조등 경고등 확인되어 인입', 16]
# ['차간 거리 경보등 점등 ', 0]
# ['출차할려던도중 차량소음발생됨문의', 106]
# ['경고등 점등 여부 미점등이라 함', 55]
# ['차량문 열때마다 도난방지음 계속 울린다며 인입', 127]
# ['라이트 전조등 고장으로 차량 변경위해 인입', 31]
# ['계기판에 느낌표 충돌 공기압경고등 떳다고함', 16]
# ['차량 이용하러 왔다가 시동만 켰는데 타이어 공기압 경고등 발생 되었다며 인입', 118]
# ['후진기어해도 후방카메라 안나온다함', 134]
# ['대한 주차장에 주차는 완료 하심', 11]
# ['운전석 대시보드쪽 플라스틱', 23]
# ['네비게이션이 처음에 됬다가 이제 안됨', 18]
# ['내비 업데이트 오류로 점검 요청', 20]
# ['엔진체크경고등 점등 운행중 주유해야할지', 11]
# ['고객 운행중 타이어 공기압 경고등 점등되었다고함', 118]
# ['TCS 재시작 해달라며 인입', 18]
# ['블랙박스에 메모리 카드가 없다며 인입', 45]
# ['우측 앞문 열고 닫을때 소음이 있음', 29]
# ['타이어사진전송', 118]
# ['내비게이션안되신다며인입', 18]
# ['운전자 보조기능도 떴는데 갠찮은지', 15]
# ['지속방전 및 전압 낮음', 56]
# ['조기배차로 주차비 발생되어 문의', 2]
# ['와이파이 연결이 되지않아 인입', 21]
# ['시동라이트 OFF 주유카드 없음 이용할때부터 못봄', 96]
# ['TCS재시작 해드려도 안된다 함', 21]
# ['운전석 도어 소음 발생', 29]
# ['워셔액 안나옴 워셔액은 있음', 81]
# ['고객님께 연락요청 현장조치불가', 109]
# ['차량에 핸들이 이상하게 움직인다고하심', 110]
# ['안전벨트를 풀고 시속 KM로 운행 시에 경고음도 들리지 않음', 42]
# ['차량 인수 직후 타이어 공기압 경고등 확인', 118]
# ['시동이 걸리지 않는다고함', 56]
# ['배터리방전 문제어불가인입', 35]
# ['본인 병원 못가게되면 책임질꺼냐고 말씀', 11]
# ['경적 울리지 않음', 127]
# ['워셔액 얼어서 안나옴', 81]
# ['배터리 교체하러 왔는데 문제어 안된다고 하심', 56]
# ['차량 하향등 고장으로 인입', 31]
# ['전기차량이 소음이 왜이리 심하냐 불만', 106]
# ['워셔액 미분사 시야확보 불가', 81]
# ['문 잠궈져있고 열림해도 안열린다고 하심', 35]
# ['조수석 뒷좌석 문 안쪽에서안열림', 28]
# ['운전석 열선시트', 59]
# ['건', 112]
# ['트렁크쪽 누유', 76]
# ['화면은 켜진다함', 18]
# ['어제는 내비게이션이 들어오다 나가다 했는데 오늘은 전원이 전혀 들어오지 않았음', 18]
# ['주행 중 덜덜덜 너무 심하게 떨려서 다시 쏘카존 정위치 주차 후 인입', 107]
# ['배터리방전으로 확인', 56]
# ['시동은 걸리는데', 103]
# ['차량 시동 꺼짐 문제로 현장 조치 받았는데', 55]
# ['주행중 차량 떨림 문의', 107]
# ['와이퍼 휘어짐 워셔액 없음', 74]
# ['주유량도 였다고 불만 하소연', 70]
# ['반납전 내비 문제 제보', 18]
# ['이미 반납하러 가는길인데 뭔 차량변경이냐며 내비게이션 없는 차량 기준으로 요금 맞춰달라며 욕설고성반말 사용 항의', 18]
# ['하이패스 단말기 미인식', 125]
# ['경로변경 내비 네트워크 연결이안되고', 21]
# ['처음에는 차량 네비게이션이 화면 멈춤으로 인해 문의 예약 연장을 하려고 했느나 네트워크에 연결ㄷ되어 있지 않습니다 라고 뜨고 있어 문의', 18]
# ['취소처리완료', 56]
# ['네비게이션이 계속 꺼졌다 켜졌다 한다고하심', 18]
# ['제동등왼쪽이 들어오지 않는것같다고 함', 16]
# ['차량이용시 라이트 경고등 점등되엇다 하심', 31]
# ['사진첨부 어제 사진못찍음 내부 창문이 이렇게되어있음 밖에서는 잘안보여 확인못함 운전석뒷자리 내부 유리', 112]
# ['T맵 실행준비중으로 나오고 작동 안된다고 하심', 21]
# ['해당 차량 대차 안내', 31]
# ['브레이크를 밟으면 끼익 거리는 소리가 남', 44]
# ['차량 엔진을 켜보니 주행가능 거리 KM 나옴', 12]
# ['수동모드에서는 점등', 31]
# ['SD카드가 없다라고 나옴', 18]
# ['어두운 곳에 가면 가시거리 안나올 수 있다고 주장', 31]
# ['네비게이션은 재시작 후 작동되는데 후방카메라 작동 안된다고 하심', 134]
# ['TCS 재시작요청', 21]
# ['A필러 파손되어 있음', 23]
# ['블랙박스 메모리카드 확인해달라는 멘트 나타남', 45]
# ['외부인', 63]
# ['하향 전조등 점검 경도등 뜸', 31]
# ['방향 지시등 미점등', 31]
# ['재시작하셨는데도 동일하신지맞음', 18]
# ['문안열림으로 문제어 요청 문의', 25]
# ['수긍 근데 인근에 차량이 없어서 우선은 이용하고 반납후 점검요청', 35]
# ['대차 차량 안내', 15]
# ['차량 담배냄새도 심하고 쓰레기도 있고 물도 있음', 96]
# ['네비게이션 안됨', 18]
# ['내비게이션도 화면이 아예안나옴', 31]
# ['보조석 안전벨트 고장으로 대차 요청', 64]
# ['차량문제 제보 인입', 74]
# ['기존 차량 주행 할때 페어링 문제있다고 함', 106]
# ['인근존에 주차하고 인입되어 반납처리 안내', 110]
# ['TCS 재시작하였지만 동일 문제로 실행안됨', 21]
# ['대차 원하심', 32]
# ['문 잠금 진행', 22]
# ['차량 시동을 껏다 켰는데도 네비게이션 안됨', 18]
# ['배터리 방전으로 시동 걸리지 않는다고 함', 56]
# ['와이파이와 네비게이션 안됨', 21]
# ['이상 주행 시 차량떨림 심함', 107]
# ['내비 오작동 재인입', 18]
# ['후방카메라 안된다며인입', 134]
# ['엔진체크경고등점등으로인입', 11]
# ['경고등 사진 전송 후 인입', 8]
# ['블루투수 연결 문의', 70]
# ['오디오 소리 안나와서 인입', 71]
# ['이전 상담했고 폰이꺼져서 로 재인입 사진보낼테니 링크 다시 보내달라', 51]
# ['전방충돌방지시스템 점검 경고등 점등되어서 인입', 15]
# ['제동등 점검 경고등 점등 타이어 공기압 함께', 31]
# ['시거잭고장', 53]
# ['워셔액 부족하다는 음성 나온다고함', 89]
# ['우측 방향지시등을 키면 계속 경고음 발생', 15]
# ['타이어 가라앉아있음', 121]
# ['인근쏘카존으로 견인해야해서 현위치', 57]
# ['일단 운행은 하신다고 하심', 81]
# ['엑셀이 밟고 반박자 늦는 느낌입니다', 107]
# ['분실물 종류', 16]
# ['라이트 전조등 경고등 점등', 31]
# ['내비게이션이 안된다고 그냥 반납하겠다고 인입', 18]
# ['라이트결함경고등 및 통합경고등 점등', 31]
# ['후미등 파손', 32]
# ['운행 중 소음', 106]
# ['견인기사 인입', 25]
# ['차량 운행중 경적과 비상등이 깜빡인다고 함', 116]
# ['빨리 공항으로 이동해야한다함', 44]
# ['시동불가로 문의', 57]
# ['지방을 내려가야하는 관계로 눈 등 예보가 있어 워셔액이 나와야함', 81]
# ['내비게이션 작동안함', 21]
# ['고객 위치', 44]
# ['하이패스 구간 통행시 카드가 꽂혀있지 않다는 안내가 지속 나옴', 123]
# ['시일 소요되는거 알겠으니 상급자와 통화하고 싶다고 함', 55]
# ['주행중 소음 후진할때 나지않음', 106]
# ['조절은 된다하심', 70]
# ['배터리방전이라고인입', 56]
# ['업데이트해야한다고 업데이트이후 또 업데이트시작 무한반복이라고함', 20]
# ['고객 오디오 버튼이 없고 차량내 쓰레기가 있다고 함', 70]
# ['문제어 해드림', 11]
# ['어제 문의 하였으나 다시 주간 주행등 점검 경고등 점등', 31]
# ['차량 언더커버', 78]
# ['차량 시동 갑자기 꺼짐과 함께 배터리 방전됨 차량 멈춰 인입', 31]
# ['라이트가 안들어오는것은 아니나 운행어렵다 하시며 상향등을 켜야 하는 상황이라고 하심', 31]
# ['라이트 경고등 있다고 함', 31]
# ['재결제 시 오류 메세지 확인됨', 95]
# ['문자링크통해 사진촬영 안내수긍', 22]
# ['주행중 잠시 멈추면 내비가 꺼진다고 함', 2]
# ['문열림 통화중 이동주차 완료 여부 O 문잠금 시동라이트 OFF 확인 O 주유카드 여부 O', 36]
# ['현재 운행 중 모닝 브레이크 점검 필요해보임 저번 급정거 시 소리 및 브레이크 잘 안됨', 42]
# ['타이어 공기압 낮음 경고등', 118]
# ['공기압경고등으로조치 받았는데 계속 똑같은게 뜸', 118]
# ['내비 화면오작동문의', 18]
# ['고객 엑셀을 밟으면 급발진이 되는게 불안하다고 인입', 103]
# ['보조석 운전석쪽 문이 뻑뻑함', 22]
# ['운행 전 타이어공기압경고등 점등으로 인입', 118]
# ['조수석 안전벨트 스프링 고장 인입', 64]
# ['내비게이션이 안 켜진다며 인입', 18]
# ['시동 걸자 마자 그랬음', 16]
# ['내비게이션이 중간에 끊기며 주행중 위험할것같고 카메라 모양에 금지마크가 떠있어 차량변경요청', 21]
# ['등받이 조절 고장', 58]
# ['네비 문제로 통화중 재시작 해드렸으나 단선되어 오비했는데 고객 통화중 재인입된듯', 18]
# ['와이파이 연결불가', 21]
# ['지연된 시간 연장 안내', 118]
# ['충전카드가 없어서 충전불가 상태 인입', 117]
# ['워셔액 보충후 다시 안나온다고 인입', 80]
# ['주차후 시동키니 경고등점등되어인입', 11]
# ['타이어 조치완료 됐으나 후방충돌감지경고등은 따로 조치 어렵다고 하심', 15]
# ['타이어 펑크 문의', 121]
# ['TCS재실행 꺼지지 않음', 21]
# ['장거리 운행하는데 발이 너무 시렵다고 함 보상요청', 137]
# ['네비가 SD카드가 없다고 뜸', 18]
# ['엔진체크 경고등점등 문의', 11]
# ['충전카드 칩 오류로 충전불가 인입', 115]
# ['경고등 없음', 31]
# ['차량 장애 확인을 위해 예약해서 차량에 왔으나 장애가 그대로 있음', 25]
# ['블랙박스에 메모리카드확인해달라는 문구가뜸', 45]
# ['주행중 제동등 점검하라고 떠서 문의', 7]
# ['차량위치 확인불가해서 OB', 100]
# ['번호판 떨어짐으로 인입', 39]
# ['반납한 차량 후우 창문 썬팅 벗겨 있다함', 112]
# ['브레이크 밞아도 급발진하려고한다고함', 42]
# ['워셔액이 안나온다고 하심', 81]
# ['내비게이션 오작동으로 인입', 18]
# ['내비게이션 재시작 받았지만 여전히 인터넷 연결 불가하여 연락드림', 21]
# ['출발전 블루투스연결하려는데 미디어 버튼누르면 바로 네비게이션화면이 뜨면서 블루투스활성화안됨', 71]
# ['배터리 방전되서 시동 안 걸리는거 같다고하심', 56]
# ['내비 간헐적으로 재시작됨', 118]
# ['차량내 경고등 점등되어 문의', 11]
# ['주유카드 없음 옥스트라에는 있음으로 나옴', 96]
# ['문제어불가로인입', 56]
# ['블루투스 연결 및 소리나는법 문의', 71]
# ['워셔액이없는건지문의', 81]
# ['내비 지속 꺼짐으로인입', 18]
# ['분사구', 81]
# ['차량 받았는데 네비게이션이 파손되어있음', 22]
# ['CS재시작해도 불가', 25]
# ['연결 끊김 점등', 0]
# ['기사님 오셨으나 차량 상세 점검이 필요하다며 공업사 입고해보아야한다고 말씀하심으로 문의', 107]
# ['글로브 박스나 차량안 없을지없다함', 96]
# ['주유카드오류로 결제불가안내', 95]
# ['내비가 안된다고 하심', 18]
# ['타이어 운전석앞바퀴 뽈록하게 튀어나옴', 120]
# ['어제 이용한 코나 차량에 엔진 경고등이 들어와서 제보', 11]
# ['백미러 오작동', 49]
# ['네비게이션 사용자 인증정보 오류 인입', 18]
# ['차량 전원만 들어오고 시동은 안걸린다고 함', 56]
# ['타이어 공기압 경고등 점등 현재 반납하기 위해 반납존 도착하니 점등되었고 주차완료 함', 118]
# ['주유카드가 없어 인입', 96]
# ['USB 포트 고장났다고함 충전 불가', 2]
# ['제동등 경고등 점등으로 네번째 전화 확인 후 연락 준다고 하고 아직 연락 없음', 16]
# ['일단알겠다며 대차존 이동하신다고함', 57]
# ['공기압 통합 경고등 점등', 16]
# ['운전석 뒷좌석 발판매트 분실', 37]
# ['세게밟을 수록 소리는 더 크게 발생', 44]
# ['하이패스 미부착차량', 123]
# ['운전석 앞쪽 타이어', 118]
# ['의자 고정은 되는데 소리가 계속 난다고 하심', 60]
# ['엔진체크 경고등 점등으로 반납하려는데 부분환불요청', 11]
# ['브레이크', 44]
# ['내비 부착 안되어있음 확인후 조치필요 ', 22]
# ['내비게이션 받침대가 뿌러져있다며인입', 18]
# ['워셔액 자꾸 얼어서 문의 인입', 81]
# ['버튼 하나 없음 제보', 23]
# ['TCS 재시작 상담사 시행 동일증상 발생시', 21]
# ['차량 타이어펑크난거 같다고 하심', 118]
# ['블루투스 라디오가 연결이 되지않아 문의주심', 71]
# ['내비게이션 이용 불가 서비스가 지연되고 있다는 메세지에서 넘어가지 않음', 21]
# ['차량 내부상태불량', 67]
# ['조수석 보관함 뒷편과 발놓는 곳 사이 그 위편 오른쪽에 구멍이 뚫렸다고 함', 111]
# ['블랙박스 탈거로인한 장애블락 생성 ', 45]
# ['공업사 가봐야 한다는데 어떻게 하는지', 106]
# ['차량 후방카메라가 안나옴', 134]
# ['운전석 범퍼 아래 가이드 고무', 78]
# ['단말기 GPS 위치 오류로 블락 생성', 25]
# ['고객 차량 이용시 기어변속부분에서 문제 발생으로 인입', 104]
# ['통합경고등뜸', 16]
# ['내부 동물털 항의', 85]
# ['경고등은 모르겠고 육안확인 가능하다고 사진보내줌', 121]
# ['차량 내부 충전카드 미비치됨 및 충전구 뚜껑 파손됨', 90]
# ['운행중 차량 방전이라고 인입', 56]
# ['전우 타이어 파스후좌 타이어 못박힘', 121]
# ['배터리방전 인근차량변경', 56]
# ['네비게이션이 켜지지않는다며 인입', 18]
# ['타이어에 못 박혀 있었음', 106]
# ['단말기 신호 불량 문제어불가', 56]
# ['후측방 충돌 경고시스템', 15]
# ['본넷소음', 40]
# ['파손사진 업로드 해준다심', 26]
# ['연결은 되었는데 노래가 나오지 않는다고 함', 71]
# ['인ㄱ근 쏘카존 이동 후 대차', 118]
# ['선바이저 거울파손', 52]
# ['정위치 인지 맞음', 92]
# ['내비게이션이 이용 중 초기화가 됨 네번째 전화하는것 차량 변경 요청', 18]
# ['워셔액이 없는 줄 알고 사서 넣어봤는데도 워셔액이 안나오고 앞이 안보여서 운행 불가능 할거 같다고 하심', 81]
# ['카오디오도 잘안된다고하심', 22]
# ['주유카드 분실 고객 자비결제 후 환불접수예정', 96]
# ['마스터키 작동불가', 36]
# ['문닫히지않아서 인입', 28]
# ['분실물 폐기', 111]
# ['핸들 조작 시 소음 발생', 129]
# ['트렁크 손잡이에 손을 넣고 안쪽을 누르며 트렁크를 연건지맞다고함', 122]
# ['운행중 차량 동일차량으로 저녁에 예약 했으나 반납절차 없이 이용가능 문의', 67]
# ['센터페시아 하단 보관함 쪽 내장제 단자파손', 23]
# ['타이어공기압점등', 118]
# ['차량 네비게이션 고장으로 인해 인입', 21]
# ['차량 전조등 하향등 점검 메세지', 31]
# ['단말기 신호이상', 25]
# ['차량을 이용하러왔는데 타이어 공기압 경고등으로 인입', 118]
# ['문잠금 안되고 스마트키 작동안됌 수기 반납요청', 35]
# ['운전석 뒤 타이어 못이 박혀있고 부름지에서 차량 받았을때부터 계기판에 타이어 공기압 경고등 점등으로 고객 직접 공업사 가서 확인하였으나 운전석 뒤 타이어 못 박힘으로 현장조치 불가 안내받았다고 문의', 121]
# ['네비게이션에 업데이트 관련 멘트가 뜬다고 하심', 20]
# ['브레이크 소음 발생 경고등이 많이 떴다며 인입', 15]
# ['차량에 주유카드없다함', 96]
# ['분실물 회수 및 착불요청', 111]
# ['문제어 불가 문의', 56]
# ['경고등사진첨부', 31]
# ['와이퍼 소리남', 74]
# ['와이퍼 파손', 75]
# ['오비', 121]
# ['네비게이현 T맵실행중 이후 화면 변화없음', 18]
# ['반납하신 차량 내부에서 담배냄새 난다고 하심', 49]
# ['라이트 경고등 점등 외관상 확인 안됨', 31]
# ['전기차 충전 카드가 안된다고 함', 91]
# ['핸들러분도 겨우겨우 파킹으로 놨다고 함', 104]
# ['타이어펑크 어디쪽인지 확인요청 오른쪽 앞타이어', 121]
# ['제가 최근 이용했던 차량에 브레이크액셀이 조작시 조금 덜컹거리는 소리가 남', 106]
# ['운전석 안개등 고장', 31]
# ['내비게이션은 편의품목이라서 차량 변경이 어렵다고 안내', 21]
# ['계기판 경고등 민 분실물 습득 인입', 16]
# ['경고등사진 확인 요청', 31]
# ['TCS재시작상담사 전원 꺼지지 않음', 18]
# ['차량 바로 변경진행안내', 57]
# ['조수석 라이트가 들어오지 않음', 31]
# ['경기 고양시 일산동구 장항동 우림로데오스위트 지하 층', 94]
# ['내비게이션 업데이트 문제로 인입', 18]
# ['워셔액이 부족하지는않으나 워셔액 노즐이 동결된것으로 추정됨', 81]
# ['고객님 현재 반납 중으로 확인 됨', 135]
# ['TCS 오작동 재시작 요청 실행준비중', 18]
# ['운전석 하향등 점검', 31]
# ['블랙박스 메모리카드 인식불가 문구가 보인다고 함', 45]
# ['운행중 연결중입니다 메세지 출현후 미작동', 21]
# ['조치 완료', 80]
# ['왼쪽 상향등이 조금 약하게 들어오긴하나 전체적으로 전부 점등된다고함 ', 31]
# ['후미등은 들어 오고 그 옆 차폭등이 안 들어 오는거 같다고 하심', 31]
# ['라이트 장애 및 통합경고등 점등문의', 16]
# ['전기차 충전후 반납하려고하는데 충전카드가 보이지 않는다고 문의', 117]
# ['이용전 배터리 방전으로 시동불가 하다고 유입', 56]
# ['블루투스가 안됨', 71]
# ['사진첨부 와이파이도 안됨', 21]
# ['해당 연결 부위가 애초에 손상이 있었다고 함', 93]
# ['원 쏘카존에서 출차 시 지속 주차비 발생되어 전달해달라 하심', 31]
# ['내비게이션 정상 작동하지 않음', 18]
# ['스마트키 인식 안됨', 25]
# ['하이패스인식 불가', 123]
# ['확인처리', 118]
# ['실내부품 장애', 69]
# ['내비게이션 안됨', 18]
# ['내비게이션이 갑자기 작동이 안되서 연락드림 자꾸 인터넷 연결이 안된다함', 21]
# ['뒤쪽에 블랙박스가 떨어졌다고 함', 135]
# ['배터리 방전 관련하여 예약취소', 56]
# ['보조석 뒷 문계패 안에서 밖으로가안됨', 30]
# ['핸드폰과 차량 블루투스 연결을 위해 차량 오디오에있는 PHONE을 눌러도 화면이 넘어가지도 않고 활성화도안됌 심지어 핸드폰 블루투스에 차량넘버 확인도 안되고 있음', 71]
# ['내비게이션 실행 준비중입니다 하고 화면 안넘어가서 인입', 20]
# ['오디오 기능', 71]
# ['차량 충전 카드에 충전 비용이 정', 115]
# ['주간주행등점검하라는 경고등이 나옴', 16]
# ['대차 차량존 도착', 45]
# ['이전 상담시 가능하다고 해서 블루투스 오작동으로 인한 대차 요청', 71]
# ['시동 안걸린다며 인입', 56]
# ['분실물 회수 및 착불 요청', 111]
# ['O', 118]
# ['모니터링항목', 112]
# ['내비게이션이 라디오 화면으로 계속 바뀐다고 함', 18]
# ['전조등 경고등 확인', 31]
# ['고객도착시 충전중이였으며 분리불가라고인입', 90]
# ['차량 이용하려 하시는데 계기판에 경고등이 점등되었다고 하심', 31]
# ['반납했는데 문열려 있다고잠금 요청', 44]
# ['통화종료', 11]
# ['분실물 놓고내린 휴대폰 충전기랑 케이블 찾을 수 있을지 문의', 118]
# ['차량이용할려하는데 시동이안걸림', 56]
# ['타이어 공기압 경고등 방향지시등 경고등 점등 되어 차량 관리 여부', 118]
# ['현재 계신 위치 문의', 16]
# ['RPM이 이상한것같음', 103]
# ['차량이 왼쪽으로 쏠리는 느낌도 든다고 함', 108]
# ['주유카드 분실로 문자받고 인입', 96]
# ['내비에서소리가안나온다고하심', 18]
# ['운행전 보조석 뒷 라이트 깨짐 발견', 32]
# ['경고등 따로 없으신지 없음', 133]
# ['좌측으로 쏠림으로 인입', 108]
# ['내비게이션이 안켜짐으로 문의', 18]
# ['차량 운행중 브레이크 밟으면 끽소리가 난다고 함', 44]
# ['지금 차량에 히터가 잘 안나와서 교환가능할지', 137]
# ['평평한 도로에서 차가 왼쪽으로 기우는것같았다함', 108]
# ['원존 운행전 시동 불가 배터리방전', 56]
# ['이 차 핸들 왼쪽 음량 버튼이 안됨', 70]
# ['외부경관등 결함 경고등 점등 및 좌측 앞 라이트 꺼짐', 31]
# ['블랙박스 메모리 관련 작동 안됨', 45]
# ['고객 차량 운행중 공기압 경고등 점등으로 인입', 121]
# ['주행소음이난다며인입', 106]
# ['타이어 공기압 현장조치 하나 일주일에 한번꼴로 동일 문제 발생되어 정비 한번 받아봐야될거같다함고객께 직접 오비드림 현장 조치 부탁', 118]
# ['담배 냄새 및 키아웃 경고등 점등되어 인입', 57]
# ['후방카메라 장애', 134]
# ['창문 닦으려하니 워셔액이 없다함', 81]
# ['주행중 덜덜 소리난다함 소리발생 위치 확인 불가', 106]
# ['운행중 타이어 공기압 경고등 점등되어 인입', 121]
# ['차량 시동불가로 취소요청', 56]
# ['차량 긴출기사 확인시 운행 불가로 긴출 기사 핸드폰으로 상담하였으나 이전 상담원이 고객 핸드폰 직접 다시 전화 하라했다며 강성 항의', 108]
# ['네비게이션 연결 안됨 및 사용 불가', 21]
# ['주유카드도 없고 브레이크가 안먹힌다고함', 43]
# ['내비게이션 먹통 재시작부탁', 18]
# ['처음탑승했을때도 전조등 되지않았고 워셔액도 나오지않아서 주유소에서 고침', 81]
# ['운행하려고 방금 탑승했는데 주유량이 퍼센트로 부족해서 인입', 12]
# ['조수석 안전벨트 고장', 64]
# ['하이패스 지나갈시 미인식된다고함', 123]
# ['차량변경시 대여료보험료주행요금 동일 하거나 이전 차량과 비교하여 저렴하게 적용됨안내', 35]
# ['운행전 타이어 공기압 경고등이 점등되어 인입', 118]
# ['대차존옴 대차요청', 18]
# ['전방충돌감지 센서 작동 안함', 0]
# ['대차 불가 안내', 18]
# ['아직 출차전', 18]
# ['조수석 후미등 운전석 전조등 미점등', 31]
# ['네비게이션 고장으로 인입', 18]
# ['운전석 앞바퀴', 118]
# ['T맵 실행 준비중입니다 잠시후 자동으로 T맵이 실행됩니다', 21]
# ['라이트 경고등 있다고 유입', 31]
# ['고속 주행을 뛰고 나면 배터리 자체에 문제 있어보임', 6]
# ['차량 문제어가 되지않아 인입', 56]
# ['뒷좌석 양쪽 도어가 개폐 버튼은 열렸다 잠겼다 되는데 안에서 열었을때 안열린다고 하심', 28]
# ['좌우측 깜박이 점등되지 않음', 31]
# ['문이 안열림 시부터 예약이고 촬영 제출했음', 35]
# ['LOGO', 112]
# ['통합경고등 나왔다며 인입', 16]
# ['실내등이 안꺼져서 인입', 61]
# ['브레이크 급제동', 42]
# ['엔진체크 경고등 점등돼서 문의', 11]
# ['후방카메라 고장으로 반납요청으로 인입', 134]
# ['전원이 자꾸 꺼짐', 18]
# ['단말기 재시작 이후 재확인 OB', 35]
# ['브레이크 등 경고등 떠서 인입', 7]
# ['뜨거운 물부어서 녹여 보았는데도 다시 안된다고 함', 81]
# ['하부 소음 및 쇼바 브레이크 소음 으로인한 참고 요청후 무응답', 44]
# ['전조등 이상', 31]
# ['운행전 사진 다른 차량으로 등록 진행', 18]
# ['차량엔진체크경고등 아침부터 점등되어서 운행하다가 인입', 11]
# ['주행 중 시동이 번 꺼졌었고 타는 냄새도 났었다고 하심', 55]
# ['계기판 유리 깨짐', 23]
# ['얼어서 안열리고 있음', 31]
# ['상급자 통화요청', 55]
# ['차량 배터리 충전 필요 긴출 접수 요청', 56]
# ['키아웃으로 인입', 57]
# ['고객외 손말이음센터', 57]
# ['운행 중 사용자 정보 변경되었다 나오며 지속 내비게이션 전원 꺼짐', 21]
# ['전기차 충전카드 쓰려고하는데 입력하신 카드가등록이 안되어있다고 카드가 안된다고하심', 115]
# ['기사가 현장에 이동해도 조치는 어려운 사항임 그럼 현위치 반납하고 남은금액 크레딧으로 주던가 환불 해달라고 함', 13]
# ['내비 이용안됨', 18]
# ['경고등 따로 없음', 31]
# ['내비가 자꾸 다른곳 안내 한다고 항의', 18]
# ['내비게이션 거치대 탈거', 22]
# ['워셔액 모터 고장으로 대차 요청', 81]
# ['제주도 전기차 충전기 태깅시', 115]
# ['내비 안켜짐', 18]
# ['사진은 없음', 44]
# ['현재 주유소 와서 주유구 여는 버튼 눌러서 열긴했는데 안에 돌려서 여는게 안열림 힘으로라도 열려고 했는데 부서질거같고 연료량 인데 이대로 반납처리 가능할지 문의', 94]
# ['지금 몇번째인지모르겠음', 134]
# ['제동등 경고등 점등으로 장애 블락 생성', 31]
# ['해당차량 이후 예약 고객이 없으니 차량 정위치 해주시면 이후조치 하겠음', 138]
# ['주행중에 내비가꺼져서 몇번이고 도로이탈하였다하심 불편하다하심', 18]
# ['고객 후방 블랙박스가 파손되어있다며인입', 45]
# ['차량 운행하러왔는데 차량에 전조등이 안나와서 문의', 31]
# ['원존에 차량이 없어 택시타고 이동 하시라고 함', 49]
# ['전기차 충전카드 분실', 117]
# ['호', 35]
# ['글로브박스에 내비게이션 없으신지', 19]
# ['반납하시면 점검 하겠음', 35]
# ['라이트경고등 점등 우측전방', 31]
# ['근데 주행 쏠림으로 차량 자체 확인 긴출 안내', 108]
# ['양지주차장관리인', 36]
# ['차량 뒷자석에 토를 했는데 늦은시간이라서 내부세차 할곳이 없다고 반납하고 쏘카에서 해주면 얼마인지 문의', 83]
# ['쏘카존만차문의', 11]
# ['차량 충전후 단말기 상태 확인 필요로 장애 블락 생성', 25]
# ['안녕하세요 쏘카입니다', 57]
# ['차량변경 안내 코나차량으로 변경', 69]
# ['워셔액 없음 문의', 89]
# ['쎄게 닫아도 안된다심', 40]
# ['이전고객님 주차 동일쏘카존에 했다고 주장함안내', 100]
# ['경거등확인 ', 15]
# ['차량안에 타는냄새가 심하다고 인입', 109]
# ['차량반납 주차라인 자리없어 라인 바로 뒤 주차진행 괜찮은지 확인해달라함', 96]
# ['차고장난것 같음 점검이 필요한 차량같은데 취소해달라하심', 56]
# ['정면 유리창 미흡 한 흠집', 77]
# ['초기화면에서 네비게이션 안내화면으로 전환되지 않음', 18]
# ['눈발이 날려 운행중 워셔액으로 유리창을 닦아야하는데 위험해서 천천히 주행을 하고 있다고 함', 81]
# ['후진시 내비게이션 내 후방카메라 확인되지 않음', 134]
# ['조수석 워셔액은 나오는대 운전석 워셔액만 나오지않아 인입', 81]
# ['내비게이션 전원불가로인입', 18]
# ['디스플레이부분 전원들어오지않음', 18]
# ['검색하면 초기화면으로 돌아감', 21]
# ['차량 변경시점 중간 결제', 81]
# ['주정차시에 내비 꺼짐', 18]
# ['차량 안에 분실물 없다고 하심', 11]
# ['브레이크 패달 부근에 와이어가 노출되어 브레이크 조작시 발에 걸림 뒷유리 와이퍼 블레이드가 찢어져 닦이지 않음', 74]
# ['블루투스 오작동 PHONE 버튼 작동 불가', 71]
# ['타인의 분실물이 있는지 확인요청', 21]
# ['블루투스 오작동', 71]
# ['운전석쪽 USB 포트', 2]
# ['지속 접수 되었음에도 조치되지 않은걸로 확인됩니다 확인 후 꼭 수리 부탁드립니다', 23]
# ['브레이크를 밟을 시에 드르륵 소리가 들림', 44]
# ['반납안되어 인입', 56]
# ['내비가 안된다고 인입', 21]
# ['충전카드 없음', 117]
# ['USB포트에 충전불가', 2]
# ['장착물 장애', 1]
# ['조수석 쪽 전조등 나갔다고함', 31]
# ['이전에 오디오 버튼 안눌리는거 저번에 점검해달라 요청했는데 안고쳐져있다며 문의', 70]
# ['배터리 방전 인입', 56]
# ['내비게이션 장애', 18]
# ['네비게이션 실행중 상태에서 작동안됨', 18]
# ['내비게이션 실행 오류', 18]
# ['와이퍼 중간에 계속 멈춤', 73]
# ['나오지않음', 21]
# ['시동 지속 안걸린다고 하심', 56]
# ['고객외고객외', 31]
# ['운전석 의자조절 레버 파손', 58]
# ['사이드미러 조작 버튼 작동불가', 49]
# ['사진첨부 반납했음 타이어 공기압 보충 필요함', 118]
# ['운전석 라이트안들어옴', 31]
# ['사진보낸 후 인입', 11]
# ['운전석 고장 보조석 이상없음', 59]
# ['급발진 또는 급후진 현상도있음', 107]
# ['긴출 기사 도착 현장 확인 해보니 엔진룸에 고양이가 들어가서 뭔가를 건드려서 고장난것으로 파악됨 고양이 현재 꺼낼수 없고 주행 불가함 해당 차량 견인해야함', 11]
# ['이전 이용 시 네비게이션 음성이 출력되지 않았다고 제보 ', 18]
# ['오른쪽 앞 바퀴에 문제가 있는지 덜컹거림', 107]
# ['변경된 번호임 쏘카 가입한적 없음', 104]
# ['시트 높낮이 조절 레버 파손', 58]
# ['엔진 문제 경고등 점등되어 인입', 11]
# ['고객 차량 빌리고 운행은 안했는데 라이트도 안꺼지고 노랑색으로 경고등 떠서 인입', 121]
# ['오른쪽은 움직인다고함', 49]
# ['배터리 방전된거 같아서 시동 안걸린다고 인입', 56]
# ['워셔액부족', 81]
# ['차량위치 확인 불가', 100]
# ['엔진체크경고등으로 인입', 11]
# ['주간주행등 경고등이 점등되어 인입', 16]
# ['TCS오작동 네트워크 연결오류', 21]
# ['와이퍼 고장문의', 81]
# ['블루투스 연결방법 문의', 71]
# ['타이어 펑크로 인해 차량 대차받으셔야 한다하심', 118]
# ['핸들 소음', 129]
# ['언더커버 고정 또는 교환 요청', 78]
# ['해당없음', 56]
# ['경고등 점등 제보', 15]
# ['충전카드 없음차량내부에서 확인불가 ', 117]
# ['차량 반납했음 오른쪽 뒷 타이어 공기압 낮다고 계속 뜸 그래서 차량 중심 잘 안잡히는것같다함', 118]
# ['지금 운행했더니 아예 주저 앉았다고함', 121]
# ['주행소음으로 주차후 연락 안내받음', 106]
# ['오디오볼륭버튼 파손', 70]
# ['내부에 오바이트 및 쓰레기 발견', 83]
# ['그럼 내부 파손은 안된다고 말씀하시는것인지 항의', 23]
# ['A필러 덜컹거림', 23]
# ['사이드브레이크 해제했는데 지속 경고등 점등 ABS 경고등도 점등 공기압 경고등도 점등 주행 중에도 속도계', 3]
# ['부품이 떨어져서 굴러다닌다심', 58]
# ['차량 코너시 미끄러져서 확인해보니 타이어 홈이 닳아있음', 119]
# ['사진전송안됨 내부위생불량 모래 쓰레기 음식물 많음', 64]
# ['타이어 공기압 전조등으로 긴출 접수건', 31]
# ['네비문제', 18]
# ['차량 내 주유카드 없음', 96]
# ['내비게이션 작동 불가 문의', 18]
# ['내비가 아예없음', 19]
# ['경고등', 11]
# ['키아웃으로 견인하려 했으나 전자파킹브레이크가 풀리지 않아 견인 불가', 57]
# ['운전석 주간 전조등 고장', 31]
# ['반납 이후로 사진 요청 불가', 21]
# ['운행중 네비게이션이 자꾸 오류를 일으켜 이십분에 한 번 꼴로 운행중 난처한 상황이 발생 사진첨부', 18]
# ['후방카메라 안나와서 없는 차량인지 문의', 134]
# ['후좌타이어 공기압 이상', 118]
# ['하향등안나온다고인입', 31]
# ['고객 블랙박스 탈거 됬다고 하심', 45]
# ['운행중 계기판에 경고등이점등되어 인입', 31]
# ['화면 넘어가지않고 초기화면 정지상태', 18]
# ['타이어공기압으로 현장조치받았으나 동일하게 계기판에 점등됨', 118]
# ['오디오 볼륭버튼', 69]
# ['내외부 세차는 완료했으나 이전 사용자가 트렁크에 토를해서 시트에서 냄새는 안 사라진다고 하심', 87]
# ['고객이 오른쪽 뒤에 후미등이 약하게 나온다고 함', 31]
# ['얼라이먼트 장애로 대차 인입', 108]
# ['아직 기름은 많은데 카드가 없길래 혹시나 저희한테 불이익이 올까문의', 96]
# ['와이퍼가 잘 안닦이고 워셔액이 없다며 인입', 74]
# ['조수석 열선시트', 59]
# ['종합 경고등', 16]
# ['왼쪽 하향등 안나오고 현장조치 불가', 31]
# ['오류메세지 나와도 하이패스이용 무방함', 124]
# ['차량 브레이크 상단측에 배선이 튀어나와 있음', 42]
# ['주유카드 없음', 22]
# ['손님을 대접하고 있는데 해당 소음 때문에 거슬리는 것도 있고 운전시 너무 신경이 쓰일 정도', 138]
# ['내비게이션 작동 안됨 차량 타기전 외부사진찍고 전송', 18]
# ['계기판에 경고등이 점등된다며 인입', 11]
# ['경고등 점등과 정차 후 주행시 펑펑 거리는 소리가 난다함', 15]
# ['통합 경고등도 있다고 함', 16]
# ['라이트 경고등 점등 운전석 하단 라이트', 31]
# ['단말기 문제로 확인되어 반납필수 안내 후 반납완료 후 종결 ', 25]
# ['운행중 공기압 경고등 점등 들어왓다 없어졌다함', 118]
# ['조수석 본넷쪽에 귀뚜라미소리처럼 전자파 소리 들린다고함', 40]
# ['고객님 시동불가인입', 56]
# ['보류', 112]
# ['주유카드 없다며 문의', 96]
# ['하이패스 관련 문의', 123]
# ['내비게이션 소음', 18]
# ['엔진체크 경고등 점등으로 운행 가능 한지문의', 11]
# ['창문이 얼어서 닫히지 않음', 113]
# ['한진주차장 관리인호 브레이크 패드가 잘 안밟힌다며 대여하면 안된다함', 42]
# ['TCS 번재시작동일안됨', 18]
# ['시동이 잘 걸리지 않았으며 현재 경고등 점등', 31]
# ['인근 주유소 다 문닫혀있어 주유 할수없는 상태로 인입', 12]
# ['뒷타이어 파스 공업사견인인데 견인시 차량을 들어 올리고 이동하는데 뒷타이어 파스라 앞타이어와 교체후 이동해야해서 추가로 타이어교체 접수요청', 118]
# ['하이패스 결제 오류', 123]
# ['차량 창문이 안닫김', 113]
# ['브레이크밝는쪽에 위쪽에전선탈거됨', 26]
# ['차량변경 요청', 54]
# ['차량 없음 인입', 100]
# ['크락션이 울리지 않음', 127]
# ['CS 재시작 후에도 동일증상 발생', 25]
# ['내비게이션이 제대로 고정되지 않아서 사용이 어려움', 22]
# ['차량운행중 핸들이 고정이안되어 움직임이 심하여 똑바로 주행이안된다고함', 110]
# ['차량 워셔액이 없고 운전석 와이퍼는 작동 안됨', 81]
# ['경고등 유무없음', 43]
# ['쏘카패스를 개월권으로 결제함 년권으로 변경 하고 싶음', 51]
# ['차량 네비게이션 거치대 파손되어있다하심', 22]
# ['네비게이션 오작동 모바일 데이터 또는 WIFI 연결상태 확인 요청', 21]
# ['전조등 점검 경고등 점등', 31]
# ['운전석 발 쪽 히터 안나옴', 137]
# ['경고등 미점등', 81]
# ['사진첨부 반납예정 왼쪽 뒷 타이어 공기압 낮음 뜸', 118]
# ['일신빌딩 쏘카존이 제일 가깝다고 말씀해주심', 118]
# ['외관손상문의', 111]
# ['블루투스키려하면 화면이꺼짐 점검요청', 71]
# ['문열어주시는 시점에 배터리잔량이 급감하여 통화중 대기하였으나 회복되지않음', 56]
# ['운행전 계기판점등됨', 11]
# ['타이어 파스로 바람 빠짐 현장조치 불가', 121]
# ['타이어 마모 되었다며 인입조수석쪽에있는 와이퍼도 찌그러져있다며 말씀', 119]
# ['변경받을 쏘카존 도착하였다며 인입', 57]
# ['계기판에 경고등 표시', 31]
# ['차량 바퀴가 헛돈다며 취소 요청', 103]
# ['워셔액 분출 고장', 81]
# ['쏘카존 지하라 확인불가였는데 나와서 보니 동물털이 너무 많아 인입', 85]
# ['제동등 점검하라는 문구 떳었다함', 16]
# ['부름지 반납하려는데 이중주차만 가능하다함', 129]
# ['내비게이션이 안된다며 항의 인입', 18]
# ['반납한 차량 공기압 경고등 점등', 118]
# ['내비게이션 정상작동하지 않음', 18]
# ['타이어 바람 미세하게 빠지나 날씨가 추운탓에 바람 구멍을 찾을 수가 없음', 121]
# ['사이드 브레이크 경고등이 꺼지질않는다고하심', 7]
# ['타이어펑크 후우', 121]
# ['차량 내부 담배냄새로 인해 장애 블락 생성 ', 118]
# ['해당내용으로 정차후 시동 오프후 문을열었다 닫은후 재시동 및 TCS재시작 하여드렸으나 정상작동하질 않고 실행준비중 화면에서 넘어가질 않아 해당내용으로 불편호소하시어 시간 쿠폰케어 SV알엠협의 동승자분 휴대폰 내비게이션 사용하시어 운행해 주시기로함', 18]
# ['네비게이션 재부팅햇는데도 잘 보이지 않고 자꾸 사용자 인증정보가 변경되어 자동로그아웃으로 인해 불편문의', 18]
# ['내비게이션 고장 문의', 18]
# ['핸들조작 시 소음 지속 밠행', 129]
# ['내비게이션 GPS 위치 이상', 21]
# ['내비게이션 문제로 재인입', 18]
# ['워셔액 얼어서 사용 못한 부분 점거 요청', 81]
# ['웹뷰미사용 기타사유 기재', 11]
# ['한도 초과로 결제 불가', 95]
# ['후방카메라도 안된다고함', 134]
# ['내비지속꺼짐으로인입', 18]
# ['타이어찢겨있다고하심 이용전사진에 등록하셨다함', 121]
# ['워셔액 고장 문의', 81]
# ['네비 소리 안남', 18]
# ['후방카메라 안나옴', 134]
# ['수도꼭지 모양 경고등이 점등 되었다고함', 11]
# ['공기압경고등도 체크가안된다고함', 43]
# ['컨트롤 패드 GPS 오류로 인입', 18]
# ['주간주행등 경고등 및 네비게이션 문의', 31]
# ['트렁크 안열림 문의', 122]
# ['다른위치 문의', 58]
# ['기어R로변경시 후방카메라 나오지않아문의', 134]
# ['충전카드 태깅오류', 91]
# ['차량 운행하러왔는데 차량에 시동이 안걸려서 문의', 56]
# ['엔진 경우 툭툭 치는 이상한 소림 난다고함', 106]
# ['주행소음 있다고 유입', 106]
# ['내비게이션이 게속 지연 된다고함', 21]
# ['코너링으로 핸들 한바퀴이상 돌리면서 주행하면 끼긱 소리납니다', 107]
# ['계기판내 경고등 들어와있음', 118]
# ['경적 X', 127]
# ['운행자 변경 되서 로그아웃된다고 하며 문의', 18]
# ['경고등점등 대차 요청인입', 118]
# ['육안상 확인시에도 문제는 없다함', 106]
# ['운전석 와이퍼', 73]
# ['운전중에 갑자기 멈췄다 다시 운전이 됨 뒷창문이 작동하지 않음', 107]
# ['공기압 경고등 들어와서 문의', 118]
# ['경차라서 소음 발생할 수 있음', 106]
# ['차량 제동등 점검으로 공업사 갈려고 했으나', 18]
# ['보조석 도어', 29]
# ['긴출기사현장조치완료', 121]
# ['내비 네크워크가 연결이안된다고하심', 21]
# ['차량이용하러왔으나 거치대가 파손되어있다고하심', 22]
# ['시동껐다가다시켜도동일현상발생한다고함', 20]
# ['차량 문제어안됨으로 인입', 56]
# ['어려운건 아님', 43]
# ['핸들러님 타이어 경고등 제보 사진확인 시 통합경고등 점등 확인되어 추가 접수', 16]
# ['운전석 문 안쪽손잡이 부분에 플라스틱이나 기타 물질이 따따따닥 소리가 들린다고 함', 32]
# ['외관이 너무 더러움 문의', 88]
# ['브레이크에서 터지는 듯한 소리가 남', 43]
# ['운전석 쪽 사이드미러 안접힘 운행 지장없으니 그냥 타겠다함', 49]
# ['내비게이션 안된다며 반납후 조치요청', 21]
# ['고객 주행중 사진 실패 주행문제없으니깐 이용한다고함', 31]
# ['내비 화면 나오지 않아 인입', 18]
# ['내비화면안들어온다하심', 18]
# ['워셔액이 나오지 않아 인입', 81]
# ['기사가 주행하면서 왼쪽으로 살짝 쏠리긴한다고 함', 108]
# ['조수석 뒷바퀴 바람 빠져있다고함', 118]
# ['어제 차량 이용 중 난폭운전으로 차량 뒤집힐 뻔 했음 블랙박스 영상 요청', 48]
# ['핸들내 볼륨 조절버튼 고장', 128]
# ['차량 시동은 걸리나 키아웃 경고등 지속 발생 앞유리 세차 필요 워셔액 뿌려도 자국이 남아 운행에 지장이 있다고 함', 57]
# ['핸들을 한쪽으로 꺾어야지만 직진 주행이 가능하다고 인입', 110]
# ['브레이크 밞으면 차체가 심하게 떨림', 107]
# ['TCS재시작 요청', 21]
# ['사진 보냈는데 조수석에 종이가 갈기갈기 찢겨져있고 네비작동이 안되고 후방카메라가 켜져야하는데 안켜진다함', 134]
# ['주간주행등 노란등', 31]
# ['내비게이션 화면볼륨 버튼 눌렀으나 화면꺼침', 18]
# ['기사님 도착후 인입', 106]
# ['내비게이션이 안됨', 18]
# ['월 일 일 쏘카를 이용하다가 차량에 배치된 카드로 주유를 할려했는데 정지되었다고해서 개인카드로 주유를 했는데 환불 신청을 하면 된다기에 영수증 첨부해서 했는데 고객센터에 문의를 하라 답변을 받았음', 95]
# ['반납하려고 하는도중 보조석앞타이어 찢어짐확인인입', 121]
# ['타는 냄새와 시동불가', 109]
# ['어제 새벽 시경 한국전기차충전서비스 충전기로 충전을 시도하고자 하였으나 회원카드가 인식이 되지 않았음', 115]
# ['제동등 점검 경고알림 확인', 31]
# ['불편생기시면 언제든지 연락주시라 말씀드림', 18]
# ['차량 문제 재인입', 75]
# ['물량 부족으로 수리 불가 하다고 했다고 함', 31]
# ['방향 지시등 안되서 문의', 16]
# ['공기압경고등 들어와 문의', 118]
# ['내비가 자꾸꺼지고 소리안나온다함', 18]
# ['티맵실행중이라는 문구 발생되면서 내비 불가로 인입', 21]
# ['USB포트', 2]
# ['내비게이션은 작동중인데 핸드폰 및 아이가 사용하는 기계에 와이파이가 안잡힘', 21]
# ['핸들러 배차지에 도착해서 내비게이션 거치대가 떨어졌다고 함', 22]
# ['긴출기사 현장 확인시 연료가 얼어 시동이 안걸리며 정비소 입고시켜야한다고 하심으로 문의', 12]
# ['후방카메라가 있긴 한지', 134]
# ['대차 쏘카존 도착하여 인입', 31]
# ['느낌표모양경고등점등되었다며인입', 118]
# ['사진 보내주셨다며 인입', 31]
# ['노란 경고등이 두개나 들어왔으며 차량 내 담배냄새 및 담뱃재가 가득있어 이용불가하다 인입', 118]
# ['OB요청하여 전화드림', 44]
# ['배터리 방전으로 문의', 56]
# ['안나오는 사진 밖에서 찍어 달라고 했는데 운행중이라고 거부', 31]
# ['엔진체크 경고등 점등되었다함', 11]
# ['해당 쏘카존에서 차량 찾으시면 재전화 안내', 31]
# ['차안에서 기름냄새가 나는것은사실', 109]
# ['열선시트 고장', 59]
# ['카오디오 안눌림', 71]
# ['MAP 실행준비중 메세지 출현', 21]
# ['원존 운행전 통합경고등 점등', 16]
# ['점검하겠음 경고등여부문의 없음', 31]
# ['하이패스 카드가 미장착이라고 함', 124]
# ['운석적 의자각도 조절 레버 파손 되어있어 인입', 58]
# ['차량 옆에 없음', 31]
# ['블랙박스 메모리카드 분실되어 문의', 45]
# ['카오디오는 안된다심', 69]
# ['차량배터리 방전된것같음', 56]
# ['운행중 공기압 경고등 점등 조수석 앞바퀴', 118]
# ['차량에 띠띠띠 소리가 계속 난다고하심', 72]
# ['고객 이미 차량에서 멀리 떨어졌고 추후 점검을 해야될 거 같아서 전화 드린거라고 하심', 134]
# ['추가 접수 요청', 56]
# ['지정공업사까지 KM이상 남았는데 가다가 엔진퍼지면 어떡하냐하심', 11]
# ['블랙박스가 안된다', 45]
# ['후방카메라 작동안됨', 21]
# ['주행하다가 브레이크 밟으면 소음 발생된다고 하심', 106]
# ['네비게이션 탈거 운행중 너무 불편한데 기대걸쳐놓아도 자꾸쓰러져서', 22]
# ['고속도로 주행중 타이어 퍼짐', 121]
# ['전기차 충전문의', 115]
# ['하양등 점검문구 확인', 31]
# ['주행중 울컥거림으로 인입', 107]
# ['타이어 조작 불가 인입', 131]
# ['조수석 앞 차량문이 올라가지 않아 문의', 113]
# ['후미등이 안 나온다며 재 문의', 31]
# ['차량 대차 받았는데 엔진 경고등 또 나왔다며 인입', 11]
# ['전조등불량', 31]
# ['소리 문제는 ADAS로 설명드림', 45]
# ['시거잭 충전 안됨', 53]
# ['주행소음', 106]
# ['운전석 등받이 각도조절 불가 인입', 58]
# ['얼라이먼트로 봐야된다고', 108]
# ['A필름쪽 내장제 파손 운전석쪽', 23]
# ['인입됨', 18]
# ['블루투스 되지 않아 인입', 18]
# ['전조등이나 후면등 어디가 문제일지', 108]
# ['차량 라이트로 인해 문의', 31]
# ['문잠금 안된다함', 35]
# ['차량변경요청', 71]
# ['반납은 원존으로 가능 안내', 31]
# ['문열림 버튼 누를경우 운전석은 잘열리나 보조석문열림 안되어 인입', 28]
# ['대차 문의', 118]
# ['고객님 인입시 점등 안돼는곳 확인 및 전조등이면 긴출 그외 라이트라면운행 가능여부 확인해서 대차 부탁드립니다', 31]
# ['아직 쏘카존임', 31]
# ['트렁크 찍혀서 문의', 122]
# ['핸들 돌아갈때마다 딱딱딱한다고 함', 81]
# ['차량 시동 맘대로 꺼지며 심하게 떨린다고 하심', 107]
# ['차량 운행중 소음이난다고하심', 106]
# ['배터리 방전 시동 불가', 11]
# ['운행중시동이 지속 꺼짐', 11]
# ['운행중 차에 경고등 점등됨', 15]
# ['전조등 점검해보라는 경고등 떠서 연락드림', 31]
# ['차량 마다 타이어 쪽에 있는 이격임', 106]
# ['내비게이션 업데이트 오류', 18]
# ['사용 어렵다고 하시어 동일 쏘카존 동급 차량으로 대차 진행', 44]
# ['오류있을수 있음', 125]
# ['채 팅 건불 만 건', 112]
# ['시트가 뒤로 최대한 되어 있는데 레버 눌러도 앞으로 조절이 안된다고 하심', 58]
# ['내부 위생불량하다고 하심', 83]
# ['안열림', 30]
# ['제동등 점검필요 경고등 엑셀을 밟을 시 RPM이 심하게 올라감', 31]
# ['내비게이션 실행 오류 문의', 18]
# ['주유소 군데 방문했으나 유효한카드가 아니라며 인식되지않음 ', 95]
# ['후방카메라가 정중앙이 아님', 135]
# ['운행전 엔진체크 경고등 점등', 11]
# ['내비 문제로 재인입', 18]
# ['문자로 사진 발송 요청 드림', 106]
# ['차량 운전석 내부 버튼 작동 불가 상태', 94]
# ['왼쪽 하향등 안나와서 긴출 요청', 31]
# ['차량을 운행하러왔는데 차량이 안보여서 문의', 100]
# ['본넷 지지대 분실', 41]
# ['차량 스페너모양 경고등 점등됐다고하심', 8]
# ['쏘카존만차로인입', 99]
# ['고객님 네비게이션 벌어짐인입', 22]
# ['재시작 해드림 여전히 안된다 함', 18]
# ['전조등 점검하라고 뜸 실제로 점등안되는지는 밖에서 못봤다고 하심', 31]
# ['안전벨트 알림 소리', 64]
# ['제동등 경고등 점등 후좌', 7]
# ['잠깐쓰고 말꺼여서 필요없다고 하심', 43]
# ['엔진 체크 경고등이 점등 되었다고함', 11]
# ['핸드폰 내비게이션 이용 반납후 점검하도록 하겠음', 21]
# ['차량 내부상태 불량', 83]
# ['워셔액으로 대차 받았으나 대차차량도 워셔액 안나옴', 81]
# ['문제어 및 GPS신호는 정상이나 문잠금 지속 실행되지않아 장애블락 생성', 35]
# ['준비준으로만 나오고 안된다고 함', 21]
# ['어제부터 계기판에 엔진모양 경고등 떠있었다며 인입', 11]
# ['후방카메라 작동시 화면 지지직 거림', 134]
# ['타이어공기압경고등 사진전송후 인입', 118]
# ['조치하겠음 안내', 25]
# ['반납불가', 99]
# ['네비게이션문제', 18]
# ['전조등 경고등 점등', 31]
# ['운전석 높낮이 레버 고장', 58]
# ['운전자석 시트 각도조절기가 빠져있는건지', 58]
# ['전기차 카드태그안됨', 115]
# ['재부팅 동일증상 발생', 21]
# ['휠 얼라이먼트 조정 요청 전륜 서스펜션 수리 요청 핸들이 정방향으로 가지않고 우측으로 돌아가있는것 점검요청 가벼운 과속방지턱 넘을때마다 삐그덕 거린다 검검요청', 136]
# ['워셔액 분출 고장으로 인한 시야확보 불편', 81]
# ['뒷 범퍼 이격현상', 78]
# ['엔진체크 경고등 점등 인입', 11]
# ['주행중에 점등이된건지 처음부터 점등됬던건지 모르겠고 지금보닊 점등되어있다함', 15]
# ['티맵 안됨', 18]
# ['내부 상태 불량 및 경고등으로 인입', 16]
# ['브레이크가 장애가 있는것같다', 42]
# ['내비게이션 이용불가 경로탐색 누르면 초기화면으로 이동', 18]
# ['내비 소리가 안나와 연락 준다했는데 연락이 안와 인입', 18]
# ['하이패스가 문제가 있는거같다고함', 123]
# ['점등상태에서 운행해도 무관', 4]
# ['블랙박스 고장으로 인입', 45]
# ['주행도중 시속 KM 이상 주행하면 소음 발생으로 조치 받았으나 이상 없음 조치 받아서 계속 운행 했음 하지만 주행도중 뭔가 터지는 소리 발생하여 정차하여 문의함', 106]
# ['브레이크 떨림은 긴출해야됨', 43]
# ['긴급출동 기사가 현장에서 비용 납부 요구 시 절대 응하지 말고 고객센터 측으로 문의 안내 필요', 31]
# ['차량내 충전카드 없음', 117]
# ['주간라이트경고등 점등이라고 함', 31]
# ['TCS재시작상담사 여전히 안됨', 21]
# ['오른쪽 뒤 창문 올림 내림작동안된다함', 113]
# ['주행소음 심하고 속도도 안나서 대차 원하시는데 확인요청하심', 106]
# ['전조등 경고등 점등 및 네비안켜짐', 18]
# ['이전 차량 가시동 이였음', 56]
# ['타이어', 118]
# ['세모에 느낌표 경고등 떠있고 후방카메라 점검이 필요하다고 함 내비도 안된다고 차량 점검하라고 하심 사진전송안내', 16]
# ['코나차종안내 연장금액 하이패스금액 사고시 휴차료금액 변경받는 차량으로 적용됨', 56]
# ['충전 커넥터 연결 안됨', 92]
# ['핸들이 왼쪽으로 조금 감깁니다', 108]
# ['뒷자석 시트 파손', 23]
# ['행 중 재부팅 반복만되는경우도 발생', 21]
# ['긴급 출동 접수를 하였으나 기사가 라이트 교체는 공장에서 해야한다고 했다고함', 31]
# ['화면은 역시 안 나옴', 18]
# ['운행하려는데 블랙박스 메모리문제로인입', 45]
# ['차량에 소음이난다고 하심', 106]
# ['핸등 소음 발생', 129]
# ['운전석 데일리등이 들어오지 않음', 32]
# ['차량문이 안열린다며 인입', 18]
# ['왼쪽 브레이크등 점등으로인입', 7]
# ['모든 경고등 점등', 8]
# ['케이블 빼고 SD카드 재삽입 모르겠음', 45]
# ['후방카레마 안됨', 134]
# ['반납존에 와서 차량 펑크 확인되어 문의', 121]
# ['워셔액 미분사 앞유리 성애로 시야확보 불가', 81]
# ['오른쪽 전조등이 안나옴', 31]
# ['차량 받았으나 담배냄새가 심해서 인입', 22]
# ['직진을할려면 핸들을 살짝오른쪽으로 틀어야한다며 핸들쏠림이있는거같다며인입', 108]
# ['공기압 조치했는데 계속 경고등점등 타이어 교체해야한다고함', 118]
# ['제동등경고등점등', 7]
# ['블박열화현상', 45]
# ['와이파이 작동되지않아 네비게이션 끊겨 중간에 길 한참 헤맸다함', 21]
# ['워셔액없어서 주유소에서 구입했고 넣었는데 얼어서나오지않음', 81]
# ['조수석 전조등 미점등', 31]
# ['충전카드 오류 유효하지않다는 메세지나옴', 115]
# ['시동도 바로 들어오는 게 아니라 뒤늦게 켜지는 감이 있다고', 10]
# ['내비게이션 탈거되어잇다고함', 22]
# ['차량운행하려는데 문제어가 안되어서인입', 56]
# ['쏘카의 경우 차량 내부에있는 와이파이는 편의품목으로 인해 실 장착여부는 차량마다 상이하여 없는 경우 사용은 어려움', 21]
# ['배터리 방전 시동 불가 인입', 56]
# ['시동안걸린다고 인입 배터리 부족확인', 56]
# ['차량 문제어 불가 ', 35]
# ['네비게이션이 시간째 소리안남', 18]
# ['점검할수있도록 하겠다 안내', 44]
# ['경고등도 많이 점등되었고 주행도 어려워 인입', 11]
# ['후방카메라 탈거인입', 135]
# ['반납한 차량에 이전 고객이 회수하지 않은 쓰레기 있었음 워셔액도 나오지 않음', 81]
# ['네트워크가 연결문제로 작동이 되지 않음 TCS 재시작으로 해결 불가', 21]
# ['후방카메라 이격', 135]
# ['운전석뒷바퀴', 118]
# ['브레이크를 밟으면 주행떨림 발생', 107]
# ['후방센서 감지기 문제', 133]
# ['블랙박스 앞 뒤로 모두 없음 문의', 46]
# ['전기차 충전카드 보이지않음', 117]
# ['건의사항으로 인입', 18]
# ['히터를 틀 시 히터 펜이 갈리는 듯한 소리가 심하게 나서 위험할 수도 있어 반납 후 인입', 138]
# ['차량을 반납했는데 차량에 블랙박스가 떨어져 있어서 문의', 45]
# ['후방카메라사용불가네비게이션 디스플레이불량', 18]
# ['타이어 공기압경고등점등', 118]
# ['일단 이동해야한다고함', 44]
# ['한번씩 꺼질것처럼 깜박거림', 18]
# ['차량 이용할려고 딱 탔는데 타이어공기압경고등 발생됨', 118]
# ['반납시작성하려했는데 좋아요 눌려서 못남겼는데 차량상태 안좋음', 107]
# ['시동을 껏다켜도 작동을 안함', 81]
# ['전조등 점검 경고등', 31]
# ['배선 밖으로 빠져나와있다고함', 24]
# ['차량 시동', 56]
# ['운행전 경고등 점등 인입', 16]
# ['후방카메라 불량', 134]
# ['사이드 브레이크 해제했으나 동일하게 브레이크등 점등된다며 인입', 7]
# ['스마트키 인식불가 문의', 57]
# ['워셔액도 없음', 18]
# ['블루투스 연결 시 노래 재생이 잘 안된다고 하심', 134]
# ['경고등점등문의', 11]
# ['내비게이션 이용불가 실행 준비중 메세지 확인', 134]
# ['네비게이션 SD 카드 오류', 20]
# ['차량 시동불가 배터리방전같다하심', 56]
# ['유효기간은 일이며 국산차종 사용 시 사용 가능하고 쏘카패스 쿠폰과는 별개로 시간 사용시에도 사용 가능한 쿠폰인 점 참고', 18]
# ['차량문이 안열려문의', 56]
# ['주행소음으로 대차', 106]
# ['원존 문열림 안되어 차량상태 확인시 배터리 방전', 56]
# ['키아웃 신호 보냈지만 시동걸리지않음', 57]
# ['충전카드 태깅시 등록된 회원이 아니라고뜸', 115]
# ['뒷자리 안전벨트 잠금 장치 파손', 64]
# ['엔진체크경고등 점등됐다고 함', 11]
# ['내비에 반납지 설정이 안되어 있다함', 18]
# ['문제어 불가시동불가인입', 35]
# ['내비게이션 T맵 실행중 맨트에서 동일화면 유지됨', 20]
# ['차량 배터리 방전으로 인해 시동이 불가한 상태', 56]
# ['내비게이션불가인입', 21]
# ['조수석 앞 창문 버튼 작동 불가', 113]
# ['차량 주행 떨림있어서 문의', 107]
# ['전화 끊어져서 재연락드림', 118]
# ['시동껐다켜도 동일 서비스 지연되고있다고만 뜸', 21]
# ['조수석 문 안에서 안열림', 28]
# ['후진시 후방카메라 이용불가', 134]
# ['아틀란 소리 이용 불가 패드에서 소리가 안나옴 ', 20]
# ['통합경고등점등되었다며인입', 16]
# ['워셔액 충전을 위해 보넷 열어야 하는데 어떻게 하는지 모른다고 하심', 40]
# ['트렁크 안열려서 문의', 122]
# ['주행 중 소음발생으로 인입', 106]
# ['KM 주행중 앞차 급정거로 브레이크 밟았을때 브레이크 풀리는 느낌들며 밀림 제동시 이상한 소음도 발생 ', 43]
# ['블루투스 연결불가 및 오디오 송출 불가로 인입', 71]
# ['배터리 방전이라 나오면서 시동이 안 걸린다며 인입', 56]
# ['차량이 한쪽으로 계속 쏠리는 느낌이라고 하심', 108]
# ['오른쪽으로 차량이 튄다고함', 108]
# ['조수석 뒷자리 손잡이 파손', 30]
# ['고객님 통합경고등 후측방경고등인입', 15]
# ['차량운행중 네비게이션 작동안되어 길을잘못찾아 길을 시간가량 돌아왔다고함', 18]
# ['TCS 재시작상담사 똑같음', 21]
# ['블루투스 연결 X', 71]
# ['내비게이션 문의', 22]
# ['내비 화면 불가', 18]
# ['실내등 안꺼진다함', 61]
# ['차량 내 담배꽁초 쓰레기가 있었는데 그건 본인이 치웠지만 브레이크가 밀린다고 하심', 43]
# ['네비 소리 안나온다고 인입', 18]
# ['사진첨부 네비게이션 작동하지않음', 21]
# ['레이더 가림으로 후측방 경고 시스템이 정지되어 있다고 나온다고', 15]
# ['배터리방전으로 인입', 56]
# ['시트조절 불가', 58]
# ['내비게이션 네트워크 연결이 안된다고하심 작동은 되나 검색안됨', 21]
# ['시동껐는데 어플에서 자꾸 시동켜져있다고 나와서 반납이 안된다고 인입', 97]
# ['그럼 반납후 조치요청하여 그렇게하겠음종결', 118]
# ['차내 내비게이션이 안됨', 21]
# ['뒷좌석 가운데 안전벨트 고정이 안됨', 64]
# ['경고등 확인 요청', 118]
# ['인근쏘카존 다른 차량 안내', 31]
# ['네비게이션 되지않음으로인입', 18]
# ['운행 시 차체 흔들림이 심함', 107]
# ['트렁크제어 불가로 문의 손잡이안에 실리콘 없음', 122]
# ['주행 중 두둥 소음발생으로 인입', 106]
# ['후방카메라가 안 된다며 대차요청', 134]
# ['급하게 이동중으로 점검 받을 수 없음', 106]
# ['타이어 주행중 웅웅 소리가 들린다고 하심', 106]
# ['고객님께서 직접 사서 워셔액 넣어봤지만 동일하게 안나옴', 81]
# ['주행 중 소음이 심하게 발생된다고 하심', 106]
# ['블랙박스 탈거돼서 인입', 45]
# ['블루투스 연결 안되서 인입', 21]
# ['차량 번호', 36]
# ['하향등 점검 경고등', 31]
# ['연료', 12]
# ['운행중 차량에서 달그락 거리는 소리가 난다고 함', 106]
# ['내비 연결 안됨', 21]
# ['내비게이션 안돼서 문의', 21]
# ['배터리방전 키아웃', 56]
# ['이상 속도가 나지않음', 104]
# ['와이파이가 안되어 인입', 21]
# ['접촉여부문의 접촉 없었다고 주장 유턴하다가 바람빠짐', 121]
# ['차량 타려고 봤는데 라이트 경고등이 점등되어 인입', 31]
# ['후방카메라 작동불가', 134]
# ['공기압 조치받음', 118]
# ['주차장관리인', 54]
# ['정위치 주차까지 분 걸린다함', 118]
# ['긴출완료후 인입', 110]
# ['하향 전조등 점검하라는 문구 노출 확인후 조치필요 ', 31]
# ['차량 안심번호 미부착', 62]
# ['접촉 한곳은 없는지 수긍', 121]
# ['브레이크시 땅긇이는 소리가 난다고 하심', 44]
# ['주행시 엔진이 지속튄다며인입', 106]
# ['타이어 운행중 못박혀 펑크난것같다고함', 121]
# ['차량 변경요청', 53]
# ['GPS 안잡힘', 18]
# ['핸들이 오른쪽으로 꺾여있고 브레이크 밟으면 오른쪽으로 휜다고 하심', 108]
# ['업데이트 오류 발생 뜬다', 20]
# ['내비 업데이트 오류', 20]
# ['호을 수차례 이용하고 있는데 최근에 주유를 할때 투입량과 계기판에 있는 수치와 핸드폰수치가 다름', 21]
# ['조수석 하향등경고등 점등', 31]
# ['주유카드 한도초과뜸', 95]
# ['이용불가 TMAP이 중지되었다는 알림', 21]
# ['타이어 공기압 및 외부경관등 경고등 점등', 118]
# ['앞유리 얼어있어 운행불가하다하심', 81]
# ['내비게이션이 지연된다며 안된다고하심', 18]
# ['브레이크 점검 하라는 경고등 점등되어 장애블락 생성', 7]
# ['잠깐 주행했는데 점검 표시등 점등되어 문의', 11]
# ['전조등 왼쪽 안나옴', 31]
# ['타이어 공기압 경고등 점등도 되고 내비게이션도 먹통으로 아예 안켜진다고 인입', 18]
# ['CS 재시작 후 문열기 잠금 반복', 25]
# ['내비가 연결이 안됨', 21]
# ['CS재시작 및 키아웃신호 회 보냄', 56]
# ['SD카드가 없다고나왓다고하심', 18]
# ['주유캡분실', 93]
# ['주차시 기어를 D나 R로 두고 운행시 공회전이나 움직이지 않고 있다가 주행한다고 함', 103]
# ['차량 파스로 공업사 입고 요청', 121]
# ['핸들에 문제 있어 이전에 접수했고 지금은 동승자가 예약해서 탓는데 아직도 안고쳤다고 항의', 131]
# ['외관상 문제는 없어보인다함', 31]
# ['부품 하나가 빠져있다며 인입', 18]
# ['키아웃현상', 57]
# ['하이패스 통과시 결제 안된다고 함', 123]
# ['기사 따로 접수 필요없고 이동 직접 한다고 함', 121]
# ['차량 소음건은 이후 조치 하겠음', 106]
# ['공기압 이상', 118]
# ['쏘카존내 차량없음', 100]
# ['기어봉 아래 버튼빠짐', 70]
# ['인근에서 대차진행안내', 57]
# ['사이드미러 오른쪽 후측방경고도 센서고장으로 불이 계속들어옴', 15]
# ['내비게이션 인터넷 연결 불가', 21]
# ['오늘 레이 차량 이용햇는데 차량에 문제가 있어서 그냥 도중에 이용하다가 빨리 반납하고 다른 차 빌려감', 106]
# ['차량이제이용할려고탔는데 번호판이 떨어져있음', 39]
# ['충전카드 분실 ', 117]
# ['이전 올뉴K차량 공기압경고등 떠있었다며 점검한번 해보라하심 반납 후로 따로 사진은 없음', 31]
# ['단말기 재시작 이후 OB', 35]
# ['고객님 하단 디퓨저 파손확인', 78]
# ['계기판에 전방충돌방지보조시스템 점등', 15]
# ['거치대 파손', 22]
# ['조수석 헤드라이트 고장 경고등 점등', 31]
# ['차량시동을꺼도 엔진룸쪽에서 계속 엔진이 돌아가는소리가 들려서 이상한거같아 알려줄려고 전화함', 106]
# ['차량 내비 화면 안나와 문의', 18]
# ['운전석 안전벨트 뺄 때 잘 안된다고 하심', 64]
# ['계기판RPM경고등 뜸', 11]
# ['브레이크가 더디고 울퉁불퉁한 길을 주행시 차량이 많이 흔들림', 43]
# ['고객 차량 브레이크 소음 문제로 긴출 현장 확인후 재인입', 44]
# ['호 쏘카세이브 투싼 O 차량 시동걸리지 않음', 56]
# ['반납 차량 문 안잠김', 18]
# ['다시 이용시 소음 다시 발생', 106]
# ['타이어 펑크로 인한 인입', 121]
# ['조수석 앞 바퀴 바람 많이 빠짐', 121]
# ['운행시작전 차량상태 확인중 타이어 전우 펑크난 부분으로 확인되어인입', 121]
# ['하단 디퓨저', 78]
# ['차량을 인수하러 왔는데 블랙박스가 떨어져있음', 45]
# ['내비 안되어 문의', 58]
# ['길이 많이 얼어서 불안함', 64]
# ['엔진 냉각수 온도가 올라가고 시동이 꺼짐 회', 11]
# ['반납을 하려는 과정 중 차량 후진이 되지 않아 주차 자체가 어려운 상태', 104]
# ['패달위에 선이 나와있어 인입', 24]
# ['라이트가 안나온다고 인입', 31]
# ['차량 브레이크에서 소음이 들린다며 인입', 59]
# ['쓰레기가 너무 많다고함', 83]
# ['사고카드 생성', 118]
# ['이후 점검블락 있어 점검블락 전까지 장애블락 점유', 31]
# ['차량계기판점등됨', 15]
# ['운행중 라이트 점검등 점등', 31]
# ['외부에서 시동끄고 주유구 눌러 시도했으나 열리지않음', 94]
# ['운전중 조수석 운전석에서 차가 울렁거린다는 느낌의 승차감 있었음', 107]
# ['내비게이션 화면꺼짐', 18]
# ['오디오노이즈만들림', 69]
# ['전륜타이어교체', 119]
# ['키아웃으로 시동안걸림', 57]
# ['라이트 조치후 인입', 31]
# ['워셔액 분사 불가', 81]
# ['키아웃 신호 보내드렸으나 지속 시동 켰으나 안된다고 하심', 57]
# ['운행중 잘되다가 갑자기 안된다고하심', 21]
# ['카드방향을 확인하라는 맨트가 지속됨', 123]
# ['찾았음 주차장에 없고 옆에 있었음', 71]
# ['와이퍼 작동 시 파손됨', 75]
# ['고객님 타이어공기압경고등점등인입', 118]
# ['차량에 경고등 점등되었다하심', 16]
# ['시동 ON 상태로 이동중이신지 문의맞음', 137]
# ['고객 브레이크 밟을 때 소리가 나며 차가 밀린다고 함', 43]
# ['선루프가 잘 안닫힘 기능 사용하는 방법이 따로 있는건지 문의', 113]
# ['시동 라이트 껐다고 함', 25]
# ['이용하러왔더니 공기압 점등', 118]
# ['후방카메라 화면이 뿌옇게 나옴', 134]
# ['접착력이 없는거같음', 45]
# ['카드방향을 확인하라는 안내멘트지속 발생 인입', 125]
# ['시동안걸려서 문의', 56]
# ['차량이용안되면 취소하고싶다고함', 118]
# ['현장조치 불가해서 인입', 108]
# ['내비 위치가 아예 다른곳으로 나온다고 함', 21]
# ['따뜻한바람도 안나오고 워셔액안나온다함', 81]
# ['내비화면안넘어간다함', 18]
# ['차량블랙박스가 떨어져 있어 문의', 45]
# ['내비 거치대 불량', 22]
# ['충전구 파손', 90]
# ['핸들러는 쏘카존 거의 도착하여 반납하겠다 함', 31]
# ['스마트키 인식불가로 시동걸리지 않아 문의', 57]
# ['CSUSIMON 이력', 106]
# ['잠금레버 파손', 30]
# ['구동축 파손', 131]
# ['통합경고등 점등돼서 문의', 16]
# ['창문 위쪽 고무', 113]
# ['볼륨조절 버튼 작동불가', 128]
# ['내일 지방으로 출장을 갈거라 결제후 환불은 번거로움 차량변경요청', 96]
# ['TPMS 경고등 타이어', 11]
# ['운전석 하향등 미점등', 31]
# ['남은 시간에 대한 부분환불 협의 된 것 확인 해드림', 31]
# ['차량 문 잠금이 되지 않아서 반납이 안되었다', 35]
# ['시동 불가 경고등 여러개 뜸', 56]
# ['매연 필터 장치 경고등 제보', 4]
# ['차량 관리는 하는건지 항의', 18]
# ['수리 요청', 135]
# ['운전석 뒷 타이어 펑크 출차 불가 하니 조치 바람', 121]
# ['기어가 아에 들어가지 않고 엑셀을 밟아도 엔진소리밖에 안남 RPM올라가는데 차는 굴러가지 않음', 103]
# ['차량 네비가 자꾸 메시지를 띠우고 로그아웃 되어서 운전중 너무 불편네비 스크린에서 시간 연장 하려면 해당차량이 없다면서 종료시스템이 고장인 듯하니 빨리 정비 바람', 18]
# ['반납하려는데 제동등 점검하라고 경고등 떠서 인입', 31]
# ['카오디오 안되서 인입', 21]
# ['차량 타자마자 타이어 공기압경고등이 점등되어 인입', 118]
# ['스마트키를 인식할수없다고 나오고 시동안걸려서 인입', 56]
# ['갑자기 네비게이션 안됨', 18]
# ['차량 반납이 안되어 인입', 92]
# ['핸즈프리', 71]
# ['차량타고있음 굉음들림 워셔액 안나옴 불안 뭔지', 106]
# ['제동등 경고등 확인', 31]
# ['내비게이션 작동되지 않음', 21]
# ['차량이용할려하니까 라이트가 안나옴', 31]
# ['저번에도 동일한 문제로 해당 차량 수리해달라 요청한 적 있었는데 하나도 개선이 안 되었다며 인입', 106]
# ['브레이크 소음으로 인입', 44]
# ['시동 소음으로 문의', 54]
# ['경적소리도안들린다 하심', 100]
# ['조수석 안개등 안들어옴 인입', 31]
# ['차량받아서 주행하려고 했는데 오른쪽 주간주행등 점검하라고 문구가 나와서 인입', 31]
# ['브레이크등 경고등 떠서 인입', 7]
# ['네비게이션 고장으로 인입 네비게이션 검색시 처음 화면으로 다시 돌아간다고 하심', 18]
# ['하 법인고객 월요일부터 금요일까지 매일 사용하는데 트렁크가 계속 열려서 사고 우려가 있음 신속한 조치요청 똑같은 내용으로 번째 의뢰 현상은 운행중 트렁크 열림라이트 스위치 조작시 트렁크 열림 지난번 사고 수리 후 같은 현상이 계속 됨', 122]
# ['차량에 공기압 부족이라는 지시등이 켜져있는데 주행에는 문제가 없을지', 118]
# ['운행시작전 타이어공기압 경고등 점등으로 차량변경요청', 118]
# ['내비게이션 T맵 실행중 이후 작동 안됌', 18]
# ['네비게이션도 작동이 안되었었음', 18]
# ['메모리카드 삽입해달라는 문구 지속 뜸', 45]
# ['후방카메라 화질 이상', 135]
# ['TCS 오작동 네트워크 연결 안된다며 작동 안됨 와이파이도 꺼짐', 21]
# ['네비게이션 거치대 판손', 22]
# ['차량반납했는데 정차중에 브레이크 소리나서문의', 43]
# ['경적 발생유무인지 혹은 차량소음인지 사전 확인 불가 장블생성', 127]
# ['차량 보조석 문이안열려서 이용 안하였다고함', 28]
# ['사고났을때 안전벨트 고장난것처럼 채우려고 해도 뽑히지 않고 운전석 조수석 모두 같은 증상이라고 하심', 64]
# ['차량접촉은 따로없었고 이용시작하려는데 바로 공기압떠서 전화했다고함', 118]
# ['반납은 하였으나 엔젠체크경고등이 점등되었었음 조치요청', 11]
# ['내부상태 불량 및 외관 더러움', 118]
# ['운전석 문이 안열린다며 인입', 28]
# ['계기판에 공기압경고등 확인', 118]
# ['내비게이션 작동이 안되서 문의드림', 131]
# ['워셔액얼었음', 81]
# ['운행중 소음이 계속 발생한다 하심', 106]
# ['쏘카존내 차량없어 인입', 100]
# ['차량문제 제보로 OB', 107]
# ['이전고객 구투한듯함', 82]
# ['내비게이션 연결 지연', 21]
# ['유리에 금도 갔다고 함비접촉', 75]
# ['워셔액 분사가 안되어 문의', 81]
# ['네비게이션이 되지않음으로인입', 20]
# ['원존 핸들 접수 요청 X', 16]
# ['일 이용시 후방카메라 이용불가 제보', 134]
# ['내비게이션 안되신다 문의', 18]
# ['내비게이션 선이 다빠져있고내비 인터넷이 안된다', 21]
# ['주행 소음 안내', 106]
# ['블루투스 연결 불량', 71]
# ['전좌', 121]
# ['내비 소리가 나오지 않음', 18]
# ['버튼조작이 안됨', 49]
# ['배터리 방전으로 인한 시동불가', 56]
# ['와이파이도 안되고 내비가 안되어 상담받다가 끊어져 인입', 21]
# ['차량 이용전 문제어가 안되어 인입', 56]
# ['차량 CS재시작 및 키아웃 신호보냄', 57]
# ['언덕길 못올라가고', 103]
# ['재시작 해드렸으나 네비 무반응', 18]
# ['차량 노령화 및 동일 경고등 점등으로 생각해보면 관리를 전혀 하지 않는것같다고 주장', 16]
# ['트렁크가 열리지 않는다고 함', 122]
# ['내비게이션 안된다며인입', 18]
# ['기사 방문 시간 얼마나 소요되는지', 55]
# ['차 내부에서 소리가 남 운전석 왼편에서 지지직 거림', 106]
# ['결제 진행 태그시 카드인증실패 다시시도 메세지 나옴', 115]
# ['내비게이션 화면 미출력으로 문의', 18]
# ['후방카메라 고장과 동승자 등록', 134]
# ['원존 운행전 타이어 공기압 경고등 점등되어 인입', 118]
# ['타이어소음', 106]
# ['이동주차 요청 위한 문제어 요청', 36]
# ['이용중에 불편함은 없지만 이거 경고등이 뭔지 궁금해서 문의주셨다고하심', 118]
# ['차량문은 어렵게 열렸으나 시동 불가함 배터리 방전 의심', 56]
# ['차량 문제어요청', 11]
# ['내비장애 인입', 21]
# ['반납 제시간에 된건지문의', 58]
# ['차량 이제 이용하려는데 팔거리가 빠진건지 뺀건지 분리되어있어 인입', 23]
# ['충전소 왔는데 충전카드 태깅 시 유효하지 않은 번호라고 나옴', 115]
# ['차량이 얼라이먼트가 나갔는지 오른쪽으로 자꾸 쏠린다고 하심', 108]
# ['운행하다보니 왼쪽 라이트가 꺼짐', 31]
# ['차량 문이 안 열린다고 하심', 35]
# ['트렁크에 있는 물건도 없는데 계속 소리난다고 하심', 22]
# ['대차 받고 이용하려는데경고등 있다고 유입', 16]
# ['풋브레이크이신지', 51]
# ['본네트가 떨어져있다고함', 40]
# ['반납은 일단 했는데 오른쪽 뒷바퀴에 공기압이 낮다고 뜨셨다함', 118]
# ['차량바꿔줘서 바꾼대로 왔는데 제동등이 점등되었음', 16]
# ['차량에 주유카드가 없다고 하심', 96]
# ['블루투스 노래음성안나옴문의', 21]
# ['운전석 썬바이저 거울 깨짐', 52]
# ['핸들을 돌릴때 툭툭치는 소리가 나서 인입', 129]
# ['경고등 점등으로 대차안내', 118]
# ['핸들건 이후 점검블락 있어 카드만 생성함', 28]
# ['문제어불가 기타', 35]
# ['타이어 바람마개 뚜껑 왜 없는것이냐', 118]
# ['전조등을 점검하라는 경고등 점등이 되어 문의', 31]
# ['현재 차량위치 운행건으로 쏘카존으로 위치확인됨', 25]
# ['차량장애 취소 요청', 110]
# ['운행중 오른쪽으로 많이 쏠림 힘주어 조향유지해야할정도 추후 수리필요', 108]
# ['분실물 회수 후 예약 건 취소 요청', 11]
# ['이용전 배터리방전', 56]
# ['브레이크가 밀리고 쇠갈리는 소리 심하다고 하심', 44]
# ['차량 주행등 경고등', 31]
# ['이전상담사 주행하는 와중 갑자기 TCS 꺼서 놀랐다고함', 18]
# ['T맵 실행 준비중입니다 잠시후 자동으로 T맵이 실행됩니다 문구 지속 발생', 21]
# ['차량탑승했는데 타이어 공기압 경고등이 점등되었다며 인입', 118]
# ['TCS재시작상담사 똑같은 증상 나타남', 21]
# ['고객 긴출받았으나 기사 주행시 바퀴헛도는부분있다고했다고함', 55]
# ['고속 운행준 시동이 꺼짐', 55]
# ['팡팡 터지는 소리 난다고 하심', 106]
# ['제동등경고등이점등되었다며인입', 7]
# ['차가 시동이 걸리지 않고 상태가 이상함', 56]
# ['스마트키 인식할수없다고 하며 문의', 57]
# ['브레이크 기계끌리소리처럼 난다고함', 44]
# ['폰을 누르면 블루투스 연결이 되어야 하는데 바로 내비게이션 화면이 나옴', 71]
# ['블랙박스 탈거되있다며 문의', 45]
# ['엔진체크 경고등 점등되면서 차량 주행중 멈춤', 11]
# ['고객 내비게이션 전원이 켜졌다 꺼졌다 한다고 함', 18]
# ['시동 다시 키니깐 연기 난다고 하심', 13]
# ['통합경고등 점등', 11]
# ['워셔액 동결', 81]
# ['고객님 후방카메라나오지않음 불량인입', 134]
# ['배터리 방전으로 시동불가', 56]
# ['서비스가 지연되고 있다고 뜨면서 내비 안됨', 18]
# ['반납 차량 타이어 공기압 경고등 제보', 118]
# ['경고등외관상 손상 없으나 문제가 있는것 같다고함', 129]
# ['타이어 공기압 경고등점등 바퀴 가라앉음', 118]
# ['브레이크등 나오지않음인입', 31]
# ['재시작해도 안된다 함', 18]
# ['검색하다 초기화면으로 되돌아간다고함', 21]
# ['무상 연장요청', 58]
# ['운전석 아래 타이어 공기가 아얘 없다 문의', 121]
# ['핸들에 보시면 오른쪽 왼쪽 모드가 있는데 왼쪽이 안되서 인입', 71]
# ['주행소음 심함 라이닝 갈리는 소리처럼 들린다하심', 106]
# ['방향지시등 운전석방향안나옴 운행에는지장없으시어 반납이후정비요청', 31]
# ['지우는 중이후로 진행이안됨', 18]
# ['경고등 점등 라이트 하나 나감', 31]
# ['사진못찍고 이동했다고 함', 11]
# ['내비게이션 이용불가', 21]
# ['후방카메라 화면불가', 134]
# ['시동안 걸려 인입', 57]
# ['경고등 점등되어서 인입', 118]
# ['배터리 방전', 56]
# ['후진기어시 시스템 점금 메시지 점등', 133]
# ['내비게이션 및 블루투스', 18]
# ['내비게이션 지우는중이라고 떠있다고함', 18]
# ['배터리 충전은 따로 접수 안해도 된다고 하심', 56]
# ['핸들러 배차지에 도착했는데 내비게이션과 후방카메라에 문제가 있다고 함', 21]
# ['수령했을떄부터 타이어공기압경고등 점등되었었다 문의', 118]
# ['제동경고등 동합경고등 점등 으로 어떡해야 하냐고 인입', 16]
# ['문제어 불가로 긴출접수되어 처리중 긴출기사 인입하여 강제로 문은 열었으나 차량 배터리 방전도 아닌데 시동불가 견인처리 해야 한다고 문의', 35]
# ['엔진체크경고등 후방센서 감지 기어봉도이상함', 11]
# ['고객 차량 운행시작시 타이어 공기압 경고등 점등으로 인입', 118]
# ['시동이 안걸리고 에어백 경고등 떠있다며 인입', 9]
# ['차량에서 제동 시 소리가 심함', 106]
# ['운전석 뒷창문 개폐버튼이 작동하지 않음', 107]
# ['조수석 타이어가 바람이 없는거 같다', 118]
# ['차량 시동을 키면 소음발생한다고 인입', 111]
# ['차량 내비 점검요청했는데 조치가 안되어 인입', 21]
# ['도착하여 내전 안내 후 종료', 96]
# ['터치 불가', 18]
# ['라이트 경고등 점등되었다 하심', 31]
# ['차량운행중 엔진경고등이들어왓다고하심', 11]
# ['반납이 되지 않아 인입', 25]
# ['엔진경고등 점등되어있다며인입', 11]
# ['사이드 미러 오른쪽 작동이 잘되지 않는다고 함', 49]
# ['후우타이어 못박힘', 121]
# ['내비가 안되 문의', 18]
# ['차량 블루투스 연결이 되지않아 인입', 71]
# ['안됌 어플상 문 열림으로 뜨나 실제로 안열림', 57]
# ['GPS 위치 이상 지속', 21]
# ['블루투스 노래소리 안들림', 71]
# ['경기 오산시 원동 원동이편한세상단지 동 뒤쪽 지하층 B 앞쪽', 57]
# ['바쁨', 118]
# ['고객 이용하려왔으나 관리하는분이 엔진경고등으로대차필요하다고하여 인입', 11]
# ['반납한 차량 타이어 공기압 경고등 점등', 118]
# ['앞 와이퍼', 75]
# ['정차 시 시동 꺼지면서 네비게이션 화면 같이 꺼진다고 하심', 18]
# ['라디오 소리가 발생되지않고 화면만 출력되어 문의', 72]
# ['요청사유', 36]
# ['저번에 빌린 티볼리는 왜 차량변경안해준건지', 43]
# ['워셔액없음 쏘카 카드로 사면되는지 후방카메라 덜렁거림 떨어질것같다함', 135]
# ['내비게이션 작동안되어 인입', 18]
# ['뒷유리 썬팅 기포', 112]
# ['파인드라이브 내비게이션 지도 화면에서 좌측 하단의 ATLAN 버튼 을 누르신 후 전환된 화면에서 우측 하단의 전원 버튼을 눌러주세요', 18]
# ['사진전송으로 인입', 16]
# ['충전기대로 시도해봤으나 둘다 동일하게 발생된다고함 ', 115]
# ['취소해드림', 121]
# ['TCS재시작 시에도 반응 없음', 18]
# ['신한 신용카드 파란색 유지홍 이름으로 되어있다고 하심', 134]
# ['엔진체크 경고등점등되어 인입', 11]
# ['휴차료하이패스연장료', 11]
# ['태깅기 탈거', 26]
# ['블루투스 연결이 안된다며 인입', 71]
# ['계기판에 느낌표 떴다며 문의', 31]
# ['워셔액 나오지 않음 생수 사서 뿌려가며 닦으며 이용하고 있음', 81]
# ['배터리방전으로 시동불가및 문제어불가 ', 56]
# ['우측 브레이크등 고장', 31]
# ['강제개방후 키아웃', 35]
# ['방금 쏘카로 모닝 이용했는데 브레이크가 완전 꽉 밟아야만 멈춤 확인 부탁 드려요', 43]
# ['이동했다가 불안해서 원존 복귀', 106]
# ['핸들 쏠림있다고 유입', 108]
# ['핸들러 인입 공기압 경고등 점등 문의', 118]
# ['차량 탑승하시고 시동거시는데 공기압경고등이 점등되었다고 인입', 118]
# ['복우너요청 ', 114]
# ['타이어외에도 차량내부 더럽고 워셔액도 안나온다고함', 81]
# ['후방카메라 안되서 인입', 134]
# ['주유하고났는데 주유카드가없음', 96]
# ['차량이용할려하니까 내부에 먼지같은것도있지만 썬팅도 뒤에가 붕떠서 불편함', 112]
# ['운행전 부터 조수석 창문 열려있었고 올릴라니까 안올라간다함', 113]
# ['차량 탑승하자마자 엔진경고등 떴는데 문제 없어보여서 주행했는데 차량이 떨리는 느낌이 난다며 인입', 11]
# ['내비게이션 화면 멈춰있어서 인입', 21]
# ['하기건 재인입 시동 안걸리고 기어도 안바뀐다하심', 54]
# ['경고등 두개 뜬다고 인입', 31]
# ['방향지시등 경고등이 발생되엇음 오른쪽 방향지시등이안나옴', 16]
# ['차량 전조등 하향등 왼쪽고장', 31]
# ['시동안되서 문의', 56]
# ['내비게이션 거치하는게 떨어져서 문의', 22]
# ['와이퍼가 파손 상태임', 73]
# ['뒤쪽에 덜그덕 소리가 난다고 하심', 22]
# ['차량 내 주유카드가 없어서 인입', 96]
# ['TCS 재시작 상담사 시행 동일 증상시 말씀', 21]
# ['주행시 좌측으로 차량쏠림 있음 심함', 108]
# ['차량 브레이크에 문제가 있음', 43]
# ['출차전 배터리방전으로 시동안걸림문의', 56]
# ['에어백 경고등점등문의', 9]
# ['후방카메라가 지지직 거리면서 잘 안보였고 내비게이션이 계속 T맵 준비중입니다 하고 뜨셨다함', 18]
# ['썬루프', 28]
# ['라이트가 나아서 주행어렵다고 인입', 31]
# ['카드 태깅 후 케이블 연결해도 안된다고 하심', 91]
# ['운전석 시트 앞뒤 조절 불가', 58]
# ['고객님 차량문이열리지않는다하심', 56]
# ['TCS 재시작 상담사 시행 동일증상시 말씀', 21]
# ['시가잭 곳 모두 전원 불량', 11]
# ['차량 배터리방전으로 인해 인입', 56]
# ['고객님 가시동 경고등점등', 54]
# ['차량 뒷자석에 머리받침대 문의', 34]
# ['라이트장애 경공등 점등되어 인입', 31]
# ['시이드미러 각도조절불가 양쪽', 49]
# ['블랙박스 없음 선이 다빠져있다하심', 46]
# ['깜빡이를 킬 때 왼쪽만 너무 빠르게 켜졌다가 꺼진다고 함', 31]
# ['차량내 쓰레기 인입 주행해보려고했는데 도무지 불가 하여 인입', 103]
# ['내비재시작 했는데다시 안된다고함', 18]
# ['후방카메라작동불가인입', 134]
# ['네비게이션 재시작시에도 이용이 어렵다 하심', 18]
# ['타이어 공기압', 118]
# ['시동걸리지않음', 56]
# ['화면이 엄청 어둡고 계속 끊겨보임', 134]
# ['내비게이션 티맵 로그인 계속 안된다함 재부팅 해도 안된다고함', 21]
# ['장착이 되지 않는건지 질의', 64]
# ['원존 시동이 안걸려서 인입', 56]
# ['후방카메라 사용불가 및 네비게이션 위에 있는부분으로 주행 시야 확보 어려우시어 전액 환불 요청', 134]
# ['고객 내비게이션 거치대 탈거되서 떨어져서 깨졌다고 하심', 22]
# ['TCS번 재시작동일', 18]
# ['세모 느낌표 경고등 점등되었다고 인입', 31]
# ['내부 버튼 빠져있음 제보', 2]
# ['주유카드결제 안되어 인입', 95]
# ['주간 주행등 점등으로 인입', 16]
# ['내비게이션을 고정하는 부분이 고장났고 주유카드 없음 사이드미러 오른쪽이 접어지지 않음', 22]
# ['단말기 오류로 키아웃 장애 블락 생성', 25]
# ['전좌 타이어 바람빠짐', 118]
# ['타이어공기압경고등 전방추돌경고등점등', 15]
# ['네트워크에 연결되어있지 않다고 뜸 티맵 실행 불가', 21]
# ['주유카드 자리에 하이패스 카드가 있었다고 함', 96]
# ['내비게이션 실행 문제', 21]
# ['타이어 조수석 앞 타이어 라고 하심', 121]
# ['차량 백미러가 파손되있음', 33]
# ['배터리방전인근쏘카존 더뉴아반떼변경 이동거리 택시비환불 반납은 기존쏘카존', 56]
# ['내비게이션 작동하지 않음', 18]
# ['도착 후 내전안내 무상연장 진행', 100]
# ['주간주행등 경고등 점등되어서 인입', 31]
# ['내비게이션 실행준비중으로만 뜸 해결방법있는지', 21]
# ['시동이 안걸림', 56]
# ['배터리 방전임', 56]
# ['서비스점검경고등', 8]
# ['내비 터치 안됨', 18]
# ['USB고장', 2]
# ['계기판 유리 파손으로 인입', 23]
# ['사이드 브레이크 해제여부문의 당연하다고 하심 본인 휴대폰으로 연락달라고 하며 종결', 13]
# ['긴출기사 방문시 타이어에 못 박혀 현장조치 안된다함', 121]
# ['내비 안된다고 유입', 21]
# ['네비게이션이 안나봄', 18]
# ['하기이력 정정', 31]
# ['대차존 안내', 31]
# ['엔진체크경고등이 점등 되었다고함', 11]
# ['경고등 재점등 되어 문의', 118]
# ['반납하고 다른차량이용하겠다고하심 차량교체요청', 106]
# ['타이어 공기압 경고등 점등 못박힘 확인', 118]
# ['운전석 A필름 천장연결부분 내장제 파손', 23]
# ['차량 시동이 안걸린다고 함', 54]
# ['차량 내외부 위생 불량 시동 걸면 내부 쇳소리 떨림 소음 발생', 106]
# ['주간주행등 점검 요청멘트', 31]
# ['티맵실행되지않음', 21]
# ['내비게이션 초기화를 해도 음량이 나오지 않는다고 함', 18]
# ['차량장애제보', 108]
# ['주유 카드가 없음', 117]
# ['차량내 USB꽂는 곳에 핸드폰 충전이 되다 안되다 한다고 문의', 2]
# ['이용전 사진 촬영 시 전면 운전석 앞 범퍼 밑 타이어 물받이 파손 및 나사 풀려있음으로 대차요청', 78]
# ['경고등이 두개 있는데 뭔지 모르겠음', 31]
# ['도착하기 분전 긴급출동접수 요청하라고 해서 문의', 43]
# ['차량이 눈으로 덮혀있고 차량들이 주차창 입구를 막고 있어 출차 불가', 101]
# ['바로반납 크레딧 지급안되는지 문의', 11]
# ['경고등 점등되어 이전상담사분께서 확인후 연락준다고했는데 연락안옴', 11]
# ['컨트롤 패드 오작동으로 인입', 18]
# ['반납을 어디에해야하는지 문의', 23]
# ['휠 손상으로 접촉여부 재차 여쭤봤으나 비접촉 주장', 121]
# ['운행시 악셀에서 발을떼면 소음 발생하면서 엔진브레이크가 걸렸었음 문제 점검 요청', 106]
# ['차량 소음으로 긴출 접수하였으나 현장출동 기사님도 차량에 문제가있는거같다고하여 인입', 106]
# ['브레이크 경고등', 7]
# ['블랙박스에 메모리 카드 없다 뜨고 타이어 공기압 경고등 점등 되었다함', 45]
# ['썬루프 닫음', 21]
# ['타이어 수명이 다달은거같다고하심 멈추면 미끌린다고하심 차량점검필요할거같다하심', 119]
# ['고객 운행할때 후방카메라가 안나온다고 하심', 134]
# ['타이어공기압경고등점등으로 인입', 118]
# ['문 잠금 불가', 28]
# ['뒷유리 썬팅 기포가 심해 야간주행시 걱정된다함', 112]
# ['블루트스 연결안됨', 71]
# ['워셔액 안나온다고', 81]
# ['워셔액이 초반에 나왔었는데 지금 안나옴 워셔액은 가득 차 있음 확인함', 81]
# ['왼쪽 미등이 안나온다고함', 31]
# ['와이파이가 아예 작동하지않는다고 하심 네비게이션도 안된다고 하심 이 차량 몇번 이용했었는데 계속 안된다고 함', 21]
# ['버튼은 단말기재시작해드렸을때 동일하게안될수있음', 70]
# ['운행전 경고등 떠있어 문의', 118]
# ['내비가 고장났는지 파란화면 깜빡거림', 18]
# ['내비가 있다고 들었는데 내비도 안나옴', 107]
# ['티맵 실행 준비중입니다로 인입', 21]
# ['네비게이션 소리 지직거리며 불량', 18]
# ['반납확인요청', 35]
# ['이후 대차진행하였으나 외부상태불량으로 대차진행', 12]
# ['센서 경고등이 왔다갔다 함 결빙어쩌고 나옴 지금은 안나오고있음', 23]
# ['고객님 차량 운행은완료', 103]
# ['고객님 반납 후 정비 안내', 22]
# ['시 분 까지 수정해달라고 요구', 55]
# ['분실물 점검 및 착불 요청', 111]
# ['차량이용중인데 엔진경고등이 발생되었음', 11]
# ['차량 와이퍼 네비 안되서 문의', 73]
# ['네비없음 차량변경 요청', 22]
# ['후진기어 넣지 않으면 따로 소리안나는건지 그렇다고 하심', 133]
# ['주간 주행등 점등', 31]
# ['운행중 접촉은 없었다고 함', 118]
# ['기사님 전화와서', 31]
# ['차량 내부 시프트락 버튼이 내려가있다고 하심', 105]
# ['경고등 점등으로 운행 힘들거같다', 118]
# ['제주특별자치도 제주시 연동 은하빌라', 106]
# ['후진할때 내비에 후방카메라가 안뜬다고 인입', 134]
# ['이후조치하겠음', 31]
# ['핸들을 돌릴때 소음이 나고 차량에서 끼익끼익 소음이 들림', 129]
# ['단말기고장 문제어불가', 25]
# ['반납했는데 브레이크가 잘 안든다심', 43]
# ['핸들이 KM 운행시 핸들조작이 잘안되고 핸들링이 잘안된다고함', 128]
# ['이용 전 비접촉 손상이라고 하심', 121]
# ['보조석 라이트 미점등', 31]
# ['운행전부터 공기압 경고등 있었음', 31]
# ['긴출기사 일반승용차같은걸 타고 와서 견인해야한다고 함', 121]
# ['분실물 문제어요청', 18]
# ['차량에 경고등 점등되어 문의', 16]
# ['주행시 계속 소음이 나서 긴급출동 서비스요청', 106]
# ['현위치', 42]
# ['개폐 버튼이 없다고 하심', 31]
# ['지금 워셔액은 나온다고 함', 81]
# ['블루투스 미작동', 71]
# ['차량에 시동이 안걸린다고 하심', 57]
# ['내비게이션 및 와이파이 연결 불가 로인입', 21]
# ['주행중 계기판 스패너경고등 점등되어인입', 8]
# ['본넷도 지금 틈사이에 눈이 있어서 얼어서 움직이질 않음', 31]
# ['주유소 위치 확인으로 인입', 31]
# ['라이트 경고등 조수석쪽 하향 안나옴', 31]
# ['예약한 차량 하이패스내비가 전혀 작동하지 않음', 123]
# ['TCS 오작동', 21]
# ['휴대폰 사용가능하신지 양해 일단 휴대폰쓰겠다 함', 20]
# ['사진전송 후 인입', 15]
# ['그리고 달그락달그락 소리가 들림', 118]
# ['문잠금 모니터링 중 문잠금 불가하여 장애블락생성 ', 35]
# ['사진전송 안내', 11]
# ['쏘카존 내 차량 대 있으나 대 시동이 늘 잘 걸리지 않음', 54]
# ['TCS재시작', 18]
# ['단말기 신호불량으로 옥스트라 문제어 불가', 35]
# ['이용전 배터리 방전으로 시동불가', 56]
# ['차량 문이 안열린다고 하심', 56]
# ['후방카메라 작동안되어인입', 134]
# ['한쪽만 안들어옴', 31]
# ['시동이안걸림', 56]
# ['더라움주차장 관리인 인입', 36]
# ['TCS재시작동일하다고함', 18]
# ['고맙습니다', 57]
# ['전조등 점검 문구 나옴', 31]
# ['주행중 바퀴소음발생', 106]
# ['내비 마감재가 떨어져서 내비가 아래로 쳐짐', 22]
# ['차량 변속시 정상적이지 않고 심한 주행떨림으로 운행불가하시어 차량변경 요구', 104]
# ['운전석 선바이저 파손', 52]
# ['소리가 안나서 문의', 71]
# ['안전벨트 체결 했으나 경고음 발생 문의 및 뒷자석 안전벨트 체결 안되서 문의', 64]
# ['후방카메라 작동 고장으로 조치 요청', 134]
# ['재인입시 조치 예정 확인', 25]
# ['하이패스가 전원은 연결되어 있으나 정상 작동 안하는것 같다고 함', 123]
# ['차량 앞에 방향지시등이 안나와서 인입', 31]
# ['타이어 바람빠져 있어 인입', 121]
# ['타이어 경고등건', 121]
# ['차량 문열리지 않음', 35]
# ['워셔액 없어서 문의', 81]
# ['워셔액 통 얼어서 안나옴', 80]
# ['오전에 한차례 내비게이션 정상작동되지 않아 상담했었음 지금 또 정상 작동되지 않음', 21]
# ['차량 후방카메라가 탈거되어 인입', 135]
# ['성신여대로 다시갈꺼라하심', 11]
# ['하이패스 단말기 탈거', 126]
# ['전좌 펑크라고하심', 121]
# ['차량이용중 타이어공기압 경고등떳다고함', 118]
# ['경고등 없으며 차량 상태 문제 없으나 브레이크가 잠긴 느낌이며 주행시 드르륵 소리가 난다함', 42]
# ['주행시 덜덜 소리남 KM 넘으면 심하다함', 106]
# ['운전석은 들어온다고함', 31]
# ['내비 화면이 저절로 블루투스로 변경됨', 18]
# ['이동주차요청 양식 예약메모 콜라비', 96]
# ['타이어 공기압 경고등 점등인입', 118]
# ['내비게이션 이용불가 GPS가 잡혔다가 안잡혔다 반복', 18]
# ['배터리 없음', 56]
# ['차량파손되어 사진전송함', 50]
# ['블랙박스 메모리카드 확인하라고 안내문구나와 인입', 45]
# ['워셔액 동결 추정', 81]
# ['핸들이 쏠리는 현상도 느껴짐', 108]
# ['내비오작동으로인입', 21]
# ['라이트 장애 경고등 긴출 받았으나 규격 안맞아 현장 조치 불가하다며 인입', 31]
# ['시동 걸리지 않아 인입', 56]
# ['내비게이션 안됨 대여 시 차량 정차상황되지않아 다시 문의못했음', 21]
# ['와이퍼도 조금 노후된것 같다고 하심', 74]
# ['운행중 주유하러갓는데 주유소직원이 차량주유캡이 없다고하여인입', 93]
# ['버튼 설명 드렸으나 뜩뜩 거리는 소리나며 장애 해소 안됌', 113]
# ['문제어 불가취소처리', 25]
# ['거치대가 있어서 핸드폰 이용하겠음', 18]
# ['주행중 속도도안나고 알피엠 올라가더니 차량멈추셨다 인입', 103]
# ['엔진체크 경고등 점등주황색', 11]
# ['TCS재시작하였으나 네비가 꺼지지도 않음', 18]
# ['해당 차량 많이 써봤는데 이런 오류 처음이라고 함', 71]
# ['주행중 멈추면 기어 변속이 되지 않는다고 함', 104]
# ['타이어 터짐', 121]
# ['네비사용시 GPS 신호가 약해서 껏다 켜졋다 반복', 21]
# ['반납한차량 후방카메라 작동하지않음', 134]
# ['주유캡 안 열린다고 하심', 94]
# ['경고등은 사라졌지만 차량 변경을 받고 싶다고 함', 118]
# ['다른층도 만차라고하심', 99]
# ['타이어 공기압 경고등 들어와 문의', 118]
# ['차체자세제어장치', 15]
# ['창문락 해제 한건지', 113]
# ['전방충돌방지경고등 점등으로 인입', 7]
# ['후방카메라 나오지 않음 어제는 정상 작동 되었었음', 134]
# ['차량 불량', 28]
# ['일찍 반납하면 크레딧 지급되냐고 문의', 77]
# ['워셔액 직접 구매하여 사용했으나 안나옴', 89]
# ['운행중에 문제는 없을거같은데 내비탈거되있다함', 22]
# ['스마트키 인식되지 않음으로 인입', 57]
# ['내비인터넷연결불가인입', 21]
# ['번호판 재발급', 38]
# ['차량 이용하려고 쏘카존 도착시 차량에 경고등 점등되었다하심', 118]
# ['하이패스 요금은 부과 될 것 안내', 123]
# ['계속 경고음이 들려 인입', 106]
# ['이용한 차량 내비게이션 작동도안됬고 앞창 금이감', 114]
# ['배터리 긴출접수해줘서 조치했는데 배터리 또나갈수있다고해서 불안하다하심 내비게이션도', 21]
# ['내비게이션 작동 안됨 와이파이 연결 불가', 21]
# ['차량 오른쪽 깜빡이 안들어옴', 31]
# ['전우타이어펑크', 121]
# ['운행전 배터리방전문의', 56]
# ['고객님 네비게이션 오류인입', 18]
# ['핸들러확인시 오른쪽미등 미점등확인 경고등 점등안되어있다고 하심', 31]
# ['타이어공기압 경고등 점등돼서왔는데 파스로 확인되어 문의했을때 완료처리하고 가면된다 안내받았는데 맞는것인지 확인요청 긴출기사 인입', 118]
# ['전조등 한쪽이 들어오지 않음', 31]
# ['반납차량 주유카드 없음', 96]
# ['왼쪽 라이트 미점등 내비게이션 장애', 32]
# ['주차브레이크 해제 및 기어변경 불가로 시동걸어도 가시동상태로만 확인되고 운행불가한 차량으로 확인됨', 54]
# ['버튼 눌러도 보조석쪽 안펴짐', 49]
# ['도착 후 전화 주시면 코나차량으로 변경 안내', 9]
# ['그러면 핸들 옆에 버튼 없으신지', 71]
# ['충전기 보조석 전면부 히터', 137]
# ['타이어 공기부족', 118]
# ['주유량부족으로 대차요청', 12]
# ['주행중 엔진경고등 뜨셔서 인입', 11]
# ['시동불가 키아웃 신호 보냈지만 실패', 57]
# ['소음', 29]
# ['내비게이션 안되셔서 인입', 18]
# ['고쳐주세요 스티커도 붙어있다고 함', 23]
# ['지속 재시작 동일', 21]
# ['차량 눈치우고 움직이려니까 경고등 울린다고함', 106]
# ['경고등 점등 되어 있어 문의', 11]
# ['후방카메라 안나온다며 인입', 134]
# ['차량 운행중인데 차량에 브레이크 밟을때마다 시동이 꺼질려고 하고 패드가 밀려서 문의', 43]
# ['크락션이 되지않아인입', 22]
# ['A 필러 파손', 23]
# ['네비게이션장애 휴대폰사용 권유 받은 후 사진전송 시 시간 쿠폰발급해준다고 했음', 21]
# ['운행중 고속도로요금소 통과했는데 인식이안되어인입', 123]
# ['카플레이 옵션 문의', 22]
# ['내비게이션 탈거되어있다고 하심', 22]
# ['라이트 안나온다며 문의', 31]
# ['워셔액이 얼었는지 안나옴', 81]
# ['차량 방전', 56]
# ['주유소 들어오다가 펑 소리와 함께 전우 타이어가 터졌다며 문의', 121]
# ['동일 차량 아님 최근에 썼던 차량이라면 그 차량도 내비게이션 안됐음', 21]
# ['대차를위해 인입', 107]
# ['내비가자꾸꺼진다며 불만으로인입', 18]
# ['콜 백 건V O C 건', 112]
# ['경고등점등됬다며 인입', 31]
# ['후방카메라 센서 빠져있어 후진시 마다 소리나서 운행 불가', 133]
# ['트렁크 열리지 않음', 122]
# ['사진보냈다며 문의', 118]
# ['차량 운행중인데 차량에 핸들이 살짝 쏠리는거같아서 문의', 129]
# ['블루투스 연결했는데 소리가 나지 않아 인입', 71]
# ['핸드폰 내비게이션 이용 불편 사과', 21]
# ['차량 반납지연되서 인입', 28]
# ['내비 장애', 18]
# ['차량 브레이크 살짝만 밟아도 소리가 엄청 크고 드드드득 거린다고 하심 혹시 눈에서 밟지는 않았는지 지하주차장 한층 내려왔는데 이렇다고 하심 분명히 문제가 있다고 하심', 44]
# ['사이드 브레이크 못찾아 출발못하고잇음', 51]
# ['차량을 이용하러왔는데 시동이 안걸려서 문의', 56]
# ['차량 브레이크등 안나오신다하심', 31]
# ['차량 앞 좌석에서 문이 열리지 않는다며 인입 하지만 조수석에서는 조작 가능하여 알려드리려 연락했다 함', 113]
# ['위치오류', 25]
# ['차량 배차중 주유소에서 재시동시 키아웃 문구 발생', 25]
# ['화면 깨짐', 69]
# ['트랜스미션 이상 경고등 ', 104]
# ['브레이크 호스가 터져서 브레이크 오일이 다 샜다고 하심', 7]
# ['수긍 후 통화종료', 11]
# ['사진첨부 타이어 파여있음 타도되는지', 119]
# ['차량에 엔진오일 경고등 들어왔는데 무시하면 되는지', 10]
# ['내비게이션이 작동이 되었다 안되었다 한다고 함', 18]
# ['우측 전조등 하향 점검 경고등 점등', 31]
# ['블루투스때문에 이용못한 분여 시간쿠폰발급드림', 71]
# ['운전석 앞바퀴라고 하심', 121]
# ['충전카드 승인 안됨 결제 불가', 115]
# ['운전시작하자 본네트에서 연기가 올라왔다심', 11]
# ['타이어 바람 빠져있음', 121]
# ['경고등 점등으로 운행 불가', 118]
# ['네비게이션 컴플레인해서 다시켜주셨는데 또 오류', 21]
# ['차량 삐걱 소리 심함 인입', 106]
# ['임시로 지렁이 끼웠으나 펑크난 곳이 사이드라서 기사가 완벽하게 조치가 안 될거 같다고 하셨다며 문의', 121]
# ['서비스점검등 점등으로 출발 전 전화드림', 8]
# ['브레이크페달경고등 점등되었다고 하심', 7]
# ['허 차량으로 대차 블락 설정 해드림', 11]
# ['워셔액 안나와서 매우 불편함문의', 81]
# ['차량 위치 확인 불가로 예약 건 반납 후 인입', 100]
# ['차량 워셔액이 안 나와서 죽을 뻔 했다며 인입', 81]
# ['브레이크에서 끼익소리가남', 44]
# ['고객 운전석 시트높이조절 장치 파손으로 인입 운행하는데 너무 불편하다고 하심', 58]
# ['현장조치 불가하다고 하심', 35]
# ['내비 터치가 아예 안된다고 인입', 18]
# ['재시작후에도 꺼진다함 고속도로진입했는데 자꾸꺼진다고하심불편하다함', 18]
# ['차량 내부 타는냄새', 139]
# ['운전석 조수석 벨트 착용 했는데도 미착용 알림이 계속 울림', 64]
# ['요소수부족경고등점등으로인입', 14]
# ['차 만 탄거를 주면 어쩌냐고 하시며 대차 원하시는데 확인 가능 한 지문의', 106]
# ['차량운행중인데 운행시작부터 타이어공기압이 떳었는데 일단 시간이급해서 계속운행중이라고함', 118]
# ['차량배터리방전인것같다고함', 56]
# ['고객 내비게이션 탈거되서 운행에 불편함으로 인입', 22]
# ['사진으로 받음', 45]
# ['주유하러 왓는데 사용중지 카드라고함', 95]
# ['네비게이션 오작동 문의', 18]
# ['고객님 현재 위치 상세', 11]
# ['내비게이션 장애 제보', 18]
# ['네비게이션 안됨재시작 해도 안됨', 21]
# ['제동등 점검 필요하여 인입', 31]
# ['운행전 타이어 공기압 경고등점등', 118]
# ['조수석쪽 라이트가 안나옴', 31]
# ['이용전부터 있었던 손상이라고 하심', 23]
# ['연장이랑 네비랑 두가지 화면에서 넘어가지가 않아요', 21]
# ['엔진 체크 경고등 아직도 들어오고 있다고 하심', 11]
# ['내비 화면이 나오지 않아 문의', 18]
# ['TCS오작동 워셔액 안나옴', 21]
# ['후방카메라도 흐릿하게 나옴', 103]
# ['수긍 및 종결', 139]
# ['운행전', 12]
# ['타이어 펑크 난 것 같다며 인입', 121]
# ['차량에 타자마자 타이어 공기압이 낮다는 경고등이 점등되어 인입', 118]
# ['워셔액 안내와서 인입', 81]
# ['시트조절버튼 손상', 58]
# ['내비게이션이 소리가 찢어져 이용이 어렵다며 인입', 18]
# ['카드 태깅시 승인되지 않은 카드로 나옴', 91]
# ['운행하려고 했는데 보니까 타이어공기압 경고등 점등되어있음', 118]
# ['배터리방전으로 조금전에 긴출접수해서 조치했는데 이후에 시동끄면 배터리방전또 될수도있고 내비도안된다함', 21]
# ['KM 이상 넘어가는 시점에 떨림이 있다고 함 누구나 느낄정도라고 함', 107]
# ['차량내 워셔액없음 시야가려서 운행어려움', 81]
# ['차량 이용할려고 보니까 타이어펑크 나있음', 121]
# ['고객님 운행전 차량 라이트경고등 확인', 31]
# ['후좌 타이어 펑크로 인입', 121]
# ['그럼 USB 충전은 왜 안되죠', 21]
# ['냉각수 경고등 타이어 공기압 경고등 ', 13]
# ['이나', 112]
# ['타이어공기압 경고등 점등 되어 문의', 118]
# ['타이어 관련 문의', 119]
# ['재시동해도 동일하게 점등됨 확인 ', 11]
# ['보조석 대쉬보드 아래 전면부 히터가 안나온다고함', 137]
# ['경상남도 창녕군 창녕읍 창녕대로 SK행복충전 대흥가스충전소 지상 층', 42]
# ['브레이크 밟을 때 마다 소음 발생하며 에어컨 쪽에서도 가끔씩 이상한 소리가 난다 지금 반납하러 가는 길인데 운행해도 되는건지 모르겠어서 불안하다며 확인 해달라 문의', 44]
# ['워셔액 분사 불가로 점검 요청', 81]
# ['차량 부딪힌 적이 없는데 부딪혔다는 신호가 떴다고 문의', 15]
# ['문열림 문잠금 신호 보냄 반응 옴', 57]
# ['차량 이용하러 왔는데 경고등이 계속 나오면서 차량 시동이 안 걸림 방전된 차량인 것 같다며 인입', 56]
# ['앞 번호판', 135]
# ['차량을 방금 빌렸는데 시동이 걸리지않는다', 56]
# ['시동이 안걸리는데 배터리 방전같다', 56]
# ['조수석 햇빛가리개에 검은색으로 칠해져 있다고 함볼륨 버튼 음향 조절 되지 않는다고 함', 70]
# ['라이트 경고등 통합경고등', 16]
# ['하이패스 통행 시 장착되지 않았다 나와 출구로 나올 때 직접 결제했음', 123]
# ['출차전 경고등노출되어인입', 118]
# ['햐향등 경고등 점등 조수석 방향 하향등 점등되지 않음', 31]
# ['뒷자석 양쪽문 다안열리신다 인입', 28]
# ['내비SD카드삽입하라해서 차량변경해달라하심', 20]
# ['계기판에 연료배출 표시등이 떠서 문의', 11]
# ['라이트장애 경고등 점등', 31]
# ['준비중입니다라고 만나오고 안된다고 함', 21]
# ['라이트 결함 경고등 점등', 31]
# ['엔진체크 경고등과 가속페달이 밟히지 않음', 11]
# ['내비게이션 탈거', 22]
# ['엔진 냉각수 온도가 올라가고 시동이 꺼짐', 11]
# ['네비게이션 고장', 18]
# ['썬루프 제어 불가', 28]
# ['타이어 교체필요', 118]
# ['TCS오작동으로 인입', 18]
# ['주행하려고 하는데 경고등 들어옴', 31]
# ['고객 타기도 전에 차량앞바퀴 펑크', 121]
# ['차량문안열려서 인입', 56]
# ['차랑정차시 본네트 앞에서 떨림 소리 들려 긴급출동 조치 받았으나 현장조치 불가로 인입', 106]
# ['차량변경받았는데 대차받은차량이 경고등이 또떠서 인입', 31]
# ['대차존 도착했고 변경 받기로한 차량 먼저 체크중이었는데 현재 대차 차량 후미등 오른쪽 탈거되어있어서 문의', 32]
# ['내비게이션 소리가 너무 작게들려 이용할수없다고하여 문의', 18]
# ['운행전 문제어 불가', 56]
# ['차량브레이크조금뻣뻣하긴한데 주행에이상은없는부분이라고함', 42]
# ['내비 오작동으로 시간이상 헤메고 다녔으며 주행요금 보상요청', 134]
# ['하이패스 미인식', 123]
# ['차량 문제 문의', 103]
# ['경고등이 나왔는데 어떤건지 모르겠음', 15]
# ['화면 안켜짐', 18]
# ['매립형', 18]
# ['전상 상 충전량과 차량 실제 충전량 상이하여 전기차 충전봇 지속 알림 발생으로 장애블락 생성', 24]
# ['전자식 사이드 브레이크 버튼에 동전이 껴있어 조작 불가로 장애 블락 생성', 51]
# ['주간주행등 점검 경고등 점등되었다고 하심', 31]
# ['타이어에 펑크가 나 있어서 사진 보내주시면 차량 변경 해주시겠다 하셨다며 인입', 121]
# ['하이패스 미승인 으로 나옴', 123]
# ['차량시동이 안걸린다하심', 54]
# ['사진을 첨부해주시면서 차량 공기압 사진 보내주심', 118]
# ['단대오거리쪽으로 견인하여 이동했으나 여전히 키 인식 안됨', 57]
# ['와이퍼 소름끼치는 소리가 난다', 8]
# ['내비게이션을 종료하시겠습니까 문구가 표시된 화면이 나오면 예를 누르셔서 내비게이션 초기화 화면으로 전환되면 우측 상단의 환경설정 버튼을 눌러주세요', 18]
# ['현재 하이패스 인식 안된다고함', 123]
# ['운행전이라고 하심', 118]
# ['차량 소음으로 문의', 29]
# ['허 카니발', 96]
# ['타이어 파스 건 인입', 121]
# ['내비게이션이 T맵 실행준비중으로만 나오고 작동 되지 않음', 18]
# ['어느쪽 경고등인지', 31]
# ['내비 작동 안됨', 18]
# ['고객님 와셔액가득 나오지않음인입', 89]
# ['예약한 시간보다 시간 이상 일찍 반납했는데 크레딧 적립이 안됨', 86]
# ['내비게이션 전원을 키면 지도화면 뜨고 거기서 화면이 멈춤 클릭도 안 됨', 18]
# ['잠시후 TMAP이 실행된다고 나오고 네트워크 문제 라고한다', 21]
# ['잠금해제 접수완료', 56]
# ['후방카메라 여부 문의', 134]
# ['충전커넥터 맨아래 왼쪽 플라스틱 없음', 92]
# ['계속 연장 하고있는데 도저히 반납지까지 제시간안에 못갈거같다고 인입', 103]
# ['주차 경보 뜬다며인입', 32]
# ['문 제어가 안되어 인입', 56]
# ['불편드려 죄송하다 안내 긴출로 확인해드릴수 있다 안내', 44]
# ['라이트 안나옴 경고등은 안떠있음', 31]
# ['엔진체크 라이트 장애 경고등 점등', 11]
# ['TCS 재시작 했으나 동일증상', 18]
# ['확인해보니 방전이라고안냬', 56]
# ['라이트장애경고등 우측 하향등 문제', 11]
# ['차량운행시작하고 차량바닥에서 긁히는소리가 난다고함', 78]
# ['보조석 시트', 60]
# ['타이어 옆면 다른사람이 수리를 잘못하였다고인입', 118]
# ['사진첨부 메세지 확인 별도 조치 필요한지', 45]
# ['열선 고장 문의', 59]
# ['블랙박스 탈거 인입', 45]
# ['통화 중 지속 경고등 점등소리들림', 11]
# ['엔진오일교환필요 점등되어 문의', 10]
# ['내비게이션 업데이트가 필요하다고 주장', 118]
# ['주간주행등이 안들어온다함', 31]
# ['워셔액얼어서 안나옴 외관더러움 공기압경고등 으로 항의', 81]
# ['제동등 점검메세지 점등 ', 31]
# ['충전카드 오류로 인입', 115]
# ['워셔액 나오지 않아 장애 블락생성', 81]
# ['후방카메라가 안 된다며 인입', 134]
# ['긴출로 강제 문제어시 시동은 가능웹뷰핸들러 어플 관제상 문제어 불가로 장애 블락 생성', 25]
# ['차량반납했는데 워셔액을 쓸려고했는데 아무리해도 워셔액이안나왔음 이미 반납하고와서 사진찍어둔건없음', 81]
# ['스마트키 인식안되어 시동걸기 불가', 25]
# ['기사님 출동했으나', 121]
# ['차량문제로 긴출을 받았는데 기사가 그냥 해당문제는 확인할수없는거라고 하시고 그냥가셨다고하심', 129]
# ['고객카드로 결제 후', 95]
# ['워셔액말고는 차량에 문제는 없지만 점검 해야될 거같아서 전화 주셨다고 하심', 81]
# ['TCS 오작동 실행준비중 반복', 18]
# ['T맵 실행중입니다가 시간째 뜨면서 작동이 안된다 함', 18]
# ['차량사진확인 워셔액이안나오는건지확인', 81]
# ['인근에 대차 가능한 차량 없음', 134]
# ['차량상태조회시분실로확인되어 장접', 96]
# ['운행전 배터리방전 시동불가', 56]
# ['블랙박스메모리확인하라는문구발생인입', 45]
# ['지하층에있어 구난추가 접수 요청', 11]

# %%
# CUDA memory 비우기
import torch, gc
gc.collect()
torch.cuda.empty_cache()

# %%
# Setting parameters
max_len = 164 # 해당 길이를 초과하는 단어에 대해선 bert가 학습하지 않음
batch_size = 4 # 기본64 (메모리초과로 인해 4로 설정)
warmup_ratio = 0.1
num_epochs = 20
max_grad_norm = 1
log_interval = 200
learning_rate = 5e-5


# 분류할 type의 총 가짓수
type_cnt = len(list(set(new_data['type'].values.tolist()))) # 존재하는 카테고리 종류 모음

# %%
class BERTClassifier(nn.Module):
    def __init__(self,
                 bert,
                 hidden_size = 768,
                 num_classes = type_cnt, # softmax 사용 <- binary일 경우는 2
                 dr_rate=None,
                 params=None):
        super(BERTClassifier, self).__init__()
        self.bert = bert
        self.dr_rate = dr_rate
                 
        self.classifier = nn.Linear(hidden_size , num_classes)
        if dr_rate:
            self.dropout = nn.Dropout(p=dr_rate)
    
    def gen_attention_mask(self, token_ids, valid_length):
        attention_mask = torch.zeros_like(token_ids)
        for i, v in enumerate(valid_length):
            attention_mask[i][:v] = 1
        return attention_mask.float()

    def forward(self, token_ids, valid_length, segment_ids):
        attention_mask = self.gen_attention_mask(token_ids, valid_length)
        
        _, pooler = self.bert(input_ids = token_ids, token_type_ids = segment_ids.long(), attention_mask = attention_mask.float().to(token_ids.device))
        if self.dr_rate:
            out = self.dropout(pooler)
        return self.classifier(out)


# pytorch용 DataLoader 사용
data_train = BERTDataset(train_list, 0, 1, tok, max_len, True, False)
data_test = BERTDataset(test_list, 0, 1, tok, max_len, True, False)
train_dataloader = torch.utils.data.DataLoader(data_train, batch_size=batch_size, num_workers=5)
test_dataloader = torch.utils.data.DataLoader(data_test, batch_size=batch_size, num_workers=5)


# 모델 불러오기
model = BERTClassifier(bertmodel, dr_rate=0.5).to(device)

# Prepare optimizer and schedule (linear warmup and decay)
no_decay = ['bias', 'LayerNorm.weight']
optimizer_grouped_parameters = [
    {'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)], 'weight_decay': 0.01},
    {'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
]

# 옵티마이저 선언
optimizer = AdamW(optimizer_grouped_parameters, lr=learning_rate)
loss_fn = nn.CrossEntropyLoss() # softmax용 Loss Function 정하기 <- binary classification도 해당 loss function 사용 가능

t_total = len(train_dataloader) * num_epochs
warmup_step = int(t_total * warmup_ratio)

scheduler = get_cosine_schedule_with_warmup(optimizer, num_warmup_steps=warmup_step, num_training_steps=t_total)

# 학습 평가 지표인 accuracy 계산 -> 얼마나 타겟값을 많이 맞추었는가
def calc_accuracy(X,Y):
    max_vals, max_indices = torch.max(X, 1)
    train_acc = (max_indices == Y).sum().data.cpu().numpy()/max_indices.size()[0]
    return train_acc
  
# 모델 학습 시작
for e in range(num_epochs):
    train_acc = 0.0
    test_acc = 0.0
    model.train()
    for batch_id, (token_ids, valid_length, segment_ids, label) in enumerate(tqdm_notebook(train_dataloader)):
        optimizer.zero_grad()
        token_ids = token_ids.long().to(device)
        segment_ids = segment_ids.long().to(device)
        valid_length= valid_length
        label = label.long().to(device)
        out = model(token_ids, valid_length, segment_ids)
        loss = loss_fn(out, label)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm) # gradient clipping
        optimizer.step()
        scheduler.step()  # Update learning rate schedule
        train_acc += calc_accuracy(out, label)
        if batch_id % log_interval == 0:
            print("epoch {} batch id {} loss {} train acc {}".format(e+1, batch_id+1, loss.data.cpu().numpy(), train_acc / (batch_id+1)))
    print("epoch {} train acc {}".format(e+1, train_acc / (batch_id+1)))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:67: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 1 batch id 1 loss 4.785386562347412 train acc 0.0
# epoch 1 batch id 201 loss 5.2790327072143555 train acc 0.0037313432835820895
# epoch 1 batch id 401 loss 4.631361961364746 train acc 0.029925187032418952
# epoch 1 batch id 601 loss 4.1583685874938965 train acc 0.050748752079866885
# epoch 1 batch id 801 loss 3.785870313644409 train acc 0.0749063670411985
# epoch 1 batch id 1001 loss 4.129068374633789 train acc 0.09065934065934066
# epoch 1 batch id 1201 loss 3.974503993988037 train acc 0.09970857618651124
# epoch 1 batch id 1401 loss 3.902794599533081 train acc 0.10902926481084939
# epoch 1 batch id 1601 loss 3.5897376537323 train acc 0.11789506558401
# epoch 1 batch id 1801 loss 3.7837605476379395 train acc 0.12881732370905052
# epoch 1 batch id 2001 loss 4.115349769592285 train acc 0.14042978510744628
#
# epoch 1 train acc 0.1515047879616963
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 2 batch id 1 loss 4.067741394042969 train acc 0.25
# epoch 2 batch id 201 loss 4.4552998542785645 train acc 0.3345771144278607
# epoch 2 batch id 401 loss 3.3815860748291016 train acc 0.31982543640897754
# epoch 2 batch id 601 loss 2.975615978240967 train acc 0.3198835274542429
# epoch 2 batch id 801 loss 2.475768566131592 train acc 0.33083645443196
# epoch 2 batch id 1001 loss 3.83709716796875 train acc 0.32867132867132864
# epoch 2 batch id 1201 loss 1.4712629318237305 train acc 0.3257701915070774
# epoch 2 batch id 1401 loss 3.090872287750244 train acc 0.32780157030692364
# epoch 2 batch id 1601 loss 3.007084369659424 train acc 0.32948157401623984
# epoch 2 batch id 1801 loss 2.4226455688476562 train acc 0.3337034980566352
# epoch 2 batch id 2001 loss 3.485016345977783 train acc 0.33758120939530234
#
# epoch 2 train acc 0.3385772913816689
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 3 batch id 1 loss 3.2731142044067383 train acc 0.25
# epoch 3 batch id 201 loss 4.167140007019043 train acc 0.39925373134328357
# epoch 3 batch id 401 loss 2.083172082901001 train acc 0.3759351620947631
# epoch 3 batch id 601 loss 2.9739437103271484 train acc 0.38019966722129783
# epoch 3 batch id 801 loss 2.371427059173584 train acc 0.3910736579275905
# epoch 3 batch id 1001 loss 3.8935515880584717 train acc 0.3841158841158841
# epoch 3 batch id 1201 loss 1.5002387762069702 train acc 0.3726061615320566
# epoch 3 batch id 1401 loss 3.867370128631592 train acc 0.37205567451820126
# epoch 3 batch id 1601 loss 3.676703453063965 train acc 0.37008119925046845
# epoch 3 batch id 1801 loss 2.6113812923431396 train acc 0.3707662409772349
# epoch 3 batch id 2001 loss 3.2313809394836426 train acc 0.37243878060969515
#
# epoch 3 train acc 0.37209302325581395
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 4 batch id 1 loss 2.3758020401000977 train acc 0.25
# epoch 4 batch id 201 loss 4.477324962615967 train acc 0.4141791044776119
# epoch 4 batch id 401 loss 1.6718165874481201 train acc 0.40523690773067333
# epoch 4 batch id 601 loss 2.7351059913635254 train acc 0.4101497504159734
# epoch 4 batch id 801 loss 1.8699690103530884 train acc 0.42134831460674155
# epoch 4 batch id 1001 loss 4.00813627243042 train acc 0.41483516483516486
# epoch 4 batch id 1201 loss 1.1107622385025024 train acc 0.4052872606161532
# epoch 4 batch id 1401 loss 3.89259672164917 train acc 0.40649536045681656
# epoch 4 batch id 1601 loss 3.6980361938476562 train acc 0.4080262336039975
# epoch 4 batch id 1801 loss 2.0846943855285645 train acc 0.412965019433648
# epoch 4 batch id 2001 loss 2.1179540157318115 train acc 0.4142928535732134
#
# epoch 4 train acc 0.41393068855449155
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 5 batch id 1 loss 2.401393175125122 train acc 0.25
# epoch 5 batch id 201 loss 4.31713342666626 train acc 0.44029850746268656
# epoch 5 batch id 401 loss 1.616711974143982 train acc 0.428927680798005
# epoch 5 batch id 601 loss 2.8444318771362305 train acc 0.435108153078203
# epoch 5 batch id 801 loss 1.6055357456207275 train acc 0.44818976279650435
# epoch 5 batch id 1001 loss 4.031868934631348 train acc 0.4448051948051948
# epoch 5 batch id 1201 loss 1.02219820022583 train acc 0.43984179850124894
# epoch 5 batch id 1401 loss 3.8411402702331543 train acc 0.4377230549607423
# epoch 5 batch id 1601 loss 3.1615679264068604 train acc 0.43707058088694567
# epoch 5 batch id 1801 loss 1.8374886512756348 train acc 0.43725707940033315
# epoch 5 batch id 2001 loss 2.6735572814941406 train acc 0.4397801099450275
#
# epoch 5 train acc 0.43969448244414044
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 6 batch id 1 loss 1.474848747253418 train acc 0.75
# epoch 6 batch id 201 loss 4.156374931335449 train acc 0.4664179104477612
# epoch 6 batch id 401 loss 1.5376741886138916 train acc 0.456359102244389
# epoch 6 batch id 601 loss 2.3775930404663086 train acc 0.456738768718802
# epoch 6 batch id 801 loss 1.5947645902633667 train acc 0.4681647940074906
# epoch 6 batch id 1001 loss 3.8135509490966797 train acc 0.4617882117882118
# epoch 6 batch id 1201 loss 0.8096612691879272 train acc 0.4587843463780183
# epoch 6 batch id 1401 loss 4.121147155761719 train acc 0.4603854389721627
# epoch 6 batch id 1601 loss 3.189771890640259 train acc 0.46158650843222987
# epoch 6 batch id 1801 loss 1.5485589504241943 train acc 0.4655746807329261
# epoch 6 batch id 2001 loss 2.2746434211730957 train acc 0.4681409295352324
#
# epoch 6 train acc 0.468422252621979
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 7 batch id 1 loss 1.7717170715332031 train acc 0.5
# epoch 7 batch id 201 loss 3.811843156814575 train acc 0.48507462686567165
# epoch 7 batch id 401 loss 1.4314892292022705 train acc 0.4756857855361596
# epoch 7 batch id 601 loss 2.193575620651245 train acc 0.46921797004991683
# epoch 7 batch id 801 loss 1.5537700653076172 train acc 0.48408239700374533
# epoch 7 batch id 1001 loss 3.2258942127227783 train acc 0.4825174825174825
# epoch 7 batch id 1201 loss 0.8356752395629883 train acc 0.4804329725228976
# epoch 7 batch id 1401 loss 2.6419992446899414 train acc 0.4851891506067095
# epoch 7 batch id 1601 loss 3.026862859725952 train acc 0.4871955028107433
# epoch 7 batch id 1801 loss 1.2855572700500488 train acc 0.49125485841199334
# epoch 7 batch id 2001 loss 2.092928409576416 train acc 0.49462768615692154
#
# epoch 7 train acc 0.49851801185590516
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 8 batch id 1 loss 1.9380874633789062 train acc 0.75
# epoch 8 batch id 201 loss 3.575437307357788 train acc 0.5509950248756219
# epoch 8 batch id 401 loss 1.1938687562942505 train acc 0.5399002493765586
# epoch 8 batch id 601 loss 2.0743255615234375 train acc 0.5320299500831946
# epoch 8 batch id 801 loss 1.5027507543563843 train acc 0.5433832709113608
# epoch 8 batch id 1001 loss 3.7945876121520996 train acc 0.537962037962038
# epoch 8 batch id 1201 loss 1.282543420791626 train acc 0.5349708576186512
# epoch 8 batch id 1401 loss 3.599787712097168 train acc 0.5362241256245539
# epoch 8 batch id 1601 loss 0.5613811016082764 train acc 0.5365396627108058
# epoch 8 batch id 1801 loss 0.782213568687439 train acc 0.5412270960577457
# epoch 8 batch id 2001 loss 1.9601629972457886 train acc 0.5446026986506747
#
# epoch 8 train acc 0.5463976288189695
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 9 batch id 1 loss 1.304030179977417 train acc 0.5
# epoch 9 batch id 201 loss 3.3791496753692627 train acc 0.5845771144278606
# epoch 9 batch id 401 loss 0.2901570200920105 train acc 0.5766832917705735
# epoch 9 batch id 601 loss 2.1377015113830566 train acc 0.5827787021630616
# epoch 9 batch id 801 loss 0.9037314653396606 train acc 0.5923845193508115
# epoch 9 batch id 1001 loss 4.035294532775879 train acc 0.5861638361638362
# epoch 9 batch id 1201 loss 0.9165542125701904 train acc 0.5838884263114071
# epoch 9 batch id 1401 loss 3.154783010482788 train acc 0.5835117773019272
# epoch 9 batch id 1601 loss 0.830683171749115 train acc 0.5843222985633979
# epoch 9 batch id 1801 loss 0.660473108291626 train acc 0.5867573570238757
# epoch 9 batch id 2001 loss 1.8304531574249268 train acc 0.5913293353323338
#
# epoch 9 train acc 0.5951892384860921
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 10 batch id 1 loss 1.8645906448364258 train acc 0.75
# epoch 10 batch id 201 loss 2.9235410690307617 train acc 0.6218905472636815
# epoch 10 batch id 401 loss 0.06109699606895447 train acc 0.6246882793017456
# epoch 10 batch id 601 loss 1.7349987030029297 train acc 0.6289517470881864
# epoch 10 batch id 801 loss 0.456693559885025 train acc 0.6376404494382022
# epoch 10 batch id 1001 loss 3.6422314643859863 train acc 0.6363636363636364
# epoch 10 batch id 1201 loss 0.32078367471694946 train acc 0.6357202331390508
# epoch 10 batch id 1401 loss 2.9271693229675293 train acc 0.6349036402569593
# epoch 10 batch id 1601 loss 0.37528538703918457 train acc 0.6347595252966896
# epoch 10 batch id 1801 loss 0.5838004946708679 train acc 0.6370072182121044
# epoch 10 batch id 2001 loss 1.7120012044906616 train acc 0.6405547226386806
#
# epoch 10 train acc 0.6439808481532148
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 11 batch id 1 loss 1.7373239994049072 train acc 0.75
# epoch 11 batch id 201 loss 2.6793601512908936 train acc 0.6853233830845771
# epoch 11 batch id 401 loss 0.3052716851234436 train acc 0.6851620947630923
# epoch 11 batch id 601 loss 2.765665054321289 train acc 0.6855241264559068
# epoch 11 batch id 801 loss 1.0368224382400513 train acc 0.6931960049937578
# epoch 11 batch id 1001 loss 3.5592803955078125 train acc 0.6875624375624375
# epoch 11 batch id 1201 loss 0.24774929881095886 train acc 0.6850541215653622
# epoch 11 batch id 1401 loss 1.9917082786560059 train acc 0.6834403997144897
# epoch 11 batch id 1601 loss 0.6238046884536743 train acc 0.683635227982511
# epoch 11 batch id 1801 loss 0.35579368472099304 train acc 0.6853137146029983
# epoch 11 batch id 2001 loss 1.6029688119888306 train acc 0.6877811094452774
#
# epoch 11 train acc 0.6893524851801186
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 12 batch id 1 loss 1.5545389652252197 train acc 0.75
# epoch 12 batch id 201 loss 2.1964774131774902 train acc 0.7238805970149254
# epoch 12 batch id 401 loss 0.09127737581729889 train acc 0.7275561097256857
# epoch 12 batch id 601 loss 2.0473365783691406 train acc 0.7217138103161398
# epoch 12 batch id 801 loss 0.2831624150276184 train acc 0.7275280898876404
# epoch 12 batch id 1001 loss 3.4471607208251953 train acc 0.7222777222777222
# epoch 12 batch id 1201 loss 0.24063368141651154 train acc 0.7212739383846795
# epoch 12 batch id 1401 loss 1.085897445678711 train acc 0.7235902926481085
# epoch 12 batch id 1601 loss 0.15078751742839813 train acc 0.721736414740787
# epoch 12 batch id 1801 loss 0.08310998231172562 train acc 0.7241810105496946
# epoch 12 batch id 2001 loss 1.6473948955535889 train acc 0.7266366816591704
#
# epoch 12 train acc 0.7281121751025992
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 13 batch id 1 loss 1.3968074321746826 train acc 0.75
# epoch 13 batch id 201 loss 2.5044991970062256 train acc 0.7599502487562189
# epoch 13 batch id 401 loss 0.014846984297037125 train acc 0.7630922693266833
# epoch 13 batch id 601 loss 2.0952510833740234 train acc 0.7658069883527454
# epoch 13 batch id 801 loss 0.15219078958034515 train acc 0.7709113607990012
# epoch 13 batch id 1001 loss 3.821960687637329 train acc 0.764985014985015
# epoch 13 batch id 1201 loss 0.1870517134666443 train acc 0.763946711074105
# epoch 13 batch id 1401 loss 0.06111183017492294 train acc 0.7630264097073519
# epoch 13 batch id 1601 loss 0.058943964540958405 train acc 0.7632729544034978
# epoch 13 batch id 1801 loss 0.0626075342297554 train acc 0.7629094947251527
# epoch 13 batch id 2001 loss 1.3575828075408936 train acc 0.7658670664667666
#
# epoch 13 train acc 0.7676698586411309
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 14 batch id 1 loss 1.0829901695251465 train acc 0.75
# epoch 14 batch id 201 loss 1.6687068939208984 train acc 0.7823383084577115
# epoch 14 batch id 401 loss 0.02197442576289177 train acc 0.7917705735660848
# epoch 14 batch id 601 loss 1.3101404905319214 train acc 0.7911813643926788
# epoch 14 batch id 801 loss 0.14944197237491608 train acc 0.7971285892634207
# epoch 14 batch id 1001 loss 3.5076184272766113 train acc 0.7939560439560439
# epoch 14 batch id 1201 loss 0.1875700205564499 train acc 0.7926727726894255
# epoch 14 batch id 1401 loss 0.6794179677963257 train acc 0.7947894361170592
# epoch 14 batch id 1601 loss 0.03892911598086357 train acc 0.7952841973766396
# epoch 14 batch id 1801 loss 0.03955342620611191 train acc 0.7970571904497501
# epoch 14 batch id 2001 loss 1.927363395690918 train acc 0.7981009495252374
#
# epoch 14 train acc 0.7990196078431373
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 15 batch id 1 loss 1.1721537113189697 train acc 0.75
# epoch 15 batch id 201 loss 0.6431078910827637 train acc 0.8146766169154229
# epoch 15 batch id 401 loss 0.01737729087471962 train acc 0.8204488778054863
# epoch 15 batch id 601 loss 1.227211594581604 train acc 0.8232113144758736
# epoch 15 batch id 801 loss 0.21345333755016327 train acc 0.8295880149812734
# epoch 15 batch id 1001 loss 3.3350510597229004 train acc 0.8226773226773226
# epoch 15 batch id 1201 loss 0.09761207550764084 train acc 0.8180682764363031
# epoch 15 batch id 1401 loss 0.02249465510249138 train acc 0.8187009279086367
# epoch 15 batch id 1601 loss 0.03131985291838646 train acc 0.8202685821361649
# epoch 15 batch id 1801 loss 0.04484298825263977 train acc 0.8206551915602444
# epoch 15 batch id 2001 loss 2.0806055068969727 train acc 0.8217141429285357
#
# epoch 15 train acc 0.8226174190606476
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 16 batch id 1 loss 0.7144769430160522 train acc 0.75
# epoch 16 batch id 201 loss 0.755109965801239 train acc 0.8370646766169154
# epoch 16 batch id 401 loss 0.015835925936698914 train acc 0.8403990024937655
# epoch 16 batch id 601 loss 1.0360181331634521 train acc 0.841514143094842
# epoch 16 batch id 801 loss 0.21452847123146057 train acc 0.8470661672908864
# epoch 16 batch id 1001 loss 3.0537009239196777 train acc 0.8431568431568431
# epoch 16 batch id 1201 loss 0.03239971771836281 train acc 0.8401332223147377
# epoch 16 batch id 1401 loss 0.11632437258958817 train acc 0.8394004282655246
# epoch 16 batch id 1601 loss 0.02605225332081318 train acc 0.8411930043722673
# epoch 16 batch id 1801 loss 0.02454887144267559 train acc 0.8393947806774015
# epoch 16 batch id 2001 loss 1.5644710063934326 train acc 0.84007996001999
#
# epoch 16 train acc 0.8399452804377565
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 17 batch id 1 loss 0.6302294731140137 train acc 0.75
# epoch 17 batch id 201 loss 0.0626457929611206 train acc 0.8507462686567164
# epoch 17 batch id 401 loss 0.01343977078795433 train acc 0.8553615960099751
# epoch 17 batch id 601 loss 1.0544477701187134 train acc 0.8585690515806988
# epoch 17 batch id 801 loss 0.146515890955925 train acc 0.864856429463171
# epoch 17 batch id 1001 loss 3.242792844772339 train acc 0.8593906093906094
# epoch 17 batch id 1201 loss 0.025120418518781662 train acc 0.8563696919233972
# epoch 17 batch id 1401 loss 0.015272149816155434 train acc 0.8559957173447538
# epoch 17 batch id 1601 loss 0.02337639033794403 train acc 0.8555590256089943
# epoch 17 batch id 1801 loss 0.018648970872163773 train acc 0.85494169905608
# epoch 17 batch id 2001 loss 1.1226822137832642 train acc 0.856071964017991
#
# epoch 17 train acc 0.8557911536707706
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 18 batch id 1 loss 0.3971105217933655 train acc 1.0
# epoch 18 batch id 201 loss 0.08034761995077133 train acc 0.8706467661691543
# epoch 18 batch id 401 loss 0.01346304826438427 train acc 0.8721945137157108
# epoch 18 batch id 601 loss 0.8564375638961792 train acc 0.872712146422629
# epoch 18 batch id 801 loss 0.1455828696489334 train acc 0.8773408239700374
# epoch 18 batch id 1001 loss 2.3816957473754883 train acc 0.8713786213786214
# epoch 18 batch id 1201 loss 0.021759124472737312 train acc 0.8676103247293921
# epoch 18 batch id 1401 loss 0.02246900461614132 train acc 0.8661670235546038
# epoch 18 batch id 1601 loss 0.019250622019171715 train acc 0.8663335415365396
# epoch 18 batch id 1801 loss 0.6779094338417053 train acc 0.8656302054414214
# epoch 18 batch id 2001 loss 1.6206270456314087 train acc 0.8656921539230384
#
# epoch 18 train acc 0.8650250797993616
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 19 batch id 1 loss 0.4349147081375122 train acc 0.75
# epoch 19 batch id 201 loss 0.042106978595256805 train acc 0.8756218905472637
# epoch 19 batch id 401 loss 0.0106861786916852 train acc 0.8827930174563591
# epoch 19 batch id 601 loss 0.3702848553657532 train acc 0.8835274542429284
# epoch 19 batch id 801 loss 0.11101645976305008 train acc 0.8876404494382022
# epoch 19 batch id 1001 loss 2.540135383605957 train acc 0.8801198801198801
# epoch 19 batch id 1201 loss 0.012471480295062065 train acc 0.8763530391340549
# epoch 19 batch id 1401 loss 0.018440403044223785 train acc 0.8745538900785154
# epoch 19 batch id 1601 loss 0.023912338539958 train acc 0.8749219237976265
# epoch 19 batch id 1801 loss 0.010897781699895859 train acc 0.8740977234869517
# epoch 19 batch id 2001 loss 1.4328497648239136 train acc 0.8740629685157422
#
# epoch 19 train acc 0.8738030095759234
# HBox(children=(FloatProgress(value=0.0, max=2193.0), HTML(value='')))
# epoch 20 batch id 1 loss 0.43762317299842834 train acc 1.0
# epoch 20 batch id 201 loss 0.10669133067131042 train acc 0.8830845771144279
# epoch 20 batch id 401 loss 0.010151270776987076 train acc 0.8859102244389028
# epoch 20 batch id 601 loss 0.18493294715881348 train acc 0.8851913477537438
# epoch 20 batch id 801 loss 0.05842973664402962 train acc 0.8904494382022472
# epoch 20 batch id 1001 loss 2.6178412437438965 train acc 0.8851148851148851
# epoch 20 batch id 1201 loss 0.04862089455127716 train acc 0.8811407160699417
# epoch 20 batch id 1401 loss 0.014654329046607018 train acc 0.8793718772305497
# epoch 20 batch id 1601 loss 0.022285221144557 train acc 0.8791380387257963
# epoch 20 batch id 1801 loss 0.016695531085133553 train acc 0.8784008883953359
# epoch 20 batch id 2001 loss 1.6196684837341309 train acc 0.8784357821089456
#
# epoch 20 train acc 0.8769949840401277

# %%
# 테스트 문장 예측
test_sentence = '네비게이션 분실로 인입.'
test_label = 0 # 장애 번호

unseen_test = pd.DataFrame([[test_sentence, test_label]], columns = [['질문 내용', '장애요인']])
unseen_values = unseen_test.values
test_set = BERTDataset(unseen_values, 0, 1, tok, max_len, True, False)
test_input = torch.utils.data.DataLoader(test_set, batch_size=1, num_workers=5)

right = []
for batch_id, (token_ids, valid_length, segment_ids, label) in enumerate(tqdm_notebook(test_input)):
  token_ids = token_ids.long().to(device)
  segment_ids = segment_ids.long().to(device)
  valid_length= valid_length
  with torch.no_grad():
    out = model(token_ids, valid_length, segment_ids)
  right.append(out.to('cpu'))
  del out
  torch.cuda.empty_cache()
  # 라벨링된 type 매핑 ex) {0: '타이어_파스/펑크', 1: '내비게이션_고장', 2: '블랙박스고장', 3: '하이패스 분실', 4: '주행_차량떨림'}
  print(mapping)
#  print(out)    
  print(right[-1])    
for batch_id, (token_ids, valid_length, segment_ids, label) in enumerate(tqdm_notebook(test_input)):
  token_ids = token_ids.long().to(device)
  segment_ids = segment_ids.long().to(device)
  valid_length= valid_length
  out = model(token_ids, valid_length, segment_ids)
  # 라벨링된 type 매핑 ex) {0: '타이어_파스/펑크', 1: '내비게이션_고장', 2: '블랙박스고장', 3: '하이패스 분실', 4: '주행_차량떨림'}
  print(mapping)
  print(out)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:32: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# {0: 'ADAS_고장', 1: 'ADAS_파손', 2: 'USB포트_고장', 3: '경고등_ABS', 4: '경고등_DPF(배출가스)', 5: '경고등_ESC(차세제어)', 6: '경고등_배터리', 7: '경고등_브레이크', 8: '경고등_스패너(서비스알림)', 9: '경고등_에어백', 10: '경고등_엔진오일', 11: '경고등_엔진체크', 12: '경고등_연료부족', 13: '경고등_온도게이지', 14: '경고등_요소수부족', 15: '경고등_전/후측방 충돌 경고', 16: '경고등_통합경고등(느낌표)', 17: '글로브박스_파손', 18: '내비게이션_고장', 19: '내비게이션_분실', 20: '내비게이션_업데이트', 21: '내비게이션_인터넷연결불가', 22: '내비게이션_파손', 23: '내장제_파손', 24: '단말기_배선', 25: '단말기_신호불량', 26: '단말기_탈거', 27: '단말기_파손', 28: '도어_고장', 29: '도어_소음', 30: '도어_파손', 31: '라이트/전구_경고등(고장)', 32: '라이트/전구_파손', 33: '룸미러_파손', 34: '목받침대_고장/분실', 35: '문제어불가_옥스트라', 36: '문제어불가_카드태깅', 37: '발판매트_분실', 38: '번호판_분실', 39: '번호판_파손', 40: '본넷_고장', 41: '본넷_파손', 42: '브레이크_고장', 43: '브레이크_밀림', 44: '브레이크_소음', 45: '블랙박스_고장', 46: '블랙박스_분실', 47: '블랙박스_파손', 48: '사고조사_요청', 49: '사이드미러_고장', 50: '사이드미러_파손', 51: '사이드브레이크_해제불가', 52: '선바이저_파손', 53: '시거잭_고장', 54: '시동_고장', 55: '시동_꺼짐', 56: '시동_배터리방전', 57: '시동_키인식불가(키아웃)', 58: '시트_시트조절_고장', 59: '시트_열선시트_고장', 60: '시트_파손', 61: '실내등_고장', 62: '안심번호_분실', 63: '안심번호_연동오류', 64: '안전벨트_고장', 65: '에어컨_고장', 66: '에어컨_소음', 67: '에어컨_악취', 68: '오디오_AUX', 69: '오디오_고장', 70: '오디오_버튼파손/분실', 71: '오디오_블루투스', 72: '오디오_소음', 73: '와이퍼_고장', 74: '와이퍼_교체필요', 75: '와이퍼_파손', 76: '외관_누유', 77: '외관_파손(상부)', 78: '외관_파손(하부)', 79: '외부스티커_훼손', 80: '워셔액_(통)파손', 81: '워셔액_고장', 82: '위생_구토', 83: '위생_내부위생불량(모래, 흙, 먼지 등)', 84: '위생_담배(담배냄새, 담뱃재 등)', 85: '위생_동물털', 86: '위생_쓰레기', 87: '위생_악취', 88: '위생_외부위생불량 (유리, 경고장 등)', 89: '위생_워셔액', 90: '전기차_충전구 고장/파손', 91: '전기차_충전불가(태깅불가)', 92: '전기차_충전커넥터_고장', 93: '주유구_(캡)분실', 94: '주유구_고장/파손', 95: '주유카드_결제오류', 96: '주유카드_분실', 97: '주유카드_비치함 파손/탈거', 98: '주유카드_파손', 99: '주차장_입차불가(만차)', 100: '주차장_차량위치확인불가', 101: '주차장_출차불가(비용발생)', 102: '주차장_환경이슈', 103: '주행_RPM이상', 104: '주행_변속기이상', 105: '주행_변속레버파손', 106: '주행_소음', 107: '주행_차량떨림', 108: '주행_차량쏠림(얼라이먼트)', 109: '주행_타는냄새', 110: '주행_핸들떨림', 111: '차량상태확인', 112: '창문_썬팅', 113: '창문_작동불가', 114: '창문_파손', 115: '충전카드_결제오류', 116: '충전카드_보관함 파손/탈거', 117: '충전카드_분실', 118: '타이어_공기압경고등', 119: '타이어_마모', 120: '타이어_코드절상', 121: '타이어_파스/펑크', 122: '트렁크_고장', 123: '하이패스_고장', 124: '하이패스_분실', 125: '하이패스_카드오류', 126: '하이패스_파손(탈거, 파손)', 127: '핸들_경적_고장', 128: '핸들_기능조작', 129: '핸들_소음', 130: '핸들_열선_고장', 131: '핸들_위치조절_고장', 132: '핸들_파손', 133: '후방센서_고장', 134: '후방카메라_고장', 135: '후방카메라_파손(탈거, 각도이상)', 136: '휠_손상', 137: '히터_고장', 138: '히터_소음', 139: '히터_악취'}
# tensor([[-2.5948e+00, -2.2026e+00,  1.1744e+00, -2.8983e+00, -2.4240e+00,
#          -2.0923e+00, -3.0944e+00, -1.5863e+00, -3.6069e+00, -3.8316e+00,
#          -1.9089e+00,  7.3280e-01, -3.4905e+00, -3.4531e+00, -1.9864e+00,
#           1.0282e+00,  1.6046e+00, -3.2282e+00,  1.1489e+01,  8.8556e-01,
#           4.5241e+00,  4.6892e+00,  2.0761e+00, -1.2922e+00, -2.3573e+00,
#           1.5822e+00, -3.6021e+00, -2.8714e+00, -2.4847e+00, -1.1934e+00,
#          -3.8864e+00,  1.8769e+00, -9.3721e-01, -3.2231e+00, -3.7255e+00,
#          -6.7478e-01, -2.8790e+00, -3.5087e+00, -3.7102e+00, -2.6599e+00,
#          -6.6490e-01, -9.7090e-01, -1.3156e+00,  8.5923e-01,  1.7551e+00,
#           1.5722e+00, -1.6878e+00, -1.8716e+00,  1.1245e-01, -1.5473e+00,
#          -2.0484e+00, -4.4681e+00, -4.2776e+00, -1.3679e+00, -1.8223e+00,
#          -1.5545e+00,  5.1441e-01, -2.1566e+00,  2.0115e+00,  2.9060e-01,
#          -3.2444e+00, -2.1514e+00, -3.1455e+00, -3.6525e+00, -1.3965e+00,
#          -1.5861e+00, -2.7365e+00, -1.0666e+00, -3.3789e-01,  2.6053e+00,
#           2.3155e-01,  2.1511e+00, -7.7259e-01, -1.1434e-01, -1.7195e-01,
#          -1.5157e+00, -4.0467e+00, -3.6481e+00, -3.0686e+00, -1.5837e+00,
#          -2.0176e+00,  2.0820e+00, -2.1575e+00, -2.5520e+00, -3.2010e+00,
#          -3.0745e+00, -3.0021e+00, -3.4709e+00, -2.0126e+00, -7.3775e-01,
#          -3.0987e+00, -2.5622e+00, -2.3574e+00, -3.9242e+00, -2.7967e+00,
#          -2.0807e+00, -1.7228e+00, -3.8637e+00, -3.4892e+00, -1.8247e+00,
#          -3.1716e-01, -2.5920e+00, -2.2834e+00,  1.2021e+00, -3.5594e+00,
#          -3.1455e+00,  1.6981e+00,  1.7220e+00,  1.2372e+00, -3.8037e+00,
#          -1.0616e+00, -1.2270e+00, -2.4937e+00, -7.4467e-01, -3.9701e+00,
#          -1.6355e+00, -3.2251e+00, -3.0389e+00,  1.3550e+00, -1.8580e+00,
#          -3.9119e+00, -3.5433e-01, -5.0897e+00,  1.4551e-02, -3.1237e+00,
#          -1.8728e+00, -3.3684e+00, -1.0261e+00, -1.7091e+00, -1.0673e+00,
#          -2.2838e+00, -1.2099e+00, -3.3921e+00, -2.8215e+00,  2.5030e+00,
#          -6.0806e-06, -3.6976e+00, -3.9085e+00, -2.2071e+00, -3.3142e+00]])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# {0: 'ADAS_고장', 1: 'ADAS_파손', 2: 'USB포트_고장', 3: '경고등_ABS', 4: '경고등_DPF(배출가스)', 5: '경고등_ESC(차세제어)', 6: '경고등_배터리', 7: '경고등_브레이크', 8: '경고등_스패너(서비스알림)', 9: '경고등_에어백', 10: '경고등_엔진오일', 11: '경고등_엔진체크', 12: '경고등_연료부족', 13: '경고등_온도게이지', 14: '경고등_요소수부족', 15: '경고등_전/후측방 충돌 경고', 16: '경고등_통합경고등(느낌표)', 17: '글로브박스_파손', 18: '내비게이션_고장', 19: '내비게이션_분실', 20: '내비게이션_업데이트', 21: '내비게이션_인터넷연결불가', 22: '내비게이션_파손', 23: '내장제_파손', 24: '단말기_배선', 25: '단말기_신호불량', 26: '단말기_탈거', 27: '단말기_파손', 28: '도어_고장', 29: '도어_소음', 30: '도어_파손', 31: '라이트/전구_경고등(고장)', 32: '라이트/전구_파손', 33: '룸미러_파손', 34: '목받침대_고장/분실', 35: '문제어불가_옥스트라', 36: '문제어불가_카드태깅', 37: '발판매트_분실', 38: '번호판_분실', 39: '번호판_파손', 40: '본넷_고장', 41: '본넷_파손', 42: '브레이크_고장', 43: '브레이크_밀림', 44: '브레이크_소음', 45: '블랙박스_고장', 46: '블랙박스_분실', 47: '블랙박스_파손', 48: '사고조사_요청', 49: '사이드미러_고장', 50: '사이드미러_파손', 51: '사이드브레이크_해제불가', 52: '선바이저_파손', 53: '시거잭_고장', 54: '시동_고장', 55: '시동_꺼짐', 56: '시동_배터리방전', 57: '시동_키인식불가(키아웃)', 58: '시트_시트조절_고장', 59: '시트_열선시트_고장', 60: '시트_파손', 61: '실내등_고장', 62: '안심번호_분실', 63: '안심번호_연동오류', 64: '안전벨트_고장', 65: '에어컨_고장', 66: '에어컨_소음', 67: '에어컨_악취', 68: '오디오_AUX', 69: '오디오_고장', 70: '오디오_버튼파손/분실', 71: '오디오_블루투스', 72: '오디오_소음', 73: '와이퍼_고장', 74: '와이퍼_교체필요', 75: '와이퍼_파손', 76: '외관_누유', 77: '외관_파손(상부)', 78: '외관_파손(하부)', 79: '외부스티커_훼손', 80: '워셔액_(통)파손', 81: '워셔액_고장', 82: '위생_구토', 83: '위생_내부위생불량(모래, 흙, 먼지 등)', 84: '위생_담배(담배냄새, 담뱃재 등)', 85: '위생_동물털', 86: '위생_쓰레기', 87: '위생_악취', 88: '위생_외부위생불량 (유리, 경고장 등)', 89: '위생_워셔액', 90: '전기차_충전구 고장/파손', 91: '전기차_충전불가(태깅불가)', 92: '전기차_충전커넥터_고장', 93: '주유구_(캡)분실', 94: '주유구_고장/파손', 95: '주유카드_결제오류', 96: '주유카드_분실', 97: '주유카드_비치함 파손/탈거', 98: '주유카드_파손', 99: '주차장_입차불가(만차)', 100: '주차장_차량위치확인불가', 101: '주차장_출차불가(비용발생)', 102: '주차장_환경이슈', 103: '주행_RPM이상', 104: '주행_변속기이상', 105: '주행_변속레버파손', 106: '주행_소음', 107: '주행_차량떨림', 108: '주행_차량쏠림(얼라이먼트)', 109: '주행_타는냄새', 110: '주행_핸들떨림', 111: '차량상태확인', 112: '창문_썬팅', 113: '창문_작동불가', 114: '창문_파손', 115: '충전카드_결제오류', 116: '충전카드_보관함 파손/탈거', 117: '충전카드_분실', 118: '타이어_공기압경고등', 119: '타이어_마모', 120: '타이어_코드절상', 121: '타이어_파스/펑크', 122: '트렁크_고장', 123: '하이패스_고장', 124: '하이패스_분실', 125: '하이패스_카드오류', 126: '하이패스_파손(탈거, 파손)', 127: '핸들_경적_고장', 128: '핸들_기능조작', 129: '핸들_소음', 130: '핸들_열선_고장', 131: '핸들_위치조절_고장', 132: '핸들_파손', 133: '후방센서_고장', 134: '후방카메라_고장', 135: '후방카메라_파손(탈거, 각도이상)', 136: '휠_손상', 137: '히터_고장', 138: '히터_소음', 139: '히터_악취'}
# tensor([[-2.0281e+00, -2.0456e+00,  8.9906e-01, -1.6532e+00, -2.2080e+00,
#          -1.5081e+00, -2.0834e+00, -2.9629e-01, -2.2443e+00, -2.6883e+00,
#          -2.0799e+00,  4.1801e-01, -3.5185e+00, -3.3268e+00, -2.3436e+00,
#           1.9043e+00,  2.2986e+00, -2.2941e+00,  1.1393e+01,  2.9389e-01,
#           4.7337e+00,  4.0091e+00,  1.3813e+00, -1.0421e+00, -1.9154e+00,
#           1.2791e+00, -3.1036e+00, -1.8811e+00, -2.7401e+00, -6.0539e-01,
#          -3.7022e+00,  2.6426e+00,  4.1397e-01, -1.8530e+00, -2.5522e+00,
#          -8.8813e-01, -3.2888e+00, -3.9582e+00, -3.1003e+00, -3.4142e+00,
#          -4.7209e-03, -1.7996e+00, -3.0832e-01,  1.0849e+00,  2.2061e+00,
#           1.2933e+00, -3.6912e-01, -9.7253e-01,  2.4176e-02, -1.1048e+00,
#          -2.3659e+00, -3.7669e+00, -3.2237e+00, -1.2256e+00, -9.2448e-01,
#          -1.3792e+00,  6.6346e-01, -2.8812e+00,  3.9563e-01, -5.0605e-02,
#          -2.5393e+00, -1.8947e+00, -2.6258e+00, -3.4073e+00, -1.3141e+00,
#          -1.6591e+00, -1.2198e+00, -4.6063e-01, -8.8120e-01,  3.2269e+00,
#           7.4884e-01,  1.1285e+00,  3.1245e-01, -5.1234e-01,  5.1532e-01,
#          -9.3543e-01, -3.8943e+00, -3.4426e+00, -2.2675e+00, -1.5532e+00,
#          -1.1268e+00,  1.2533e+00, -1.9107e+00, -2.1129e+00, -2.3175e+00,
#          -2.9768e+00, -2.9260e+00, -2.4076e+00, -1.8788e+00, -8.2114e-01,
#          -3.1245e+00, -2.1755e+00, -1.6291e+00, -4.1436e+00, -3.0363e+00,
#          -1.8685e+00, -1.8357e+00, -4.1615e+00, -3.0282e+00, -2.6984e+00,
#          -7.6381e-01, -2.8868e+00, -1.7571e+00, -1.1498e-01, -3.0773e+00,
#          -2.1236e+00,  2.8976e+00,  2.4212e+00,  6.2749e-01, -2.8197e+00,
#          -8.2583e-01, -6.7908e-01, -3.5660e+00, -1.4189e+00, -3.2018e+00,
#          -2.0119e+00, -1.9526e+00, -1.8789e+00,  1.2805e+00, -1.5646e+00,
#          -3.2676e+00,  2.3250e-02, -4.5027e+00,  3.4060e-01, -2.6199e+00,
#          -1.9588e+00, -3.6878e+00, -2.8832e-01, -6.8697e-01, -6.1302e-01,
#          -1.4471e+00, -3.7230e-01, -1.6584e+00, -2.7022e+00,  1.7913e+00,
#          -7.7369e-01, -2.8079e+00, -3.8337e+00, -3.2746e+00, -3.5110e+00]],
#        device='cuda:0', grad_fn=<AddmmBackward>)
